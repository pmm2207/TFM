# %%
# Librerias utilizadas
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
# Out:
# 2022-11-13 21:24:45.731939: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Importación de datos

# %%
df = pd.read_csv('data/DATA_36.85_-4.24.csv')
df.head()
# Out:
#          DATA  spdi_1  spdi_3  spdi_6  spdi_9  spdi_12  spdi_24  spdi_36  \
# 0  1961-01-01     NaN     NaN     NaN     NaN      NaN      NaN      NaN
# 1  1961-01-09     NaN     NaN     NaN     NaN      NaN      NaN      NaN
# 2  1961-01-16     NaN     NaN     NaN     NaN      NaN      NaN      NaN
# 3  1961-01-23   -0.59     NaN     NaN     NaN      NaN      NaN      NaN
# 4  1961-02-01   -0.83     NaN     NaN     NaN      NaN      NaN      NaN
#
#    spdi_48  spei_1  ...  spi_6  spi_9  spi_12  spi_24  spi_36  spi_48  scpdsi  \
# 0      NaN     NaN  ...    NaN    NaN     NaN     NaN     NaN     NaN   -0.08
# 1      NaN     NaN  ...    NaN    NaN     NaN     NaN     NaN     NaN   -0.20
# 2      NaN     NaN  ...    NaN    NaN     NaN     NaN     NaN     NaN   -0.25
# 3      NaN   -0.47  ...    NaN    NaN     NaN     NaN     NaN     NaN   -0.35
# 4      NaN   -0.79  ...    NaN    NaN     NaN     NaN     NaN     NaN   -0.47
#
#    scphdi  sczindex  scwplm
# 0   -0.08     -0.57   -0.08
# 1   -0.20     -0.90   -0.20
# 2   -0.25     -0.39   -0.25
# 3   -0.35     -0.80   -0.35
# 4   -0.47     -0.88   -0.47
#
# [5 rows x 29 columns]

# %% [markdown]
# # Preprocesamiento de datos

# %%
# Creamos un dataset del indice SPI para un periodo de 1 mes
spi_1 = df['spi_1']
# Quitamos valores vacios
spi_1 = spi_1.dropna(how='all')
# Comprobamos que los únicos valores vacíos eran los iniciales
print(len(spi_1))
print(spi_1.index[-1]-spi_1.index[0]+1)
spi_1.head()
# Out:
# 2925
# 2925
# 3   -0.50
# 4   -0.77
# 5   -0.87
# 6   -1.36
# 7   -1.73
# Name: spi_1, dtype: float64

# %%
spi_1.plot()
plt.show()

# %%
# Separación en conjunto de entrenamiento y de prueba
train_df, test_df = train_test_split(spi_1, test_size=0.13, shuffle=False)

# %%
# Creamos un dataset sequencial con arrays de valores input/output
# Este dataset tiene la estructura adecuada para los datos de entrada
# en la red neuronal
def to_sequences(seq_size, obs):
    x = []
    y = []

    for i in range(len(obs)-seq_size):
        window = obs.iloc[i:(i+seq_size)]
        after_window = obs.iloc[i+seq_size]
        window = [[x] for x in window]
        x.append(window)
        y.append(after_window)
        
    return np.array(x),np.array(y)
    
    
sequence_size = 10
X_train,y_train = to_sequences(sequence_size, train_df)
X_test,y_test = to_sequences(sequence_size, test_df)

print("Dimensiones del training set: {}".format(X_train.shape))
print("Dimensiones del test set: {}".format(X_test.shape))
# Out:
# Dimensiones del training set: (2534, 10, 1)
# Dimensiones del test set: (371, 10, 1)

# %% [markdown]
# # Definición del modelo

# %%
model = Sequential()
model.add(Dense(20, activation='relu', input_dim=X_train.shape[1]))
model.add(Dense(1))

# %% [markdown]
# # Compilación del modelo

# %%
model.compile(optimizer='adam', loss='mse')
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 20)                220
#
#  dense_1 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 241
# Trainable params: 241
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Entrenamiento del modelo

# %%
# Creamos un early stopping para evitar overfitting
es = EarlyStopping(monitor='val_loss', verbose=1, patience=3)

# %%
history = model.fit(X_train, y_train, epochs=200, batch_size=10, validation_data=(X_test, y_test), verbose=2, shuffle=False, callbacks=[es])
# Out:
# Epoch 1/200
# 254/254 - 2s - loss: 0.8462 - val_loss: 0.3949 - 2s/epoch - 6ms/step
# Epoch 2/200
# 254/254 - 1s - loss: 0.4884 - val_loss: 0.2781 - 569ms/epoch - 2ms/step
# Epoch 3/200
# 254/254 - 1s - loss: 0.4122 - val_loss: 0.2331 - 559ms/epoch - 2ms/step
# Epoch 4/200
# 254/254 - 0s - loss: 0.3762 - val_loss: 0.2112 - 376ms/epoch - 1ms/step
# Epoch 5/200
# 254/254 - 0s - loss: 0.3564 - val_loss: 0.1997 - 327ms/epoch - 1ms/step
# Epoch 6/200
# 254/254 - 0s - loss: 0.3447 - val_loss: 0.1940 - 293ms/epoch - 1ms/step
# Epoch 7/200
# 254/254 - 0s - loss: 0.3375 - val_loss: 0.1909 - 307ms/epoch - 1ms/step
# Epoch 8/200
# 254/254 - 0s - loss: 0.3324 - val_loss: 0.1892 - 337ms/epoch - 1ms/step
# Epoch 9/200
# 254/254 - 0s - loss: 0.3287 - val_loss: 0.1880 - 403ms/epoch - 2ms/step
# Epoch 10/200
# 254/254 - 0s - loss: 0.3262 - val_loss: 0.1868 - 318ms/epoch - 1ms/step
# Epoch 11/200
# 254/254 - 0s - loss: 0.3242 - val_loss: 0.1862 - 463ms/epoch - 2ms/step
# Epoch 12/200
# 254/254 - 0s - loss: 0.3225 - val_loss: 0.1852 - 492ms/epoch - 2ms/step
# Epoch 13/200
# 254/254 - 0s - loss: 0.3210 - val_loss: 0.1844 - 366ms/epoch - 1ms/step
# Epoch 14/200
# 254/254 - 0s - loss: 0.3196 - val_loss: 0.1839 - 307ms/epoch - 1ms/step
# Epoch 15/200
# 254/254 - 0s - loss: 0.3182 - val_loss: 0.1835 - 352ms/epoch - 1ms/step
# Epoch 16/200
# 254/254 - 0s - loss: 0.3173 - val_loss: 0.1833 - 371ms/epoch - 1ms/step
# Epoch 17/200
# 254/254 - 0s - loss: 0.3165 - val_loss: 0.1831 - 314ms/epoch - 1ms/step
# Epoch 18/200
# 254/254 - 0s - loss: 0.3157 - val_loss: 0.1829 - 304ms/epoch - 1ms/step
# Epoch 19/200
# 254/254 - 0s - loss: 0.3149 - val_loss: 0.1828 - 240ms/epoch - 944us/step
# Epoch 20/200
# 254/254 - 0s - loss: 0.3142 - val_loss: 0.1828 - 304ms/epoch - 1ms/step
# Epoch 21/200
# 254/254 - 0s - loss: 0.3135 - val_loss: 0.1828 - 357ms/epoch - 1ms/step
# Epoch 22/200
# 254/254 - 0s - loss: 0.3129 - val_loss: 0.1829 - 456ms/epoch - 2ms/step
# Epoch 23/200
# 254/254 - 0s - loss: 0.3123 - val_loss: 0.1829 - 244ms/epoch - 961us/step
# Epoch 23: early stopping

# %%
# Resumen del entrenamiento
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# %% [markdown]
# # Evaluación del modelo

# %%
train_prediction = model.predict(X_train)
test_prediction = model.predict(X_test)
train_score = model.evaluate(X_train, y_train)
test_score = model.evaluate(X_test, y_test)
print('Train score: {} MSE'.format(train_score))
print('Test score: {} MSE'.format(test_score))
# Out:
# 80/80 [==============================] - 0s 2ms/step
# 12/12 [==============================] - 0s 1ms/step
# 80/80 [==============================] - 0s 1ms/step - loss: 0.3085
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1829
# Train score: 0.3085491359233856 MSE
# Test score: 0.18286052346229553 MSE

# %% [markdown]
# # Visualización de la predicción

# %%
# Graficamos los valores reales frente a los datos de predicción
plt.figure(figsize=(12, 8))
train_stamp = np.arange(sequence_size, sequence_size + X_train.shape[0])
test_stamp = np.arange(2 * sequence_size + X_train.shape[0], len(spi_1))
plt.plot(spi_1, label='Valores reales')
plt.plot(train_stamp, train_prediction, label='train prediction')
plt.plot(test_stamp, test_prediction, label = 'test prediction')
plt.legend()
plt.show()
