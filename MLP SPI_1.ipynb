# %%
# Librerias utilizadas
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
# Out:
# 2022-11-13 22:32:02.069779: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Importación de datos

# %%
df = pd.read_csv('data/DATA_36.85_-4.24.csv')
df.head()
# Out:
#          DATA  spdi_1  spdi_3  spdi_6  spdi_9  spdi_12  spdi_24  spdi_36  \
# 0  1961-01-01     NaN     NaN     NaN     NaN      NaN      NaN      NaN
# 1  1961-01-09     NaN     NaN     NaN     NaN      NaN      NaN      NaN
# 2  1961-01-16     NaN     NaN     NaN     NaN      NaN      NaN      NaN
# 3  1961-01-23   -0.59     NaN     NaN     NaN      NaN      NaN      NaN
# 4  1961-02-01   -0.83     NaN     NaN     NaN      NaN      NaN      NaN
#
#    spdi_48  spei_1  ...  spi_6  spi_9  spi_12  spi_24  spi_36  spi_48  scpdsi  \
# 0      NaN     NaN  ...    NaN    NaN     NaN     NaN     NaN     NaN   -0.08
# 1      NaN     NaN  ...    NaN    NaN     NaN     NaN     NaN     NaN   -0.20
# 2      NaN     NaN  ...    NaN    NaN     NaN     NaN     NaN     NaN   -0.25
# 3      NaN   -0.47  ...    NaN    NaN     NaN     NaN     NaN     NaN   -0.35
# 4      NaN   -0.79  ...    NaN    NaN     NaN     NaN     NaN     NaN   -0.47
#
#    scphdi  sczindex  scwplm
# 0   -0.08     -0.57   -0.08
# 1   -0.20     -0.90   -0.20
# 2   -0.25     -0.39   -0.25
# 3   -0.35     -0.80   -0.35
# 4   -0.47     -0.88   -0.47
#
# [5 rows x 29 columns]

# %% [markdown]
# # Preprocesamiento de datos

# %%
# Creamos un dataset del indice SPI para un periodo de 1 mes
spi_1 = df['spi_1']
# Quitamos valores vacios
spi_1 = spi_1.dropna(how='all')
# Comprobamos que los únicos valores vacíos eran los iniciales
print(len(spi_1))
print(spi_1.index[-1]-spi_1.index[0]+1)
spi_1.head()
# Out:
# 2925
# 2925
# 3   -0.50
# 4   -0.77
# 5   -0.87
# 6   -1.36
# 7   -1.73
# Name: spi_1, dtype: float64

# %%
spi_1.plot()
plt.show()

# %%
# Separación en conjunto de entrenamiento y de prueba
train_df, test_df = train_test_split(spi_1, test_size=0.13, shuffle=False)

# %%
# Creamos un dataset sequencial con arrays de valores input/output
# Este dataset tiene la estructura adecuada para los datos de entrada
# en la red neuronal
def to_sequences(seq_size, obs):
    x = []
    y = []

    for i in range(len(obs)-seq_size):
        window = obs.iloc[i:(i+seq_size)]
        after_window = obs.iloc[i+seq_size]
        window = [[x] for x in window]
        x.append(window)
        y.append(after_window)
        
    return np.array(x),np.array(y)
    
    
sequence_size = 10
X_train,y_train = to_sequences(sequence_size, train_df)
X_test,y_test = to_sequences(sequence_size, test_df)

print("Dimensiones del training set: {}".format(X_train.shape))
print("Dimensiones del test set: {}".format(X_test.shape))
# Out:
# Dimensiones del training set: (2534, 10, 1)
# Dimensiones del test set: (371, 10, 1)

# %% [markdown]
# # Definición del modelo

# %%
model = Sequential()
model.add(Dense(20, activation='relu', input_dim=X_train.shape[1]))
model.add(Dense(1))
# Out:
# 2022-11-13 22:32:11.597706: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-13 22:32:11.598241: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %% [markdown]
# # Compilación del modelo

# %%
model.compile(optimizer='adam', loss='mse')

# %% [markdown]
# # Entrenamiento del modelo

# %%
# Creamos un early stopping para evitar overfitting
es = EarlyStopping(monitor='val_loss', verbose=1, patience=3)

# %%
history = model.fit(X_train, y_train, epochs=200, batch_size=10, validation_data=(X_test, y_test), verbose=2, shuffle=False, callbacks=[es])
# Out:
# Epoch 1/200
# 254/254 - 2s - loss: 0.5590 - val_loss: 0.2453 - 2s/epoch - 6ms/step
# Epoch 2/200
# 254/254 - 0s - loss: 0.4019 - val_loss: 0.2208 - 491ms/epoch - 2ms/step
# Epoch 3/200
# 254/254 - 0s - loss: 0.3666 - val_loss: 0.2115 - 307ms/epoch - 1ms/step
# Epoch 4/200
# 254/254 - 1s - loss: 0.3523 - val_loss: 0.2073 - 518ms/epoch - 2ms/step
# Epoch 5/200
# 254/254 - 0s - loss: 0.3447 - val_loss: 0.2038 - 475ms/epoch - 2ms/step
# Epoch 6/200
# 254/254 - 1s - loss: 0.3394 - val_loss: 0.2006 - 531ms/epoch - 2ms/step
# Epoch 7/200
# 254/254 - 0s - loss: 0.3350 - val_loss: 0.1984 - 339ms/epoch - 1ms/step
# Epoch 8/200
# 254/254 - 0s - loss: 0.3314 - val_loss: 0.1961 - 362ms/epoch - 1ms/step
# Epoch 9/200
# 254/254 - 0s - loss: 0.3284 - val_loss: 0.1946 - 491ms/epoch - 2ms/step
# Epoch 10/200
# 254/254 - 0s - loss: 0.3259 - val_loss: 0.1930 - 403ms/epoch - 2ms/step
# Epoch 11/200
# 254/254 - 0s - loss: 0.3236 - val_loss: 0.1921 - 320ms/epoch - 1ms/step
# Epoch 12/200
# 254/254 - 0s - loss: 0.3216 - val_loss: 0.1912 - 434ms/epoch - 2ms/step
# Epoch 13/200
# 254/254 - 1s - loss: 0.3199 - val_loss: 0.1899 - 607ms/epoch - 2ms/step
# Epoch 14/200
# 254/254 - 0s - loss: 0.3183 - val_loss: 0.1888 - 395ms/epoch - 2ms/step
# Epoch 15/200
# 254/254 - 0s - loss: 0.3169 - val_loss: 0.1881 - 297ms/epoch - 1ms/step
# Epoch 16/200
# 254/254 - 0s - loss: 0.3157 - val_loss: 0.1874 - 389ms/epoch - 2ms/step
# Epoch 17/200
# 254/254 - 0s - loss: 0.3145 - val_loss: 0.1869 - 332ms/epoch - 1ms/step
# Epoch 18/200
# 254/254 - 0s - loss: 0.3135 - val_loss: 0.1865 - 258ms/epoch - 1ms/step
# Epoch 19/200
# 254/254 - 1s - loss: 0.3128 - val_loss: 0.1863 - 694ms/epoch - 3ms/step
# Epoch 20/200
# 254/254 - 1s - loss: 0.3119 - val_loss: 0.1861 - 609ms/epoch - 2ms/step
# Epoch 21/200
# 254/254 - 0s - loss: 0.3113 - val_loss: 0.1860 - 424ms/epoch - 2ms/step
# Epoch 22/200
# 254/254 - 0s - loss: 0.3107 - val_loss: 0.1857 - 480ms/epoch - 2ms/step
# Epoch 23/200
# 254/254 - 1s - loss: 0.3100 - val_loss: 0.1854 - 795ms/epoch - 3ms/step
# Epoch 24/200
# 254/254 - 1s - loss: 0.3093 - val_loss: 0.1851 - 1s/epoch - 4ms/step
# Epoch 25/200
# 254/254 - 1s - loss: 0.3087 - val_loss: 0.1851 - 1s/epoch - 5ms/step
# Epoch 26/200
# 254/254 - 1s - loss: 0.3083 - val_loss: 0.1849 - 863ms/epoch - 3ms/step
# Epoch 27/200
# 254/254 - 1s - loss: 0.3078 - val_loss: 0.1851 - 643ms/epoch - 3ms/step
# Epoch 28/200
# 254/254 - 1s - loss: 0.3074 - val_loss: 0.1849 - 640ms/epoch - 3ms/step
# Epoch 29/200
# 254/254 - 1s - loss: 0.3071 - val_loss: 0.1848 - 554ms/epoch - 2ms/step
# Epoch 30/200
# 254/254 - 0s - loss: 0.3067 - val_loss: 0.1848 - 486ms/epoch - 2ms/step
# Epoch 31/200
# 254/254 - 0s - loss: 0.3063 - val_loss: 0.1849 - 407ms/epoch - 2ms/step
# Epoch 32/200
# 254/254 - 0s - loss: 0.3060 - val_loss: 0.1848 - 478ms/epoch - 2ms/step
# Epoch 32: early stopping

# %%
# Resumen del entrenamiento
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# %% [markdown]
# # Evaluación del modelo

# %%
train_prediction = model.predict(X_train)
test_prediction = model.predict(X_test)
train_score = model.evaluate(X_train, y_train)
test_score = model.evaluate(X_test, y_test)
print('Train score: {} MSE'.format(train_score))
print('Test score: {} MSE'.format(test_score))
# Out:
# 80/80 [==============================] - 0s 1ms/step
# 12/12 [==============================] - 0s 9ms/step
# 80/80 [==============================] - 0s 2ms/step - loss: 0.3022
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1848
# Train score: 0.3021933436393738 MSE
# Test score: 0.18482352793216705 MSE

# %% [markdown]
# # Visualización de la predicción

# %%
# Graficamos los valores reales frente a los datos de predicción
plt.figure(figsize=(12, 8))
train_stamp = np.arange(sequence_size, sequence_size + X_train.shape[0])
test_stamp = np.arange(2 * sequence_size + X_train.shape[0], len(spi_1))
plt.plot(spi_1, label='Valores reales')
plt.plot(train_stamp, train_prediction, label='train prediction')
plt.plot(test_stamp, test_prediction, label = 'test prediction')
plt.legend()
plt.show()
