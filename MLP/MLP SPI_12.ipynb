# %%
# Librerias utilizadas
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from scikeras.wrappers import KerasRegressor
import warnings

# %% [markdown]
# ## Importación de datos

# %%
csv_names  = ['df_DHCMA', 'df_CHG', 'df_CHGUADIANA',
            'df_CHS', 'df_DHGB', 'df_DHTOP']
path = '..\\DATA\\'
keys_names = ['Demarcación Hidrográfica de las Cuencas Mediterráneas Andaluzas', 'Cuenca hidrográfica del Guadalquivir', 'Cuenca hidrográfica del Guadiana',
              'Cuenca hidrográfica del Segura', 'Demarcación Hidrográfica Guadalete-Barbate', 'Demarcación Hidrográfica Tinto, Odiel y Piedras']
df_dict = {key: pd.read_csv(path+value+'.csv', sep=',', encoding='ISO-8859-1')
           for key, value in zip(keys_names, csv_names)}

# %% [markdown]
# ## Procesado de datos de entrada

# %%
# Función de creación de dataset sequencial con arrays de valores input/output
# Este dataset tiene la estructura adecuada para los datos de entrada
# en la red neuronal
def to_sequences(seq_size, obs):
    x = []
    y = []

    for i in range(len(obs)-seq_size):
        window = obs.iloc[i:(i+seq_size)]
        after_window = obs.iloc[i+seq_size]
        window = [[x] for x in window]
        x.append(window)
        y.append(after_window)
        
    return np.array(x),np.array(y)

# %%
# Creación del dataset de indice SPI_12
spi_12_dict =  {key: value['spi_12']
           for key, value in df_dict.items()}

# Eliminación valores vacios iniciales
for key, df in spi_12_dict.items():           
    spi_12_dict[key] = df.dropna(how='all')

# %%
# Separación en conjunto de entrenamiento y de prueba
# Los datos de prueba empiezan a partir de 2011
spi_12_train_dict, spi_12_test_dict = {}, {}
for key, df in spi_12_dict.items():
    df_train, df_test = train_test_split(df, test_size=0.13, shuffle=False)
    spi_12_train_dict[key] = df_train
    spi_12_test_dict[key] = df_test

# %%
# Cálculo de datasets sequenciales
sequence_size = 10
X_train_dict, y_train_dict, X_test_dict,y_test_dict = {}, {}, {}, {}

for key, df in spi_12_train_dict.items():
    X_train,y_train = to_sequences(sequence_size, df)
    X_train_dict[key] = X_train
    y_train_dict[key] = y_train

for key, df in spi_12_test_dict.items():
    X_test,y_test = to_sequences(sequence_size, df)
    X_test_dict[key] = X_test
    y_test_dict[key] = y_test

print("Dimensiones del training set: {}".format(X_train_dict[keys_names[0]].shape))
print("Dimensiones del test set: {}".format(X_test_dict[keys_names[0]].shape))
# Out:
# Dimensiones del training set: (836, 10, 1)
# Dimensiones del test set: (117, 10, 1)

# %% [markdown]
# # Definición del modelo

# %%
def create_model(n_nodes=20, optimizer='adam', activation='relu'):
    # Arquitectura del modelo
    model = Sequential()
    model.add(Dense(n_nodes, activation=activation, input_dim=X_train.shape[1]))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer=optimizer,metrics=['mse'])
    return model

#  Early stopping para evitar overfitting
es = EarlyStopping(monitor='val_loss', verbose=1, patience=3)

# %% [markdown]
# ### Grid search: búsqueda de mejores parámetros

# %%
# Transformación del modelo para aplicar grid search
model = KerasRegressor(model=create_model, epochs=100, batch_size=10, verbose=0, activation='relu', n_nodes=20)

# Parámetros de búsqueda
param_grid = {
    'n_nodes': [10,20, 50],
    'epochs': [50, 100],
    'batch_size' : [5,10,20],
    'optimizer' : ['SGD', 'adam'], 
    'activation' : ['relu', 'tanh']
}



# Se ignoran avisos de ejecución del grid search
warnings.simplefilter("ignore")

# Cálculo de grid search
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=8)
grid_result_dict = {}
for key in spi_12_train_dict.keys():
    grid_result_dict[key] = grid.fit(X_train_dict[key], y_train_dict[key], callbacks=[es], shuffle=False, validation_data=(
        X_test_dict[key], y_test_dict[key]))
    print(key)
    print("Best: %f using %s" % (grid_result_dict[key].best_score_, grid_result_dict[key].best_params_))
    print('')
# Out:
# Demarcación Hidrográfica de las Cuencas Mediterráneas Andaluzas
# Best: 0.848539 using {'activation': 'tanh', 'batch_size': 10, 'epochs': 100, 'n_nodes': 10, 'optimizer': 'SGD'}
#
# Cuenca hidrográfica del Guadalquivir
# Best: 0.873958 using {'activation': 'tanh', 'batch_size': 10, 'epochs': 100, 'n_nodes': 20, 'optimizer': 'SGD'}
#
# Cuenca hidrográfica del Guadiana
# Best: 0.872505 using {'activation': 'tanh', 'batch_size': 10, 'epochs': 100, 'n_nodes': 20, 'optimizer': 'adam'}
#
# Cuenca hidrográfica del Segura
# Best: 0.882638 using {'activation': 'relu', 'batch_size': 20, 'epochs': 100, 'n_nodes': 50, 'optimizer': 'SGD'}
#
# Demarcación Hidrográfica Guadalete-Barbate
# Best: 0.854614 using {'activation': 'relu', 'batch_size': 10, 'epochs': 100, 'n_nodes': 20, 'optimizer': 'SGD'}
#
# Demarcación Hidrográfica Tinto, Odiel y Piedras
# Best: 0.872343 using {'activation': 'tanh', 'batch_size': 10, 'epochs': 100, 'n_nodes': 20, 'optimizer': 'SGD'}

# %% [markdown]
# # Entrenamiento del modelo

# %%
model_history_dict = {}

for key in spi_12_train_dict.keys():
    model = create_model(grid_result_dict[key].best_params_['n_nodes'], grid_result_dict[key].best_params_[
                         'optimizer'], grid_result_dict[key].best_params_['activation'])

    model_history_dict[key] = model.fit(X_train_dict[key], y_train_dict[key], epochs=grid_result_dict[key].best_params_['epochs'],
        batch_size=grid_result_dict[key].best_params_['batch_size'],
        validation_data=(
        X_test_dict[key], y_test_dict[key]), verbose=2, shuffle=False, callbacks=[es]
        )
# Out:
# Epoch 1/100
# 84/84 - 0s - loss: 0.0631 - mse: 0.0631 - val_loss: 0.0558 - val_mse: 0.0558 - 472ms/epoch - 6ms/step
# Epoch 2/100
# 84/84 - 0s - loss: 0.0357 - mse: 0.0357 - val_loss: 0.0445 - val_mse: 0.0445 - 70ms/epoch - 834us/step
# Epoch 3/100
# 84/84 - 0s - loss: 0.0292 - mse: 0.0292 - val_loss: 0.0364 - val_mse: 0.0364 - 67ms/epoch - 798us/step
# Epoch 4/100
# 84/84 - 0s - loss: 0.0245 - mse: 0.0245 - val_loss: 0.0304 - val_mse: 0.0304 - 69ms/epoch - 822us/step
# Epoch 5/100
# 84/84 - 0s - loss: 0.0209 - mse: 0.0209 - val_loss: 0.0258 - val_mse: 0.0258 - 69ms/epoch - 822us/step
# Epoch 6/100
# 84/84 - 0s - loss: 0.0182 - mse: 0.0182 - val_loss: 0.0224 - val_mse: 0.0224 - 66ms/epoch - 786us/step
# Epoch 7/100
# 84/84 - 0s - loss: 0.0161 - mse: 0.0161 - val_loss: 0.0197 - val_mse: 0.0197 - 68ms/epoch - 810us/step
# Epoch 8/100
# 84/84 - 0s - loss: 0.0144 - mse: 0.0144 - val_loss: 0.0176 - val_mse: 0.0176 - 67ms/epoch - 798us/step
# Epoch 9/100
# 84/84 - 0s - loss: 0.0131 - mse: 0.0131 - val_loss: 0.0160 - val_mse: 0.0160 - 69ms/epoch - 822us/step
# Epoch 10/100
# 84/84 - 0s - loss: 0.0120 - mse: 0.0120 - val_loss: 0.0147 - val_mse: 0.0147 - 67ms/epoch - 798us/step
# Epoch 11/100
# 84/84 - 0s - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0136 - val_mse: 0.0136 - 66ms/epoch - 786us/step
# Epoch 12/100
# 84/84 - 0s - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0128 - val_mse: 0.0128 - 66ms/epoch - 786us/step
# Epoch 13/100
# 84/84 - 0s - loss: 0.0099 - mse: 0.0099 - val_loss: 0.0121 - val_mse: 0.0121 - 66ms/epoch - 786us/step
# Epoch 14/100
# 84/84 - 0s - loss: 0.0094 - mse: 0.0094 - val_loss: 0.0114 - val_mse: 0.0114 - 68ms/epoch - 810us/step
# Epoch 15/100
# 84/84 - 0s - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0109 - val_mse: 0.0109 - 67ms/epoch - 798us/step
# Epoch 16/100
# 84/84 - 0s - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0105 - val_mse: 0.0105 - 66ms/epoch - 786us/step
# Epoch 17/100
# 84/84 - 0s - loss: 0.0082 - mse: 0.0082 - val_loss: 0.0101 - val_mse: 0.0101 - 68ms/epoch - 810us/step
# Epoch 18/100
# 84/84 - 0s - loss: 0.0079 - mse: 0.0079 - val_loss: 0.0097 - val_mse: 0.0097 - 67ms/epoch - 798us/step
# Epoch 19/100
# 84/84 - 0s - loss: 0.0077 - mse: 0.0077 - val_loss: 0.0094 - val_mse: 0.0094 - 69ms/epoch - 822us/step
# Epoch 20/100
# 84/84 - 0s - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0091 - val_mse: 0.0091 - 68ms/epoch - 810us/step
# Epoch 21/100
# 84/84 - 0s - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0089 - val_mse: 0.0089 - 66ms/epoch - 786us/step
# Epoch 22/100
# 84/84 - 0s - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0086 - val_mse: 0.0086 - 67ms/epoch - 798us/step
# Epoch 23/100
# 84/84 - 0s - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0084 - val_mse: 0.0084 - 67ms/epoch - 798us/step
# Epoch 24/100
# 84/84 - 0s - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0082 - val_mse: 0.0082 - 67ms/epoch - 798us/step
# Epoch 25/100
# 84/84 - 0s - loss: 0.0065 - mse: 0.0065 - val_loss: 0.0080 - val_mse: 0.0080 - 67ms/epoch - 798us/step
# Epoch 26/100
# 84/84 - 0s - loss: 0.0064 - mse: 0.0064 - val_loss: 0.0079 - val_mse: 0.0079 - 66ms/epoch - 786us/step
# Epoch 27/100
# 84/84 - 0s - loss: 0.0063 - mse: 0.0063 - val_loss: 0.0077 - val_mse: 0.0077 - 67ms/epoch - 798us/step
# Epoch 28/100
# 84/84 - 0s - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0075 - val_mse: 0.0075 - 67ms/epoch - 798us/step
# Epoch 29/100
# 84/84 - 0s - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0074 - val_mse: 0.0074 - 66ms/epoch - 786us/step
# Epoch 30/100
# 84/84 - 0s - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0072 - val_mse: 0.0072 - 65ms/epoch - 774us/step
# Epoch 31/100
# 84/84 - 0s - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0071 - val_mse: 0.0071 - 67ms/epoch - 798us/step
# Epoch 32/100
# 84/84 - 0s - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0070 - val_mse: 0.0070 - 67ms/epoch - 798us/step
# Epoch 33/100
# 84/84 - 0s - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0069 - val_mse: 0.0069 - 65ms/epoch - 774us/step
# Epoch 34/100
# 84/84 - 0s - loss: 0.0055 - mse: 0.0055 - val_loss: 0.0068 - val_mse: 0.0068 - 65ms/epoch - 774us/step
# Epoch 35/100
# 84/84 - 0s - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0066 - val_mse: 0.0066 - 66ms/epoch - 786us/step
# Epoch 36/100
# 84/84 - 0s - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0066 - val_mse: 0.0066 - 64ms/epoch - 762us/step
# Epoch 37/100
# 84/84 - 0s - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0065 - val_mse: 0.0065 - 66ms/epoch - 786us/step
# Epoch 38/100
# 84/84 - 0s - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0064 - val_mse: 0.0064 - 65ms/epoch - 774us/step
# Epoch 39/100
# 84/84 - 0s - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0063 - val_mse: 0.0063 - 66ms/epoch - 786us/step
# Epoch 40/100
# 84/84 - 0s - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0062 - val_mse: 0.0062 - 66ms/epoch - 786us/step
# Epoch 41/100
# 84/84 - 0s - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0061 - val_mse: 0.0061 - 65ms/epoch - 774us/step
# Epoch 42/100
# 84/84 - 0s - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0061 - val_mse: 0.0061 - 66ms/epoch - 786us/step
# Epoch 43/100
# 84/84 - 0s - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0060 - val_mse: 0.0060 - 67ms/epoch - 798us/step
# Epoch 44/100
# 84/84 - 0s - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0059 - val_mse: 0.0059 - 65ms/epoch - 774us/step
# Epoch 45/100
# 84/84 - 0s - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0059 - val_mse: 0.0059 - 66ms/epoch - 786us/step
# Epoch 46/100
# 84/84 - 0s - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0058 - val_mse: 0.0058 - 65ms/epoch - 774us/step
# Epoch 47/100
# 84/84 - 0s - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0058 - val_mse: 0.0058 - 66ms/epoch - 786us/step
# Epoch 48/100
# 84/84 - 0s - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0057 - val_mse: 0.0057 - 68ms/epoch - 810us/step
# Epoch 49/100
# 84/84 - 0s - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0057 - val_mse: 0.0057 - 66ms/epoch - 786us/step
# Epoch 50/100
# 84/84 - 0s - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0056 - val_mse: 0.0056 - 66ms/epoch - 786us/step
# Epoch 51/100
# 84/84 - 0s - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0056 - val_mse: 0.0056 - 66ms/epoch - 786us/step
# Epoch 52/100
# 84/84 - 0s - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0055 - val_mse: 0.0055 - 67ms/epoch - 798us/step
# Epoch 53/100
# 84/84 - 0s - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0055 - val_mse: 0.0055 - 69ms/epoch - 822us/step
# Epoch 54/100
# 84/84 - 0s - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0054 - val_mse: 0.0054 - 68ms/epoch - 810us/step
# Epoch 55/100
# 84/84 - 0s - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0054 - val_mse: 0.0054 - 67ms/epoch - 798us/step
# Epoch 56/100
# 84/84 - 0s - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0054 - val_mse: 0.0054 - 66ms/epoch - 786us/step
# Epoch 57/100
# 84/84 - 0s - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0053 - val_mse: 0.0053 - 65ms/epoch - 774us/step
# Epoch 58/100
# 84/84 - 0s - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0053 - val_mse: 0.0053 - 65ms/epoch - 774us/step
# Epoch 59/100
# 84/84 - 0s - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0053 - val_mse: 0.0053 - 65ms/epoch - 774us/step
# Epoch 60/100
# 84/84 - 0s - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0052 - val_mse: 0.0052 - 66ms/epoch - 786us/step
# Epoch 61/100
# 84/84 - 0s - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0052 - val_mse: 0.0052 - 65ms/epoch - 774us/step
# Epoch 62/100
# 84/84 - 0s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0052 - val_mse: 0.0052 - 64ms/epoch - 762us/step
# Epoch 63/100
# 84/84 - 0s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0052 - val_mse: 0.0052 - 66ms/epoch - 786us/step
# Epoch 64/100
# 84/84 - 0s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0051 - val_mse: 0.0051 - 66ms/epoch - 786us/step
# Epoch 65/100
# 84/84 - 0s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0051 - val_mse: 0.0051 - 67ms/epoch - 798us/step
# Epoch 66/100
# 84/84 - 0s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0051 - val_mse: 0.0051 - 65ms/epoch - 774us/step
# Epoch 67/100
# 84/84 - 0s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0051 - val_mse: 0.0051 - 65ms/epoch - 774us/step
# Epoch 68/100
# 84/84 - 0s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0051 - val_mse: 0.0051 - 65ms/epoch - 774us/step
# Epoch 69/100
# 84/84 - 0s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0050 - val_mse: 0.0050 - 66ms/epoch - 786us/step
# Epoch 70/100
# 84/84 - 0s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0050 - val_mse: 0.0050 - 65ms/epoch - 774us/step
# Epoch 71/100
# 84/84 - 0s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0050 - val_mse: 0.0050 - 66ms/epoch - 786us/step
# Epoch 72/100
# 84/84 - 0s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0050 - val_mse: 0.0050 - 64ms/epoch - 762us/step
# Epoch 73/100
# 84/84 - 0s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0050 - val_mse: 0.0050 - 64ms/epoch - 762us/step
# Epoch 74/100
# 84/84 - 0s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0049 - val_mse: 0.0049 - 65ms/epoch - 774us/step
# Epoch 75/100
# 84/84 - 0s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0049 - val_mse: 0.0049 - 67ms/epoch - 798us/step
# Epoch 76/100
# 84/84 - 0s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0049 - val_mse: 0.0049 - 66ms/epoch - 786us/step
# Epoch 77/100
# 84/84 - 0s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0049 - val_mse: 0.0049 - 66ms/epoch - 786us/step
# Epoch 78/100
# 84/84 - 0s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0049 - val_mse: 0.0049 - 64ms/epoch - 762us/step
# Epoch 79/100
# 84/84 - 0s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0049 - val_mse: 0.0049 - 66ms/epoch - 786us/step
# Epoch 80/100
# 84/84 - 0s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0049 - val_mse: 0.0049 - 66ms/epoch - 786us/step
# Epoch 81/100
# 84/84 - 0s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0048 - val_mse: 0.0048 - 66ms/epoch - 786us/step
# Epoch 82/100
# 84/84 - 0s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0048 - val_mse: 0.0048 - 66ms/epoch - 786us/step
# Epoch 83/100
# 84/84 - 0s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0048 - val_mse: 0.0048 - 65ms/epoch - 774us/step
# Epoch 84/100
# 84/84 - 0s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0048 - val_mse: 0.0048 - 65ms/epoch - 774us/step
# Epoch 85/100
# 84/84 - 0s - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0048 - val_mse: 0.0048 - 66ms/epoch - 786us/step
# Epoch 86/100
# 84/84 - 0s - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0048 - val_mse: 0.0048 - 65ms/epoch - 774us/step
# Epoch 87/100
# 84/84 - 0s - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0048 - val_mse: 0.0048 - 66ms/epoch - 786us/step
# Epoch 88/100
# 84/84 - 0s - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0048 - val_mse: 0.0048 - 67ms/epoch - 798us/step
# Epoch 89/100
# 84/84 - 0s - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0048 - val_mse: 0.0048 - 65ms/epoch - 774us/step
# Epoch 90/100
# 84/84 - 0s - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0048 - val_mse: 0.0048 - 65ms/epoch - 774us/step
# Epoch 91/100
# 84/84 - 0s - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0047 - val_mse: 0.0047 - 65ms/epoch - 774us/step
# Epoch 92/100
# 84/84 - 0s - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0047 - val_mse: 0.0047 - 64ms/epoch - 762us/step
# Epoch 93/100
# 84/84 - 0s - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0047 - val_mse: 0.0047 - 66ms/epoch - 786us/step
# Epoch 94/100
# 84/84 - 0s - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0047 - val_mse: 0.0047 - 65ms/epoch - 774us/step
# Epoch 95/100
# 84/84 - 0s - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0047 - val_mse: 0.0047 - 66ms/epoch - 786us/step
# Epoch 96/100
# 84/84 - 0s - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0047 - val_mse: 0.0047 - 65ms/epoch - 774us/step
# Epoch 97/100
# 84/84 - 0s - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0047 - val_mse: 0.0047 - 65ms/epoch - 774us/step
# Epoch 98/100
# 84/84 - 0s - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0047 - val_mse: 0.0047 - 65ms/epoch - 774us/step
# Epoch 99/100
# 84/84 - 0s - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0047 - val_mse: 0.0047 - 66ms/epoch - 786us/step
# Epoch 100/100
# 84/84 - 0s - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0047 - val_mse: 0.0047 - 65ms/epoch - 774us/step
# Epoch 1/100
# 84/84 - 0s - loss: 0.0138 - mse: 0.0138 - val_loss: 0.0142 - val_mse: 0.0142 - 327ms/epoch - 4ms/step
# Epoch 2/100
# 84/84 - 0s - loss: 0.0101 - mse: 0.0101 - val_loss: 0.0120 - val_mse: 0.0120 - 69ms/epoch - 822us/step
# Epoch 3/100
# 84/84 - 0s - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0105 - val_mse: 0.0105 - 68ms/epoch - 810us/step
# Epoch 4/100
# 84/84 - 0s - loss: 0.0077 - mse: 0.0077 - val_loss: 0.0094 - val_mse: 0.0094 - 69ms/epoch - 822us/step
# Epoch 5/100
# 84/84 - 0s - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0087 - val_mse: 0.0087 - 67ms/epoch - 798us/step
# Epoch 6/100
# 84/84 - 0s - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0082 - val_mse: 0.0082 - 67ms/epoch - 798us/step
# Epoch 7/100
# 84/84 - 0s - loss: 0.0064 - mse: 0.0064 - val_loss: 0.0078 - val_mse: 0.0078 - 68ms/epoch - 810us/step
# Epoch 8/100
# 84/84 - 0s - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0075 - val_mse: 0.0075 - 68ms/epoch - 810us/step
# Epoch 9/100
# 84/84 - 0s - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0073 - val_mse: 0.0073 - 66ms/epoch - 786us/step
# Epoch 10/100
# 84/84 - 0s - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0071 - val_mse: 0.0071 - 67ms/epoch - 798us/step
# Epoch 11/100
# 84/84 - 0s - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0070 - val_mse: 0.0070 - 65ms/epoch - 774us/step
# Epoch 12/100
# 84/84 - 0s - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0068 - val_mse: 0.0068 - 65ms/epoch - 774us/step
# Epoch 13/100
# 84/84 - 0s - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0067 - val_mse: 0.0067 - 65ms/epoch - 774us/step
# Epoch 14/100
# 84/84 - 0s - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0066 - val_mse: 0.0066 - 65ms/epoch - 774us/step
# Epoch 15/100
# 84/84 - 0s - loss: 0.0055 - mse: 0.0055 - val_loss: 0.0066 - val_mse: 0.0066 - 68ms/epoch - 810us/step
# Epoch 16/100
# 84/84 - 0s - loss: 0.0055 - mse: 0.0055 - val_loss: 0.0065 - val_mse: 0.0065 - 65ms/epoch - 774us/step
# Epoch 17/100
# 84/84 - 0s - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0064 - val_mse: 0.0064 - 66ms/epoch - 786us/step
# Epoch 18/100
# 84/84 - 0s - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0064 - val_mse: 0.0064 - 65ms/epoch - 774us/step
# Epoch 19/100
# 84/84 - 0s - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0063 - val_mse: 0.0063 - 65ms/epoch - 774us/step
# Epoch 20/100
# 84/84 - 0s - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0062 - val_mse: 0.0062 - 65ms/epoch - 774us/step
# Epoch 21/100
# 84/84 - 0s - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0062 - val_mse: 0.0062 - 66ms/epoch - 786us/step
# Epoch 22/100
# 84/84 - 0s - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0061 - val_mse: 0.0061 - 66ms/epoch - 786us/step
# Epoch 23/100
# 84/84 - 0s - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0061 - val_mse: 0.0061 - 65ms/epoch - 774us/step
# Epoch 24/100
# 84/84 - 0s - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0060 - val_mse: 0.0060 - 65ms/epoch - 774us/step
# Epoch 25/100
# 84/84 - 0s - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0060 - val_mse: 0.0060 - 67ms/epoch - 798us/step
# Epoch 26/100
# 84/84 - 0s - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0059 - val_mse: 0.0059 - 65ms/epoch - 774us/step
# Epoch 27/100
# 84/84 - 0s - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0059 - val_mse: 0.0059 - 65ms/epoch - 774us/step
# Epoch 28/100
# 84/84 - 0s - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0059 - val_mse: 0.0059 - 64ms/epoch - 762us/step
# Epoch 29/100
# 84/84 - 0s - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0058 - val_mse: 0.0058 - 65ms/epoch - 774us/step
# Epoch 30/100
# 84/84 - 0s - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0058 - val_mse: 0.0058 - 65ms/epoch - 774us/step
# Epoch 31/100
# 84/84 - 0s - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0058 - val_mse: 0.0058 - 65ms/epoch - 774us/step
# Epoch 32/100
# 84/84 - 0s - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0057 - val_mse: 0.0057 - 65ms/epoch - 774us/step
# Epoch 33/100
# 84/84 - 0s - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0057 - val_mse: 0.0057 - 66ms/epoch - 786us/step
# Epoch 34/100
# 84/84 - 0s - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0057 - val_mse: 0.0057 - 65ms/epoch - 774us/step
# Epoch 35/100
# 84/84 - 0s - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0056 - val_mse: 0.0056 - 67ms/epoch - 798us/step
# Epoch 36/100
# 84/84 - 0s - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0056 - val_mse: 0.0056 - 66ms/epoch - 786us/step
# Epoch 37/100
# 84/84 - 0s - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0056 - val_mse: 0.0056 - 66ms/epoch - 786us/step
# Epoch 38/100
# 84/84 - 0s - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0055 - val_mse: 0.0055 - 66ms/epoch - 786us/step
# Epoch 39/100
# 84/84 - 0s - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0055 - val_mse: 0.0055 - 67ms/epoch - 798us/step
# Epoch 40/100
# 84/84 - 0s - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0055 - val_mse: 0.0055 - 67ms/epoch - 798us/step
# Epoch 41/100
# 84/84 - 0s - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0055 - val_mse: 0.0055 - 65ms/epoch - 774us/step
# Epoch 42/100
# 84/84 - 0s - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0054 - val_mse: 0.0054 - 65ms/epoch - 774us/step
# Epoch 43/100
# 84/84 - 0s - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0054 - val_mse: 0.0054 - 65ms/epoch - 774us/step
# Epoch 44/100
# 84/84 - 0s - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0054 - val_mse: 0.0054 - 66ms/epoch - 786us/step
# Epoch 45/100
# 84/84 - 0s - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0054 - val_mse: 0.0054 - 65ms/epoch - 774us/step
# Epoch 46/100
# 84/84 - 0s - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0053 - val_mse: 0.0053 - 66ms/epoch - 786us/step
# Epoch 47/100
# 84/84 - 0s - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0053 - val_mse: 0.0053 - 66ms/epoch - 786us/step
# Epoch 48/100
# 84/84 - 0s - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0053 - val_mse: 0.0053 - 67ms/epoch - 798us/step
# Epoch 49/100
# 84/84 - 0s - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0053 - val_mse: 0.0053 - 67ms/epoch - 798us/step
# Epoch 50/100
# 84/84 - 0s - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0053 - val_mse: 0.0053 - 66ms/epoch - 786us/step
# Epoch 51/100
# 84/84 - 0s - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052 - 66ms/epoch - 786us/step
# Epoch 52/100
# 84/84 - 0s - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052 - 66ms/epoch - 786us/step
# Epoch 53/100
# 84/84 - 0s - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052 - 65ms/epoch - 774us/step
# Epoch 54/100
# 84/84 - 0s - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0052 - val_mse: 0.0052 - 66ms/epoch - 786us/step
# Epoch 55/100
# 84/84 - 0s - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0052 - val_mse: 0.0052 - 66ms/epoch - 786us/step
# Epoch 56/100
# 84/84 - 0s - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0052 - val_mse: 0.0052 - 66ms/epoch - 786us/step
# Epoch 57/100
# 84/84 - 0s - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0051 - val_mse: 0.0051 - 66ms/epoch - 786us/step
# Epoch 58/100
# 84/84 - 0s - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0051 - val_mse: 0.0051 - 65ms/epoch - 774us/step
# Epoch 59/100
# 84/84 - 0s - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0051 - val_mse: 0.0051 - 65ms/epoch - 774us/step
# Epoch 60/100
# 84/84 - 0s - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0051 - val_mse: 0.0051 - 67ms/epoch - 798us/step
# Epoch 61/100
# 84/84 - 0s - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0051 - val_mse: 0.0051 - 66ms/epoch - 786us/step
# Epoch 62/100
# 84/84 - 0s - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0051 - val_mse: 0.0051 - 65ms/epoch - 774us/step
# Epoch 63/100
# 84/84 - 0s - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0050 - val_mse: 0.0050 - 66ms/epoch - 786us/step
# Epoch 64/100
# 84/84 - 0s - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0050 - val_mse: 0.0050 - 67ms/epoch - 798us/step
# Epoch 65/100
# 84/84 - 0s - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0050 - val_mse: 0.0050 - 66ms/epoch - 786us/step
# Epoch 66/100
# 84/84 - 0s - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0050 - val_mse: 0.0050 - 66ms/epoch - 786us/step
# Epoch 67/100
# 84/84 - 0s - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0050 - val_mse: 0.0050 - 66ms/epoch - 786us/step
# Epoch 68/100
# 84/84 - 0s - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0050 - val_mse: 0.0050 - 66ms/epoch - 786us/step
# Epoch 69/100
# 84/84 - 0s - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0050 - val_mse: 0.0050 - 65ms/epoch - 774us/step
# Epoch 70/100
# 84/84 - 0s - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0049 - val_mse: 0.0049 - 67ms/epoch - 798us/step
# Epoch 71/100
# 84/84 - 0s - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0049 - val_mse: 0.0049 - 66ms/epoch - 786us/step
# Epoch 72/100
# 84/84 - 0s - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0049 - val_mse: 0.0049 - 65ms/epoch - 774us/step
# Epoch 73/100
# 84/84 - 0s - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0049 - val_mse: 0.0049 - 67ms/epoch - 798us/step
# Epoch 74/100
# 84/84 - 0s - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0049 - val_mse: 0.0049 - 66ms/epoch - 786us/step
# Epoch 75/100
# 84/84 - 0s - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0049 - val_mse: 0.0049 - 66ms/epoch - 786us/step
# Epoch 76/100
# 84/84 - 0s - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0049 - val_mse: 0.0049 - 67ms/epoch - 798us/step
# Epoch 77/100
# 84/84 - 0s - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0049 - val_mse: 0.0049 - 67ms/epoch - 798us/step
# Epoch 78/100
# 84/84 - 0s - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0049 - val_mse: 0.0049 - 65ms/epoch - 774us/step
# Epoch 79/100
# 84/84 - 0s - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0048 - val_mse: 0.0048 - 66ms/epoch - 786us/step
# Epoch 80/100
# 84/84 - 0s - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0048 - val_mse: 0.0048 - 67ms/epoch - 798us/step
# Epoch 81/100
# 84/84 - 0s - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0048 - val_mse: 0.0048 - 65ms/epoch - 774us/step
# Epoch 82/100
# 84/84 - 0s - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0048 - val_mse: 0.0048 - 68ms/epoch - 810us/step
# Epoch 83/100
# 84/84 - 0s - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0048 - val_mse: 0.0048 - 66ms/epoch - 786us/step
# Epoch 84/100
# 84/84 - 0s - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0048 - val_mse: 0.0048 - 66ms/epoch - 786us/step
# Epoch 85/100
# 84/84 - 0s - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0048 - val_mse: 0.0048 - 66ms/epoch - 786us/step
# Epoch 86/100
# 84/84 - 0s - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0048 - val_mse: 0.0048 - 66ms/epoch - 786us/step
# Epoch 87/100
# 84/84 - 0s - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0048 - val_mse: 0.0048 - 65ms/epoch - 775us/step
# Epoch 88/100
# 84/84 - 0s - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0047 - val_mse: 0.0047 - 66ms/epoch - 786us/step
# Epoch 89/100
# 84/84 - 0s - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0047 - val_mse: 0.0047 - 65ms/epoch - 774us/step
# Epoch 90/100
# 84/84 - 0s - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0047 - val_mse: 0.0047 - 65ms/epoch - 774us/step
# Epoch 91/100
# 84/84 - 0s - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0047 - val_mse: 0.0047 - 65ms/epoch - 774us/step
# Epoch 92/100
# 84/84 - 0s - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0047 - val_mse: 0.0047 - 67ms/epoch - 798us/step
# Epoch 93/100
# 84/84 - 0s - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0047 - val_mse: 0.0047 - 66ms/epoch - 786us/step
# Epoch 94/100
# 84/84 - 0s - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0047 - val_mse: 0.0047 - 65ms/epoch - 774us/step
# Epoch 95/100
# 84/84 - 0s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0047 - val_mse: 0.0047 - 66ms/epoch - 786us/step
# Epoch 96/100
# 84/84 - 0s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0047 - val_mse: 0.0047 - 65ms/epoch - 774us/step
# Epoch 97/100
# 84/84 - 0s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0047 - val_mse: 0.0047 - 66ms/epoch - 786us/step
# Epoch 98/100
# 84/84 - 0s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0047 - val_mse: 0.0047 - 66ms/epoch - 786us/step
# Epoch 99/100
# 84/84 - 0s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0047 - val_mse: 0.0047 - 65ms/epoch - 774us/step
# Epoch 100/100
# 84/84 - 0s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0046 - val_mse: 0.0046 - 67ms/epoch - 798us/step
# Epoch 1/100
# 84/84 - 0s - loss: 0.0280 - mse: 0.0280 - val_loss: 0.0247 - val_mse: 0.0247 - 328ms/epoch - 4ms/step
# Epoch 2/100
# 84/84 - 0s - loss: 0.0213 - mse: 0.0213 - val_loss: 0.0189 - val_mse: 0.0189 - 69ms/epoch - 822us/step
# Epoch 3/100
# 84/84 - 0s - loss: 0.0174 - mse: 0.0174 - val_loss: 0.0155 - val_mse: 0.0155 - 69ms/epoch - 822us/step
# Epoch 4/100
# 84/84 - 0s - loss: 0.0151 - mse: 0.0151 - val_loss: 0.0135 - val_mse: 0.0135 - 69ms/epoch - 822us/step
# Epoch 5/100
# 84/84 - 0s - loss: 0.0137 - mse: 0.0137 - val_loss: 0.0122 - val_mse: 0.0122 - 67ms/epoch - 798us/step
# Epoch 6/100
# 84/84 - 0s - loss: 0.0127 - mse: 0.0127 - val_loss: 0.0113 - val_mse: 0.0113 - 68ms/epoch - 810us/step
# Epoch 7/100
# 84/84 - 0s - loss: 0.0119 - mse: 0.0119 - val_loss: 0.0107 - val_mse: 0.0107 - 69ms/epoch - 822us/step
# Epoch 8/100
# 84/84 - 0s - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0102 - val_mse: 0.0102 - 68ms/epoch - 810us/step
# Epoch 9/100
# 84/84 - 0s - loss: 0.0109 - mse: 0.0109 - val_loss: 0.0098 - val_mse: 0.0098 - 69ms/epoch - 822us/step
# Epoch 10/100
# 84/84 - 0s - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0095 - val_mse: 0.0095 - 67ms/epoch - 798us/step
# Epoch 11/100
# 84/84 - 0s - loss: 0.0102 - mse: 0.0102 - val_loss: 0.0092 - val_mse: 0.0092 - 68ms/epoch - 810us/step
# Epoch 12/100
# 84/84 - 0s - loss: 0.0099 - mse: 0.0099 - val_loss: 0.0089 - val_mse: 0.0089 - 68ms/epoch - 810us/step
# Epoch 13/100
# 84/84 - 0s - loss: 0.0096 - mse: 0.0096 - val_loss: 0.0087 - val_mse: 0.0087 - 68ms/epoch - 810us/step
# Epoch 14/100
# 84/84 - 0s - loss: 0.0094 - mse: 0.0094 - val_loss: 0.0085 - val_mse: 0.0085 - 68ms/epoch - 810us/step
# Epoch 15/100
# 84/84 - 0s - loss: 0.0091 - mse: 0.0091 - val_loss: 0.0083 - val_mse: 0.0083 - 68ms/epoch - 810us/step
# Epoch 16/100
# 84/84 - 0s - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0081 - val_mse: 0.0081 - 66ms/epoch - 786us/step
# Epoch 17/100
# 84/84 - 0s - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0079 - val_mse: 0.0079 - 68ms/epoch - 810us/step
# Epoch 18/100
# 84/84 - 0s - loss: 0.0085 - mse: 0.0085 - val_loss: 0.0077 - val_mse: 0.0077 - 69ms/epoch - 822us/step
# Epoch 19/100
# 84/84 - 0s - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0075 - val_mse: 0.0075 - 68ms/epoch - 810us/step
# Epoch 20/100
# 84/84 - 0s - loss: 0.0081 - mse: 0.0081 - val_loss: 0.0074 - val_mse: 0.0074 - 69ms/epoch - 822us/step
# Epoch 21/100
# 84/84 - 0s - loss: 0.0079 - mse: 0.0079 - val_loss: 0.0072 - val_mse: 0.0072 - 67ms/epoch - 798us/step
# Epoch 22/100
# 84/84 - 0s - loss: 0.0078 - mse: 0.0078 - val_loss: 0.0071 - val_mse: 0.0071 - 74ms/epoch - 881us/step
# Epoch 23/100
# 84/84 - 0s - loss: 0.0076 - mse: 0.0076 - val_loss: 0.0070 - val_mse: 0.0070 - 68ms/epoch - 810us/step
# Epoch 24/100
# 84/84 - 0s - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0068 - val_mse: 0.0068 - 69ms/epoch - 822us/step
# Epoch 25/100
# 84/84 - 0s - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0067 - val_mse: 0.0067 - 68ms/epoch - 810us/step
# Epoch 26/100
# 84/84 - 0s - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0066 - val_mse: 0.0066 - 68ms/epoch - 810us/step
# Epoch 27/100
# 84/84 - 0s - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0065 - val_mse: 0.0065 - 68ms/epoch - 810us/step
# Epoch 28/100
# 84/84 - 0s - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0064 - val_mse: 0.0064 - 68ms/epoch - 810us/step
# Epoch 29/100
# 84/84 - 0s - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0063 - val_mse: 0.0063 - 67ms/epoch - 798us/step
# Epoch 30/100
# 84/84 - 0s - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0062 - val_mse: 0.0062 - 68ms/epoch - 810us/step
# Epoch 31/100
# 84/84 - 0s - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0061 - val_mse: 0.0061 - 69ms/epoch - 822us/step
# Epoch 32/100
# 84/84 - 0s - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0061 - val_mse: 0.0061 - 69ms/epoch - 822us/step
# Epoch 33/100
# 84/84 - 0s - loss: 0.0065 - mse: 0.0065 - val_loss: 0.0060 - val_mse: 0.0060 - 67ms/epoch - 798us/step
# Epoch 34/100
# 84/84 - 0s - loss: 0.0064 - mse: 0.0064 - val_loss: 0.0059 - val_mse: 0.0059 - 67ms/epoch - 798us/step
# Epoch 35/100
# 84/84 - 0s - loss: 0.0063 - mse: 0.0063 - val_loss: 0.0058 - val_mse: 0.0058 - 68ms/epoch - 810us/step
# Epoch 36/100
# 84/84 - 0s - loss: 0.0063 - mse: 0.0063 - val_loss: 0.0058 - val_mse: 0.0058 - 67ms/epoch - 798us/step
# Epoch 37/100
# 84/84 - 0s - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0057 - val_mse: 0.0057 - 69ms/epoch - 817us/step
# Epoch 38/100
# 84/84 - 0s - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0056 - val_mse: 0.0056 - 68ms/epoch - 810us/step
# Epoch 39/100
# 84/84 - 0s - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0056 - val_mse: 0.0056 - 68ms/epoch - 810us/step
# Epoch 40/100
# 84/84 - 0s - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0055 - val_mse: 0.0055 - 68ms/epoch - 810us/step
# Epoch 41/100
# 84/84 - 0s - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0055 - val_mse: 0.0055 - 68ms/epoch - 810us/step
# Epoch 42/100
# 84/84 - 0s - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0054 - val_mse: 0.0054 - 68ms/epoch - 810us/step
# Epoch 43/100
# 84/84 - 0s - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0054 - val_mse: 0.0054 - 69ms/epoch - 822us/step
# Epoch 44/100
# 84/84 - 0s - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0053 - val_mse: 0.0053 - 68ms/epoch - 810us/step
# Epoch 45/100
# 84/84 - 0s - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0053 - val_mse: 0.0053 - 68ms/epoch - 810us/step
# Epoch 46/100
# 84/84 - 0s - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0052 - val_mse: 0.0052 - 68ms/epoch - 810us/step
# Epoch 47/100
# 84/84 - 0s - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0052 - val_mse: 0.0052 - 68ms/epoch - 810us/step
# Epoch 48/100
# 84/84 - 0s - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0052 - val_mse: 0.0052 - 67ms/epoch - 798us/step
# Epoch 49/100
# 84/84 - 0s - loss: 0.0055 - mse: 0.0055 - val_loss: 0.0051 - val_mse: 0.0051 - 68ms/epoch - 810us/step
# Epoch 50/100
# 84/84 - 0s - loss: 0.0055 - mse: 0.0055 - val_loss: 0.0051 - val_mse: 0.0051 - 68ms/epoch - 810us/step
# Epoch 51/100
# 84/84 - 0s - loss: 0.0055 - mse: 0.0055 - val_loss: 0.0051 - val_mse: 0.0051 - 69ms/epoch - 822us/step
# Epoch 52/100
# 84/84 - 0s - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0050 - val_mse: 0.0050 - 70ms/epoch - 834us/step
# Epoch 53/100
# 84/84 - 0s - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0050 - val_mse: 0.0050 - 68ms/epoch - 810us/step
# Epoch 54/100
# 84/84 - 0s - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0050 - val_mse: 0.0050 - 68ms/epoch - 810us/step
# Epoch 55/100
# 84/84 - 0s - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0049 - val_mse: 0.0049 - 69ms/epoch - 822us/step
# Epoch 56/100
# 84/84 - 0s - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0049 - val_mse: 0.0049 - 69ms/epoch - 822us/step
# Epoch 57/100
# 84/84 - 0s - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0049 - val_mse: 0.0049 - 67ms/epoch - 798us/step
# Epoch 58/100
# 84/84 - 0s - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0049 - val_mse: 0.0049 - 68ms/epoch - 810us/step
# Epoch 59/100
# 84/84 - 0s - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0048 - val_mse: 0.0048 - 68ms/epoch - 810us/step
# Epoch 60/100
# 84/84 - 0s - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0048 - val_mse: 0.0048 - 68ms/epoch - 810us/step
# Epoch 61/100
# 84/84 - 0s - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0048 - val_mse: 0.0048 - 67ms/epoch - 798us/step
# Epoch 62/100
# 84/84 - 0s - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0048 - val_mse: 0.0048 - 68ms/epoch - 810us/step
# Epoch 63/100
# 84/84 - 0s - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0047 - val_mse: 0.0047 - 70ms/epoch - 834us/step
# Epoch 64/100
# 84/84 - 0s - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0047 - val_mse: 0.0047 - 68ms/epoch - 810us/step
# Epoch 65/100
# 84/84 - 0s - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0047 - val_mse: 0.0047 - 69ms/epoch - 822us/step
# Epoch 66/100
# 84/84 - 0s - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0047 - val_mse: 0.0047 - 69ms/epoch - 822us/step
# Epoch 67/100
# 84/84 - 0s - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0047 - val_mse: 0.0047 - 69ms/epoch - 822us/step
# Epoch 68/100
# 84/84 - 0s - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0046 - val_mse: 0.0046 - 68ms/epoch - 810us/step
# Epoch 69/100
# 84/84 - 0s - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0046 - val_mse: 0.0046 - 68ms/epoch - 810us/step
# Epoch 70/100
# 84/84 - 0s - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0046 - val_mse: 0.0046 - 67ms/epoch - 798us/step
# Epoch 71/100
# 84/84 - 0s - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0046 - val_mse: 0.0046 - 68ms/epoch - 810us/step
# Epoch 72/100
# 84/84 - 0s - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0046 - val_mse: 0.0046 - 68ms/epoch - 810us/step
# Epoch 73/100
# 84/84 - 0s - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0046 - val_mse: 0.0046 - 68ms/epoch - 810us/step
# Epoch 74/100
# 84/84 - 0s - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0045 - val_mse: 0.0045 - 67ms/epoch - 798us/step
# Epoch 75/100
# 84/84 - 0s - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0045 - val_mse: 0.0045 - 73ms/epoch - 869us/step
# Epoch 76/100
# 84/84 - 0s - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0045 - val_mse: 0.0045 - 68ms/epoch - 810us/step
# Epoch 77/100
# 84/84 - 0s - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0045 - val_mse: 0.0045 - 68ms/epoch - 810us/step
# Epoch 78/100
# 84/84 - 0s - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0045 - val_mse: 0.0045 - 70ms/epoch - 834us/step
# Epoch 79/100
# 84/84 - 0s - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0045 - val_mse: 0.0045 - 68ms/epoch - 810us/step
# Epoch 80/100
# 84/84 - 0s - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0045 - val_mse: 0.0045 - 67ms/epoch - 798us/step
# Epoch 81/100
# 84/84 - 0s - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0045 - val_mse: 0.0045 - 70ms/epoch - 834us/step
# Epoch 82/100
# 84/84 - 0s - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0044 - val_mse: 0.0044 - 69ms/epoch - 822us/step
# Epoch 83/100
# 84/84 - 0s - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0044 - val_mse: 0.0044 - 67ms/epoch - 798us/step
# Epoch 84/100
# 84/84 - 0s - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0044 - val_mse: 0.0044 - 69ms/epoch - 822us/step
# Epoch 85/100
# 84/84 - 0s - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0044 - val_mse: 0.0044 - 67ms/epoch - 798us/step
# Epoch 86/100
# 84/84 - 0s - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0044 - val_mse: 0.0044 - 75ms/epoch - 893us/step
# Epoch 87/100
# 84/84 - 0s - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0044 - val_mse: 0.0044 - 68ms/epoch - 810us/step
# Epoch 88/100
# 84/84 - 0s - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0044 - val_mse: 0.0044 - 67ms/epoch - 798us/step
# Epoch 89/100
# 84/84 - 0s - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0044 - val_mse: 0.0044 - 68ms/epoch - 810us/step
# Epoch 90/100
# 84/84 - 0s - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0044 - val_mse: 0.0044 - 66ms/epoch - 791us/step
# Epoch 91/100
# 84/84 - 0s - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0044 - val_mse: 0.0044 - 67ms/epoch - 798us/step
# Epoch 92/100
# 84/84 - 0s - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0043 - val_mse: 0.0043 - 67ms/epoch - 798us/step
# Epoch 93/100
# 84/84 - 0s - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0043 - val_mse: 0.0043 - 68ms/epoch - 810us/step
# Epoch 94/100
# 84/84 - 0s - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0043 - val_mse: 0.0043 - 68ms/epoch - 810us/step
# Epoch 95/100
# 84/84 - 0s - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0043 - val_mse: 0.0043 - 69ms/epoch - 822us/step
# Epoch 96/100
# 84/84 - 0s - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0043 - val_mse: 0.0043 - 68ms/epoch - 810us/step
# Epoch 97/100
# 84/84 - 0s - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0043 - val_mse: 0.0043 - 67ms/epoch - 798us/step
# Epoch 98/100
# 84/84 - 0s - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0043 - val_mse: 0.0043 - 69ms/epoch - 822us/step
# Epoch 99/100
# 84/84 - 0s - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0043 - val_mse: 0.0043 - 67ms/epoch - 798us/step
# Epoch 100/100
# 84/84 - 0s - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0043 - val_mse: 0.0043 - 68ms/epoch - 810us/step
# Epoch 1/100
# 84/84 - 0s - loss: 0.1019 - mse: 0.1019 - val_loss: 0.0353 - val_mse: 0.0353 - 328ms/epoch - 4ms/step
# Epoch 2/100
# 84/84 - 0s - loss: 0.0172 - mse: 0.0172 - val_loss: 0.0215 - val_mse: 0.0215 - 69ms/epoch - 822us/step
# Epoch 3/100
# 84/84 - 0s - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0147 - val_mse: 0.0147 - 69ms/epoch - 822us/step
# Epoch 4/100
# 84/84 - 0s - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0112 - val_mse: 0.0112 - 69ms/epoch - 822us/step
# Epoch 5/100
# 84/84 - 0s - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0093 - val_mse: 0.0093 - 68ms/epoch - 813us/step
# Epoch 6/100
# 84/84 - 0s - loss: 0.0065 - mse: 0.0065 - val_loss: 0.0083 - val_mse: 0.0083 - 68ms/epoch - 810us/step
# Epoch 7/100
# 84/84 - 0s - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0077 - val_mse: 0.0077 - 67ms/epoch - 798us/step
# Epoch 8/100
# 84/84 - 0s - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0073 - val_mse: 0.0073 - 68ms/epoch - 810us/step
# Epoch 9/100
# 84/84 - 0s - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0071 - val_mse: 0.0071 - 70ms/epoch - 834us/step
# Epoch 10/100
# 84/84 - 0s - loss: 0.0055 - mse: 0.0055 - val_loss: 0.0069 - val_mse: 0.0069 - 68ms/epoch - 810us/step
# Epoch 11/100
# 84/84 - 0s - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0067 - val_mse: 0.0067 - 68ms/epoch - 810us/step
# Epoch 12/100
# 84/84 - 0s - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0066 - val_mse: 0.0066 - 67ms/epoch - 798us/step
# Epoch 13/100
# 84/84 - 0s - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0065 - val_mse: 0.0065 - 68ms/epoch - 810us/step
# Epoch 14/100
# 84/84 - 0s - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0064 - val_mse: 0.0064 - 68ms/epoch - 810us/step
# Epoch 15/100
# 84/84 - 0s - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0063 - val_mse: 0.0063 - 68ms/epoch - 810us/step
# Epoch 16/100
# 84/84 - 0s - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0062 - val_mse: 0.0062 - 68ms/epoch - 810us/step
# Epoch 17/100
# 84/84 - 0s - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0062 - val_mse: 0.0062 - 68ms/epoch - 810us/step
# Epoch 18/100
# 84/84 - 0s - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0061 - val_mse: 0.0061 - 67ms/epoch - 798us/step
# Epoch 19/100
# 84/84 - 0s - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0060 - val_mse: 0.0060 - 67ms/epoch - 798us/step
# Epoch 20/100
# 84/84 - 0s - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0060 - val_mse: 0.0060 - 68ms/epoch - 810us/step
# Epoch 21/100
# 84/84 - 0s - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0059 - val_mse: 0.0059 - 68ms/epoch - 810us/step
# Epoch 22/100
# 84/84 - 0s - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0059 - val_mse: 0.0059 - 69ms/epoch - 822us/step
# Epoch 23/100
# 84/84 - 0s - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0058 - val_mse: 0.0058 - 68ms/epoch - 810us/step
# Epoch 24/100
# 84/84 - 0s - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0058 - val_mse: 0.0058 - 69ms/epoch - 822us/step
# Epoch 25/100
# 84/84 - 0s - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0057 - val_mse: 0.0057 - 68ms/epoch - 810us/step
# Epoch 26/100
# 84/84 - 0s - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0057 - val_mse: 0.0057 - 68ms/epoch - 810us/step
# Epoch 27/100
# 84/84 - 0s - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0057 - val_mse: 0.0057 - 68ms/epoch - 810us/step
# Epoch 28/100
# 84/84 - 0s - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0056 - val_mse: 0.0056 - 68ms/epoch - 810us/step
# Epoch 29/100
# 84/84 - 0s - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0056 - val_mse: 0.0056 - 68ms/epoch - 810us/step
# Epoch 30/100
# 84/84 - 0s - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0055 - val_mse: 0.0055 - 69ms/epoch - 822us/step
# Epoch 31/100
# 84/84 - 0s - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0055 - val_mse: 0.0055 - 68ms/epoch - 810us/step
# Epoch 32/100
# 84/84 - 0s - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0055 - val_mse: 0.0055 - 69ms/epoch - 822us/step
# Epoch 33/100
# 84/84 - 0s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0054 - val_mse: 0.0054 - 69ms/epoch - 822us/step
# Epoch 34/100
# 84/84 - 0s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0054 - val_mse: 0.0054 - 69ms/epoch - 822us/step
# Epoch 35/100
# 84/84 - 0s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0054 - val_mse: 0.0054 - 69ms/epoch - 822us/step
# Epoch 36/100
# 84/84 - 0s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0054 - val_mse: 0.0054 - 70ms/epoch - 834us/step
# Epoch 37/100
# 84/84 - 0s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0053 - val_mse: 0.0053 - 70ms/epoch - 834us/step
# Epoch 38/100
# 84/84 - 0s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0053 - val_mse: 0.0053 - 69ms/epoch - 822us/step
# Epoch 39/100
# 84/84 - 0s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0053 - val_mse: 0.0053 - 69ms/epoch - 822us/step
# Epoch 40/100
# 84/84 - 0s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0052 - val_mse: 0.0052 - 68ms/epoch - 810us/step
# Epoch 41/100
# 84/84 - 0s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0052 - val_mse: 0.0052 - 67ms/epoch - 802us/step
# Epoch 42/100
# 84/84 - 0s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0052 - val_mse: 0.0052 - 68ms/epoch - 810us/step
# Epoch 43/100
# 84/84 - 0s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0052 - val_mse: 0.0052 - 68ms/epoch - 810us/step
# Epoch 44/100
# 84/84 - 0s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0052 - val_mse: 0.0052 - 68ms/epoch - 810us/step
# Epoch 45/100
# 84/84 - 0s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0051 - val_mse: 0.0051 - 68ms/epoch - 810us/step
# Epoch 46/100
# 84/84 - 0s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0051 - val_mse: 0.0051 - 69ms/epoch - 822us/step
# Epoch 47/100
# 84/84 - 0s - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0051 - val_mse: 0.0051 - 69ms/epoch - 822us/step
# Epoch 48/100
# 84/84 - 0s - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0051 - val_mse: 0.0051 - 68ms/epoch - 810us/step
# Epoch 49/100
# 84/84 - 0s - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0050 - val_mse: 0.0050 - 70ms/epoch - 834us/step
# Epoch 50/100
# 84/84 - 0s - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0050 - val_mse: 0.0050 - 69ms/epoch - 822us/step
# Epoch 51/100
# 84/84 - 0s - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0050 - val_mse: 0.0050 - 70ms/epoch - 834us/step
# Epoch 52/100
# 84/84 - 0s - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0050 - val_mse: 0.0050 - 68ms/epoch - 810us/step
# Epoch 53/100
# 84/84 - 0s - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0050 - val_mse: 0.0050 - 69ms/epoch - 822us/step
# Epoch 54/100
# 84/84 - 0s - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0050 - val_mse: 0.0050 - 68ms/epoch - 810us/step
# Epoch 55/100
# 84/84 - 0s - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0049 - val_mse: 0.0049 - 68ms/epoch - 810us/step
# Epoch 56/100
# 84/84 - 0s - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0049 - val_mse: 0.0049 - 69ms/epoch - 822us/step
# Epoch 57/100
# 84/84 - 0s - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0049 - val_mse: 0.0049 - 69ms/epoch - 822us/step
# Epoch 58/100
# 84/84 - 0s - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0049 - val_mse: 0.0049 - 69ms/epoch - 822us/step
# Epoch 59/100
# 84/84 - 0s - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0049 - val_mse: 0.0049 - 69ms/epoch - 822us/step
# Epoch 60/100
# 84/84 - 0s - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0049 - val_mse: 0.0049 - 67ms/epoch - 798us/step
# Epoch 61/100
# 84/84 - 0s - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0049 - val_mse: 0.0049 - 68ms/epoch - 810us/step
# Epoch 62/100
# 84/84 - 0s - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0048 - val_mse: 0.0048 - 69ms/epoch - 822us/step
# Epoch 63/100
# 84/84 - 0s - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0048 - val_mse: 0.0048 - 70ms/epoch - 834us/step
# Epoch 64/100
# 84/84 - 0s - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0048 - val_mse: 0.0048 - 69ms/epoch - 822us/step
# Epoch 65/100
# 84/84 - 0s - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0048 - val_mse: 0.0048 - 70ms/epoch - 834us/step
# Epoch 66/100
# 84/84 - 0s - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0048 - val_mse: 0.0048 - 69ms/epoch - 822us/step
# Epoch 67/100
# 84/84 - 0s - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0048 - val_mse: 0.0048 - 68ms/epoch - 810us/step
# Epoch 68/100
# 84/84 - 0s - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0048 - val_mse: 0.0048 - 68ms/epoch - 810us/step
# Epoch 69/100
# 84/84 - 0s - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0048 - val_mse: 0.0048 - 67ms/epoch - 798us/step
# Epoch 70/100
# 84/84 - 0s - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0047 - val_mse: 0.0047 - 67ms/epoch - 798us/step
# Epoch 71/100
# 84/84 - 0s - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0047 - val_mse: 0.0047 - 69ms/epoch - 822us/step
# Epoch 72/100
# 84/84 - 0s - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0047 - val_mse: 0.0047 - 68ms/epoch - 810us/step
# Epoch 73/100
# 84/84 - 0s - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0047 - val_mse: 0.0047 - 68ms/epoch - 810us/step
# Epoch 74/100
# 84/84 - 0s - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0047 - val_mse: 0.0047 - 68ms/epoch - 810us/step
# Epoch 75/100
# 84/84 - 0s - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0047 - val_mse: 0.0047 - 69ms/epoch - 822us/step
# Epoch 76/100
# 84/84 - 0s - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0047 - val_mse: 0.0047 - 68ms/epoch - 810us/step
# Epoch 77/100
# 84/84 - 0s - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0047 - val_mse: 0.0047 - 68ms/epoch - 810us/step
# Epoch 78/100
# 84/84 - 0s - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0047 - val_mse: 0.0047 - 68ms/epoch - 810us/step
# Epoch 79/100
# 84/84 - 0s - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0047 - val_mse: 0.0047 - 68ms/epoch - 810us/step
# Epoch 80/100
# 84/84 - 0s - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0047 - val_mse: 0.0047 - 67ms/epoch - 798us/step
# Epoch 81/100
# 84/84 - 0s - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0046 - val_mse: 0.0046 - 68ms/epoch - 810us/step
# Epoch 82/100
# 84/84 - 0s - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0046 - val_mse: 0.0046 - 67ms/epoch - 798us/step
# Epoch 83/100
# 84/84 - 0s - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0046 - val_mse: 0.0046 - 69ms/epoch - 822us/step
# Epoch 84/100
# 84/84 - 0s - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0046 - val_mse: 0.0046 - 67ms/epoch - 798us/step
# Epoch 85/100
# 84/84 - 0s - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0046 - val_mse: 0.0046 - 67ms/epoch - 798us/step
# Epoch 86/100
# 84/84 - 0s - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0046 - val_mse: 0.0046 - 69ms/epoch - 822us/step
# Epoch 87/100
# 84/84 - 0s - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0046 - val_mse: 0.0046 - 67ms/epoch - 798us/step
# Epoch 88/100
# 84/84 - 0s - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0046 - val_mse: 0.0046 - 69ms/epoch - 822us/step
# Epoch 89/100
# 84/84 - 0s - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0046 - val_mse: 0.0046 - 68ms/epoch - 810us/step
# Epoch 90/100
# 84/84 - 0s - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0046 - val_mse: 0.0046 - 70ms/epoch - 838us/step
# Epoch 91/100
# 84/84 - 0s - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0046 - val_mse: 0.0046 - 71ms/epoch - 845us/step
# Epoch 92/100
# 84/84 - 0s - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0046 - val_mse: 0.0046 - 68ms/epoch - 810us/step
# Epoch 93/100
# 84/84 - 0s - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0046 - val_mse: 0.0046 - 68ms/epoch - 810us/step
# Epoch 94/100
# 84/84 - 0s - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0046 - val_mse: 0.0046 - 68ms/epoch - 810us/step
# Epoch 95/100
# 84/84 - 0s - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0046 - val_mse: 0.0046 - 70ms/epoch - 834us/step
# Epoch 96/100
# 84/84 - 0s - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0045 - val_mse: 0.0045 - 70ms/epoch - 834us/step
# Epoch 97/100
# 84/84 - 0s - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0045 - val_mse: 0.0045 - 69ms/epoch - 822us/step
# Epoch 98/100
# 84/84 - 0s - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0045 - val_mse: 0.0045 - 68ms/epoch - 810us/step
# Epoch 99/100
# 84/84 - 0s - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0045 - val_mse: 0.0045 - 68ms/epoch - 810us/step
# Epoch 100/100
# 84/84 - 0s - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0045 - val_mse: 0.0045 - 69ms/epoch - 822us/step
# Epoch 1/100
# 84/84 - 0s - loss: 0.0131 - mse: 0.0131 - val_loss: 0.0151 - val_mse: 0.0151 - 330ms/epoch - 4ms/step
# Epoch 2/100
# 84/84 - 0s - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0126 - val_mse: 0.0126 - 68ms/epoch - 810us/step
# Epoch 3/100
# 84/84 - 0s - loss: 0.0090 - mse: 0.0090 - val_loss: 0.0108 - val_mse: 0.0108 - 69ms/epoch - 822us/step
# Epoch 4/100
# 84/84 - 0s - loss: 0.0080 - mse: 0.0080 - val_loss: 0.0095 - val_mse: 0.0095 - 69ms/epoch - 822us/step
# Epoch 5/100
# 84/84 - 0s - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0086 - val_mse: 0.0086 - 69ms/epoch - 822us/step
# Epoch 6/100
# 84/84 - 0s - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0079 - val_mse: 0.0079 - 69ms/epoch - 822us/step
# Epoch 7/100
# 84/84 - 0s - loss: 0.0063 - mse: 0.0063 - val_loss: 0.0074 - val_mse: 0.0074 - 68ms/epoch - 810us/step
# Epoch 8/100
# 84/84 - 0s - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0070 - val_mse: 0.0070 - 68ms/epoch - 810us/step
# Epoch 9/100
# 84/84 - 0s - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0067 - val_mse: 0.0067 - 69ms/epoch - 819us/step
# Epoch 10/100
# 84/84 - 0s - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0065 - val_mse: 0.0065 - 68ms/epoch - 810us/step
# Epoch 11/100
# 84/84 - 0s - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0063 - val_mse: 0.0063 - 69ms/epoch - 822us/step
# Epoch 12/100
# 84/84 - 0s - loss: 0.0055 - mse: 0.0055 - val_loss: 0.0062 - val_mse: 0.0062 - 68ms/epoch - 810us/step
# Epoch 13/100
# 84/84 - 0s - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0060 - val_mse: 0.0060 - 68ms/epoch - 810us/step
# Epoch 14/100
# 84/84 - 0s - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0059 - val_mse: 0.0059 - 67ms/epoch - 798us/step
# Epoch 15/100
# ...
# Epoch 63/100
# 84/84 - 0s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0043 - val_mse: 0.0043 - 69ms/epoch - 822us/step
# Epoch 64/100
# 84/84 - 0s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0043 - val_mse: 0.0043 - 66ms/epoch - 786us/step
# Epoch 65/100
# 84/84 - 0s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0043 - val_mse: 0.0043 - 69ms/epoch - 822us/step
# Epoch 66/100
# 84/84 - 0s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0043 - val_mse: 0.0043 - 70ms/epoch - 834us/step
# Epoch 67/100
# 84/84 - 0s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0042 - val_mse: 0.0042 - 68ms/epoch - 810us/step
# Epoch 68/100
# 84/84 - 0s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0042 - val_mse: 0.0042 - 67ms/epoch - 798us/step
# Epoch 69/100
# 84/84 - 0s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0042 - val_mse: 0.0042 - 70ms/epoch - 834us/step
# Epoch 70/100
# 84/84 - 0s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0042 - val_mse: 0.0042 - 68ms/epoch - 810us/step
# Epoch 71/100
# 84/84 - 0s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0042 - val_mse: 0.0042 - 70ms/epoch - 834us/step
# Epoch 72/100
# 84/84 - 0s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0042 - val_mse: 0.0042 - 69ms/epoch - 822us/step
# Epoch 73/100
# 84/84 - 0s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0042 - val_mse: 0.0042 - 69ms/epoch - 822us/step
# Epoch 74/100
# 84/84 - 0s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0042 - val_mse: 0.0042 - 69ms/epoch - 822us/step
# Epoch 75/100
# 84/84 - 0s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0041 - val_mse: 0.0041 - 70ms/epoch - 834us/step
# Epoch 76/100
# 84/84 - 0s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0041 - val_mse: 0.0041 - 70ms/epoch - 834us/step
# Epoch 77/100
# 84/84 - 0s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0041 - val_mse: 0.0041 - 69ms/epoch - 822us/step
# Epoch 78/100
# 84/84 - 0s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0041 - val_mse: 0.0041 - 68ms/epoch - 810us/step
# Epoch 79/100
# 84/84 - 0s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0041 - val_mse: 0.0041 - 69ms/epoch - 822us/step
# Epoch 80/100
# 84/84 - 0s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0041 - val_mse: 0.0041 - 69ms/epoch - 822us/step
# Epoch 81/100
# 84/84 - 0s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0041 - val_mse: 0.0041 - 68ms/epoch - 810us/step
# Epoch 82/100
# 84/84 - 0s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0041 - val_mse: 0.0041 - 67ms/epoch - 798us/step
# Epoch 83/100
# 84/84 - 0s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0041 - val_mse: 0.0041 - 68ms/epoch - 810us/step
# Epoch 84/100
# 84/84 - 0s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0041 - val_mse: 0.0041 - 67ms/epoch - 798us/step
# Epoch 85/100
# 84/84 - 0s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0040 - val_mse: 0.0040 - 68ms/epoch - 810us/step
# Epoch 86/100
# 84/84 - 0s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0040 - val_mse: 0.0040 - 68ms/epoch - 810us/step
# Epoch 87/100
# 84/84 - 0s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0040 - val_mse: 0.0040 - 69ms/epoch - 822us/step
# Epoch 88/100
# 84/84 - 0s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0040 - val_mse: 0.0040 - 68ms/epoch - 810us/step
# Epoch 89/100
# 84/84 - 0s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0040 - val_mse: 0.0040 - 69ms/epoch - 822us/step
# Epoch 90/100
# 84/84 - 0s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0040 - val_mse: 0.0040 - 68ms/epoch - 810us/step
# Epoch 91/100
# 84/84 - 0s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0040 - val_mse: 0.0040 - 68ms/epoch - 810us/step
# Epoch 92/100
# 84/84 - 0s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0040 - val_mse: 0.0040 - 68ms/epoch - 810us/step
# Epoch 93/100
# 84/84 - 0s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0040 - val_mse: 0.0040 - 66ms/epoch - 786us/step
# Epoch 94/100
# 84/84 - 0s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0040 - val_mse: 0.0040 - 71ms/epoch - 845us/step
# Epoch 95/100
# 84/84 - 0s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0040 - val_mse: 0.0040 - 69ms/epoch - 822us/step
# Epoch 96/100
# 84/84 - 0s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0039 - val_mse: 0.0039 - 69ms/epoch - 822us/step
# Epoch 97/100
# 84/84 - 0s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0039 - val_mse: 0.0039 - 70ms/epoch - 834us/step
# Epoch 98/100
# 84/84 - 0s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0039 - val_mse: 0.0039 - 69ms/epoch - 822us/step
# Epoch 99/100
# 84/84 - 0s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0039 - val_mse: 0.0039 - 70ms/epoch - 834us/step
# Epoch 100/100
# 84/84 - 0s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0039 - val_mse: 0.0039 - 74ms/epoch - 881us/step
# Epoch 1/100
# 84/84 - 0s - loss: 0.0432 - mse: 0.0432 - val_loss: 0.0241 - val_mse: 0.0241 - 326ms/epoch - 4ms/step
# Epoch 2/100
# 84/84 - 0s - loss: 0.0210 - mse: 0.0210 - val_loss: 0.0185 - val_mse: 0.0185 - 67ms/epoch - 798us/step
# Epoch 3/100
# 84/84 - 0s - loss: 0.0167 - mse: 0.0167 - val_loss: 0.0147 - val_mse: 0.0147 - 68ms/epoch - 810us/step
# Epoch 4/100
# 84/84 - 0s - loss: 0.0138 - mse: 0.0138 - val_loss: 0.0120 - val_mse: 0.0120 - 68ms/epoch - 810us/step
# Epoch 5/100
# 84/84 - 0s - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0102 - val_mse: 0.0102 - 67ms/epoch - 798us/step
# Epoch 6/100
# 84/84 - 0s - loss: 0.0102 - mse: 0.0102 - val_loss: 0.0088 - val_mse: 0.0088 - 68ms/epoch - 810us/step
# Epoch 7/100
# 84/84 - 0s - loss: 0.0091 - mse: 0.0091 - val_loss: 0.0079 - val_mse: 0.0079 - 68ms/epoch - 810us/step
# Epoch 8/100
# 84/84 - 0s - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0072 - val_mse: 0.0072 - 68ms/epoch - 810us/step
# Epoch 9/100
# 84/84 - 0s - loss: 0.0077 - mse: 0.0077 - val_loss: 0.0066 - val_mse: 0.0066 - 68ms/epoch - 810us/step
# Epoch 10/100
# 84/84 - 0s - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0062 - val_mse: 0.0062 - 68ms/epoch - 810us/step
# Epoch 11/100
# 84/84 - 0s - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0059 - val_mse: 0.0059 - 69ms/epoch - 822us/step
# Epoch 12/100
# 84/84 - 0s - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0057 - val_mse: 0.0057 - 68ms/epoch - 810us/step
# Epoch 13/100
# 84/84 - 0s - loss: 0.0064 - mse: 0.0064 - val_loss: 0.0055 - val_mse: 0.0055 - 68ms/epoch - 810us/step
# Epoch 14/100
# 84/84 - 0s - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0053 - val_mse: 0.0053 - 69ms/epoch - 822us/step
# Epoch 15/100
# 84/84 - 0s - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0052 - val_mse: 0.0052 - 68ms/epoch - 810us/step
# Epoch 16/100
# 84/84 - 0s - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0051 - val_mse: 0.0051 - 68ms/epoch - 814us/step
# Epoch 17/100
# 84/84 - 0s - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0050 - val_mse: 0.0050 - 68ms/epoch - 810us/step
# Epoch 18/100
# 84/84 - 0s - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0049 - val_mse: 0.0049 - 69ms/epoch - 822us/step
# Epoch 19/100
# 84/84 - 0s - loss: 0.0055 - mse: 0.0055 - val_loss: 0.0048 - val_mse: 0.0048 - 68ms/epoch - 810us/step
# Epoch 20/100
# 84/84 - 0s - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0047 - val_mse: 0.0047 - 67ms/epoch - 798us/step
# Epoch 21/100
# 84/84 - 0s - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0047 - val_mse: 0.0047 - 67ms/epoch - 798us/step
# Epoch 22/100
# 84/84 - 0s - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0046 - val_mse: 0.0046 - 67ms/epoch - 798us/step
# Epoch 23/100
# 84/84 - 0s - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0046 - val_mse: 0.0046 - 68ms/epoch - 810us/step
# Epoch 24/100
# 84/84 - 0s - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0045 - val_mse: 0.0045 - 69ms/epoch - 822us/step
# Epoch 25/100
# 84/84 - 0s - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0045 - val_mse: 0.0045 - 69ms/epoch - 822us/step
# Epoch 26/100
# 84/84 - 0s - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0044 - val_mse: 0.0044 - 69ms/epoch - 822us/step
# Epoch 27/100
# 84/84 - 0s - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0044 - val_mse: 0.0044 - 69ms/epoch - 822us/step
# Epoch 28/100
# 84/84 - 0s - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0044 - val_mse: 0.0044 - 68ms/epoch - 810us/step
# Epoch 29/100
# 84/84 - 0s - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0043 - val_mse: 0.0043 - 67ms/epoch - 798us/step
# Epoch 30/100
# 84/84 - 0s - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0043 - val_mse: 0.0043 - 68ms/epoch - 810us/step
# Epoch 31/100
# 84/84 - 0s - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0043 - val_mse: 0.0043 - 69ms/epoch - 822us/step
# Epoch 32/100
# 84/84 - 0s - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0042 - val_mse: 0.0042 - 68ms/epoch - 810us/step
# Epoch 33/100
# 84/84 - 0s - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0042 - val_mse: 0.0042 - 68ms/epoch - 810us/step
# Epoch 34/100
# 84/84 - 0s - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0042 - val_mse: 0.0042 - 69ms/epoch - 822us/step
# Epoch 35/100
# 84/84 - 0s - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0042 - val_mse: 0.0042 - 68ms/epoch - 810us/step
# Epoch 36/100
# 84/84 - 0s - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0041 - val_mse: 0.0041 - 69ms/epoch - 822us/step
# Epoch 37/100
# 84/84 - 0s - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0041 - val_mse: 0.0041 - 68ms/epoch - 810us/step
# Epoch 38/100
# 84/84 - 0s - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0041 - val_mse: 0.0041 - 69ms/epoch - 822us/step
# Epoch 39/100
# 84/84 - 0s - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0041 - val_mse: 0.0041 - 67ms/epoch - 798us/step
# Epoch 40/100
# 84/84 - 0s - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0041 - val_mse: 0.0041 - 68ms/epoch - 810us/step
# Epoch 41/100
# 84/84 - 0s - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0040 - val_mse: 0.0040 - 68ms/epoch - 810us/step
# Epoch 42/100
# 84/84 - 0s - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0040 - val_mse: 0.0040 - 67ms/epoch - 798us/step
# Epoch 43/100
# 84/84 - 0s - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0040 - val_mse: 0.0040 - 69ms/epoch - 822us/step
# Epoch 44/100
# 84/84 - 0s - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0040 - val_mse: 0.0040 - 67ms/epoch - 798us/step
# Epoch 45/100
# 84/84 - 0s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0040 - val_mse: 0.0040 - 68ms/epoch - 810us/step
# Epoch 46/100
# 84/84 - 0s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0040 - val_mse: 0.0040 - 69ms/epoch - 822us/step
# Epoch 47/100
# 84/84 - 0s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0040 - val_mse: 0.0040 - 67ms/epoch - 798us/step
# Epoch 48/100
# 84/84 - 0s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0039 - val_mse: 0.0039 - 68ms/epoch - 810us/step
# Epoch 49/100
# 84/84 - 0s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0039 - val_mse: 0.0039 - 68ms/epoch - 810us/step
# Epoch 50/100
# 84/84 - 0s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0039 - val_mse: 0.0039 - 69ms/epoch - 822us/step
# Epoch 51/100
# 84/84 - 0s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0039 - val_mse: 0.0039 - 67ms/epoch - 798us/step
# Epoch 52/100
# 84/84 - 0s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0039 - val_mse: 0.0039 - 68ms/epoch - 810us/step
# Epoch 53/100
# 84/84 - 0s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0039 - val_mse: 0.0039 - 69ms/epoch - 822us/step
# Epoch 54/100
# 84/84 - 0s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0039 - val_mse: 0.0039 - 70ms/epoch - 834us/step
# Epoch 55/100
# 84/84 - 0s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0039 - val_mse: 0.0039 - 68ms/epoch - 810us/step
# Epoch 56/100
# 84/84 - 0s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0039 - val_mse: 0.0039 - 67ms/epoch - 798us/step
# Epoch 57/100
# 84/84 - 0s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0039 - val_mse: 0.0039 - 68ms/epoch - 810us/step
# Epoch 58/100
# 84/84 - 0s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0038 - val_mse: 0.0038 - 68ms/epoch - 810us/step
# Epoch 59/100
# 84/84 - 0s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0038 - val_mse: 0.0038 - 68ms/epoch - 810us/step
# Epoch 60/100
# 84/84 - 0s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0038 - val_mse: 0.0038 - 68ms/epoch - 810us/step
# Epoch 61/100
# 84/84 - 0s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0038 - val_mse: 0.0038 - 67ms/epoch - 798us/step
# Epoch 62/100
# 84/84 - 0s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0038 - val_mse: 0.0038 - 69ms/epoch - 822us/step
# Epoch 63/100
# 84/84 - 0s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0038 - val_mse: 0.0038 - 68ms/epoch - 810us/step
# Epoch 64/100
# 84/84 - 0s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0038 - val_mse: 0.0038 - 68ms/epoch - 810us/step
# Epoch 65/100
# 84/84 - 0s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0038 - val_mse: 0.0038 - 67ms/epoch - 798us/step
# Epoch 66/100
# 84/84 - 0s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0038 - val_mse: 0.0038 - 66ms/epoch - 786us/step
# Epoch 67/100
# 84/84 - 0s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0038 - val_mse: 0.0038 - 67ms/epoch - 798us/step
# Epoch 68/100
# 84/84 - 0s - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0038 - val_mse: 0.0038 - 67ms/epoch - 798us/step
# Epoch 69/100
# 84/84 - 0s - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0038 - val_mse: 0.0038 - 69ms/epoch - 822us/step
# Epoch 70/100
# 84/84 - 0s - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0038 - val_mse: 0.0038 - 67ms/epoch - 798us/step
# Epoch 71/100
# 84/84 - 0s - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0037 - val_mse: 0.0037 - 67ms/epoch - 798us/step
# Epoch 72/100
# 84/84 - 0s - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0037 - val_mse: 0.0037 - 66ms/epoch - 786us/step
# Epoch 73/100
# 84/84 - 0s - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0037 - val_mse: 0.0037 - 68ms/epoch - 810us/step
# Epoch 74/100
# 84/84 - 0s - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0037 - val_mse: 0.0037 - 68ms/epoch - 810us/step
# Epoch 75/100
# 84/84 - 0s - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0037 - val_mse: 0.0037 - 69ms/epoch - 822us/step
# Epoch 76/100
# 84/84 - 0s - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0037 - val_mse: 0.0037 - 68ms/epoch - 810us/step
# Epoch 77/100
# 84/84 - 0s - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0037 - val_mse: 0.0037 - 68ms/epoch - 810us/step
# Epoch 78/100
# 84/84 - 0s - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0037 - val_mse: 0.0037 - 68ms/epoch - 810us/step
# Epoch 79/100
# 84/84 - 0s - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0037 - val_mse: 0.0037 - 69ms/epoch - 822us/step
# Epoch 80/100
# 84/84 - 0s - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0037 - val_mse: 0.0037 - 68ms/epoch - 810us/step
# Epoch 81/100
# 84/84 - 0s - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0037 - val_mse: 0.0037 - 67ms/epoch - 798us/step
# Epoch 82/100
# 84/84 - 0s - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0037 - val_mse: 0.0037 - 67ms/epoch - 798us/step
# Epoch 83/100
# 84/84 - 0s - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0037 - val_mse: 0.0037 - 67ms/epoch - 798us/step
# Epoch 84/100
# 84/84 - 0s - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0037 - val_mse: 0.0037 - 66ms/epoch - 786us/step
# Epoch 85/100
# 84/84 - 0s - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0037 - val_mse: 0.0037 - 68ms/epoch - 810us/step
# Epoch 86/100
# 84/84 - 0s - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0037 - val_mse: 0.0037 - 68ms/epoch - 810us/step
# Epoch 87/100
# 84/84 - 0s - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0037 - val_mse: 0.0037 - 68ms/epoch - 810us/step
# Epoch 88/100
# 84/84 - 0s - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0037 - val_mse: 0.0037 - 68ms/epoch - 810us/step
# Epoch 89/100
# 84/84 - 0s - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0037 - val_mse: 0.0037 - 68ms/epoch - 810us/step
# Epoch 90/100
# 84/84 - 0s - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0036 - val_mse: 0.0036 - 68ms/epoch - 810us/step
# Epoch 91/100
# 84/84 - 0s - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0036 - val_mse: 0.0036 - 70ms/epoch - 834us/step
# Epoch 92/100
# 84/84 - 0s - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0036 - val_mse: 0.0036 - 68ms/epoch - 810us/step
# Epoch 93/100
# 84/84 - 0s - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0036 - val_mse: 0.0036 - 67ms/epoch - 798us/step
# Epoch 94/100
# 84/84 - 0s - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0036 - val_mse: 0.0036 - 67ms/epoch - 798us/step
# Epoch 95/100
# 84/84 - 0s - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0036 - val_mse: 0.0036 - 66ms/epoch - 786us/step
# Epoch 96/100
# 84/84 - 0s - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0036 - val_mse: 0.0036 - 70ms/epoch - 834us/step
# Epoch 97/100
# 84/84 - 0s - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0036 - val_mse: 0.0036 - 67ms/epoch - 798us/step
# Epoch 98/100
# 84/84 - 0s - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0036 - val_mse: 0.0036 - 69ms/epoch - 822us/step
# Epoch 99/100
# 84/84 - 0s - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0036 - val_mse: 0.0036 - 67ms/epoch - 798us/step
# Epoch 100/100
# 84/84 - 0s - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0036 - val_mse: 0.0036 - 68ms/epoch - 810us/step

# %%
# Resumen del entrenamiento
n_rows = 2
n_cols = 3

fig, ax = plt.subplots(n_rows, n_cols, figsize=(14,8))
fig.suptitle('Model loss SPI_12')
plt.subplots_adjust(hspace=0.3, wspace=0.3)
for i, (key, value) in enumerate(model_history_dict.items()):
    if i<n_cols:
        ax[0, i].plot(value.history['loss'])
        ax[0, i].plot(value.history['val_loss'])
        ax[0, i].set_title(key, fontsize=10)
        ax[0, i].set_ylabel('loss')
        ax[0, i].set_xlabel('epoch')
        ax[0, i].legend(['train', 'test'], loc='upper right')
    else:
        ax[1, i-n_cols].plot(value.history['loss'])
        ax[1, i-n_cols].plot(value.history['val_loss'])
        ax[1, i-n_cols].set_title(key, fontsize=10)
        ax[1, i-n_cols].set_ylabel('loss')
        ax[1, i-n_cols].set_xlabel('epoch')
        ax[1, i-n_cols].legend(['train', 'test'], loc='upper right')

# %% [markdown]
# # Evaluación del modelo

# %%
test_score_values = []
for key in spi_12_dict.keys():
    print('Evaluación '+ key)
    train_prediction = model.predict(X_train_dict[key], verbose=0)
    test_prediction = model.predict(X_test_dict[key], verbose=0)
    train_score = model.evaluate(X_train_dict[key], y_train_dict[key], verbose=0)
    test_score = model.evaluate(X_test_dict[key], y_test_dict[key], verbose=0)
    test_score_values.append(test_score[0])
    print('Train score: {} MSE'.format(train_score[0]))
    print('Test score: {} MSE'.format(test_score[0]))
    print('')

mean_test_score = sum(test_score_values) / len(test_score_values)
print('MLP SPI_12 Mean Test score: {} MSE'.format(mean_test_score))
# Out:
# Evaluación Demarcación Hidrográfica de las Cuencas Mediterráneas Andaluzas
# Train score: 0.0048028104938566685 MSE
# Test score: 0.005660890135914087 MSE
#
# Evaluación Cuenca hidrográfica del Guadalquivir
# Train score: 0.004858348518610001 MSE
# Test score: 0.00461864797398448 MSE
#
# Evaluación Cuenca hidrográfica del Guadiana
# Train score: 0.00520335603505373 MSE
# Test score: 0.004704213701188564 MSE
#
# Evaluación Cuenca hidrográfica del Segura
# Train score: 0.004220373462885618 MSE
# Test score: 0.004811499267816544 MSE
#
# Evaluación Demarcación Hidrográfica Guadalete-Barbate
# Train score: 0.004679610952734947 MSE
# Test score: 0.004397651646286249 MSE
#
# Evaluación Demarcación Hidrográfica Tinto, Odiel y Piedras
# Train score: 0.004037919454276562 MSE
# Test score: 0.003604185301810503 MSE
#
# MLP SPI_12 Mean Test score: 0.0046328480045000715 MSE

# %% [markdown]
# # Visualización de la predicción

# %%
# Gráfica con los valores reales frente a los datos de predicción
# Se usa como ejemplo la predicción de la Demarcación Hidrográfica Tinto, Odiel y Piedras
plt.figure(figsize=(12, 8))
train_stamp = np.arange(9+sequence_size, 9+sequence_size + X_train_dict[keys_names[5]].shape[0])
test_stamp = np.arange(9+2 * sequence_size + X_train_dict[keys_names[5]].shape[0], 9+len(spi_12_dict[keys_names[5]]))
plt.plot(spi_12_dict[keys_names[5]], label='Valores reales')
plt.plot(train_stamp, train_prediction, label='train prediction')
plt.plot(test_stamp, test_prediction, label = 'test prediction')
plt.title('Predicción SPI_3 '+ keys_names[5])
plt.legend()
plt.show()
