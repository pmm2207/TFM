# %%
# Librerias utilizadas
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.callbacks import EarlyStopping
from scikeras.wrappers import KerasRegressor
from sklearn.model_selection import GridSearchCV
import warnings

# %% [markdown]
# ## Importación de datos

# %%
csv_names  = ['df_DHCMA', 'df_CHG', 'df_CHGUADIANA',
            'df_CHS', 'df_DHGB', 'df_DHTOP']
path = '..\\DATA\\'
keys_names = ['Demarcación Hidrográfica de las Cuencas Mediterráneas Andaluzas', 'Cuenca hidrográfica del Guadalquivir', 'Cuenca hidrográfica del Guadiana',
              'Cuenca hidrográfica del Segura', 'Demarcación Hidrográfica Guadalete-Barbate', 'Demarcación Hidrográfica Tinto, Odiel y Piedras']
df_dict = {key: pd.read_csv(path+value+'.csv', sep=',', encoding='ISO-8859-1')
           for key, value in zip(keys_names, csv_names)}

# %% [markdown]
# ### Procesado de datos de entrada

# %%
# Función de creación de dataset sequencial con arrays de valores input/output
# Este dataset tiene la estructura adecuada para los datos de entrada
# en la red neuronal
def to_sequences(seq_size, obs):
    x = []
    y = []

    for i in range(len(obs)-seq_size):
        window = obs.iloc[i:(i+seq_size)]
        after_window = obs.iloc[i+seq_size]
        window = [[x] for x in window]
        x.append(window)
        y.append(after_window)
        
    return np.array(x),np.array(y)

# %%
# Creación del dataset de indice SPI_6
spi_6_dict =  {key: value['spi_6']
           for key, value in df_dict.items()}

# Eliminación valores vacios iniciales
for key, df in spi_6_dict.items():           
    spi_6_dict[key] = df.dropna(how='all')

# %%
# Separación en conjunto de entrenamiento y de prueba
# Los datos de prueba empiezan a partir de 2011
spi_6_train_dict, spi_6_test_dict = {}, {}
for key, df in spi_6_dict.items():
    df_train, df_test = train_test_split(df, test_size=0.13, shuffle=False)
    spi_6_train_dict[key] = df_train
    spi_6_test_dict[key] = df_test

# %%
# Cálculo de datasets sequenciales
sequence_size = 10
X_train_dict, y_train_dict, X_test_dict,y_test_dict = {}, {}, {}, {}

for key, df in spi_6_train_dict.items():
    X_train,y_train = to_sequences(sequence_size, df)
    X_train_dict[key] = X_train
    y_train_dict[key] = y_train

for key, df in spi_6_test_dict.items():
    X_test,y_test = to_sequences(sequence_size, df)
    X_test_dict[key] = X_test
    y_test_dict[key] = y_test
    
print("Dimensiones del training set: {}".format(X_train_dict[keys_names[0]].shape))
print("Dimensiones del test set: {}".format(X_test_dict[keys_names[0]].shape))
# Out:
# Dimensiones del training set: (841, 10, 1)
# Dimensiones del test set: (118, 10, 1)

# %% [markdown]
# # Definición del modelo

# %%
def create_model(n_nodes=20, optimizer='adam', activation='relu'):
    # Arquitectura del modelo
    model = Sequential()
    model.add(LSTM(n_nodes, activation=activation, input_shape=(X_train.shape[1], X_train.shape[2])))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer=optimizer, metrics=['mse'])
    return model

#  Early stopping para evitar overfitting
es = EarlyStopping(monitor='val_loss', verbose=1, patience=3)

# %% [markdown]
# ### GRID SEARCH busqueda mejores parámetros

# %%
# Transformación del modelo para aplicar grid search
model = KerasRegressor(model=create_model, epochs=100, batch_size=10, verbose=0, activation='relu', n_nodes=20)

# Parámetros de búsqueda
param_grid = {
    'n_nodes': [10,20, 50],
    'epochs': [50, 100],
    'batch_size' : [5,10,20],
    'optimizer' : ['SGD', 'adam'], 
    'activation' : ['relu', 'tanh']
}


# Se ignoran avisos de ejecución del grid search
warnings.simplefilter("ignore")

# Cálculo de grid search
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=4)
grid_result_dict = {}
for key in spi_6_train_dict.keys():
    grid_result_dict[key] = grid.fit(X_train_dict[key], y_train_dict[key], callbacks=[es], shuffle=False, validation_data=(
        X_test_dict[key], y_test_dict[key]))
    print(key)
    print("Best: %f using %s" % (grid_result_dict[key].best_score_, grid_result_dict[key].best_params_))
    print('')
# Out:
# Demarcación Hidrográfica de las Cuencas Mediterráneas Andaluzas
# Best: 0.653934 using {'activation': 'tanh', 'batch_size': 5, 'epochs': 100, 'n_nodes': 50, 'optimizer': 'SGD'}
#
# Cuenca hidrográfica del Guadalquivir
# Best: 0.660336 using {'activation': 'tanh', 'batch_size': 5, 'epochs': 100, 'n_nodes': 50, 'optimizer': 'SGD'}
#
# Cuenca hidrográfica del Guadiana
# Best: 0.693261 using {'activation': 'tanh', 'batch_size': 5, 'epochs': 100, 'n_nodes': 50, 'optimizer': 'adam'}
#
# Cuenca hidrográfica del Segura
# Best: 0.759190 using {'activation': 'tanh', 'batch_size': 5, 'epochs': 100, 'n_nodes': 50, 'optimizer': 'adam'}
#
# Demarcación Hidrográfica Guadalete-Barbate
# Best: 0.621423 using {'activation': 'tanh', 'batch_size': 5, 'epochs': 100, 'n_nodes': 50, 'optimizer': 'SGD'}
#
# Demarcación Hidrográfica Tinto, Odiel y Piedras
# Best: 0.666278 using {'activation': 'tanh', 'batch_size': 5, 'epochs': 100, 'n_nodes': 50, 'optimizer': 'SGD'}

# %% [markdown]
# # Entrenamiento del modelo

# %%
model_history_dict = {}

for key in spi_6_train_dict.keys():
    model = create_model(grid_result_dict[key].best_params_['n_nodes'], grid_result_dict[key].best_params_[
                         'optimizer'], grid_result_dict[key].best_params_['activation'])

    model_history_dict[key] = model.fit(X_train_dict[key], y_train_dict[key], epochs=grid_result_dict[key].best_params_['epochs'],
        batch_size=grid_result_dict[key].best_params_['batch_size'],
        validation_data=(
        X_test_dict[key], y_test_dict[key]), verbose=2, shuffle=False, callbacks=[es]
        )
# Out:
# Epoch 1/100
# 169/169 - 2s - loss: 0.0404 - mse: 0.0404 - val_loss: 0.0289 - val_mse: 0.0289 - 2s/epoch - 11ms/step
# Epoch 2/100
# 169/169 - 0s - loss: 0.0229 - mse: 0.0229 - val_loss: 0.0275 - val_mse: 0.0275 - 412ms/epoch - 2ms/step
# Epoch 3/100
# 169/169 - 0s - loss: 0.0221 - mse: 0.0221 - val_loss: 0.0263 - val_mse: 0.0263 - 415ms/epoch - 2ms/step
# Epoch 4/100
# 169/169 - 0s - loss: 0.0213 - mse: 0.0213 - val_loss: 0.0252 - val_mse: 0.0252 - 411ms/epoch - 2ms/step
# Epoch 5/100
# 169/169 - 0s - loss: 0.0206 - mse: 0.0206 - val_loss: 0.0242 - val_mse: 0.0242 - 412ms/epoch - 2ms/step
# Epoch 6/100
# 169/169 - 0s - loss: 0.0200 - mse: 0.0200 - val_loss: 0.0234 - val_mse: 0.0234 - 415ms/epoch - 2ms/step
# Epoch 7/100
# 169/169 - 0s - loss: 0.0195 - mse: 0.0195 - val_loss: 0.0226 - val_mse: 0.0226 - 413ms/epoch - 2ms/step
# Epoch 8/100
# 169/169 - 0s - loss: 0.0190 - mse: 0.0190 - val_loss: 0.0219 - val_mse: 0.0219 - 412ms/epoch - 2ms/step
# Epoch 9/100
# 169/169 - 0s - loss: 0.0186 - mse: 0.0186 - val_loss: 0.0213 - val_mse: 0.0213 - 416ms/epoch - 2ms/step
# Epoch 10/100
# 169/169 - 0s - loss: 0.0182 - mse: 0.0182 - val_loss: 0.0208 - val_mse: 0.0208 - 414ms/epoch - 2ms/step
# Epoch 11/100
# 169/169 - 0s - loss: 0.0179 - mse: 0.0179 - val_loss: 0.0203 - val_mse: 0.0203 - 408ms/epoch - 2ms/step
# Epoch 12/100
# 169/169 - 0s - loss: 0.0176 - mse: 0.0176 - val_loss: 0.0198 - val_mse: 0.0198 - 413ms/epoch - 2ms/step
# Epoch 13/100
# 169/169 - 0s - loss: 0.0173 - mse: 0.0173 - val_loss: 0.0194 - val_mse: 0.0194 - 411ms/epoch - 2ms/step
# Epoch 14/100
# 169/169 - 0s - loss: 0.0170 - mse: 0.0170 - val_loss: 0.0190 - val_mse: 0.0190 - 411ms/epoch - 2ms/step
# Epoch 15/100
# 169/169 - 0s - loss: 0.0168 - mse: 0.0168 - val_loss: 0.0187 - val_mse: 0.0187 - 414ms/epoch - 2ms/step
# Epoch 16/100
# 169/169 - 0s - loss: 0.0166 - mse: 0.0166 - val_loss: 0.0184 - val_mse: 0.0184 - 410ms/epoch - 2ms/step
# Epoch 17/100
# 169/169 - 0s - loss: 0.0164 - mse: 0.0164 - val_loss: 0.0181 - val_mse: 0.0181 - 412ms/epoch - 2ms/step
# Epoch 18/100
# 169/169 - 0s - loss: 0.0162 - mse: 0.0162 - val_loss: 0.0178 - val_mse: 0.0178 - 413ms/epoch - 2ms/step
# Epoch 19/100
# 169/169 - 0s - loss: 0.0160 - mse: 0.0160 - val_loss: 0.0175 - val_mse: 0.0175 - 408ms/epoch - 2ms/step
# Epoch 20/100
# 169/169 - 0s - loss: 0.0159 - mse: 0.0159 - val_loss: 0.0173 - val_mse: 0.0173 - 409ms/epoch - 2ms/step
# Epoch 21/100
# 169/169 - 0s - loss: 0.0157 - mse: 0.0157 - val_loss: 0.0171 - val_mse: 0.0171 - 411ms/epoch - 2ms/step
# Epoch 22/100
# 169/169 - 0s - loss: 0.0156 - mse: 0.0156 - val_loss: 0.0168 - val_mse: 0.0168 - 410ms/epoch - 2ms/step
# Epoch 23/100
# 169/169 - 0s - loss: 0.0155 - mse: 0.0155 - val_loss: 0.0166 - val_mse: 0.0166 - 411ms/epoch - 2ms/step
# Epoch 24/100
# 169/169 - 0s - loss: 0.0153 - mse: 0.0153 - val_loss: 0.0164 - val_mse: 0.0164 - 410ms/epoch - 2ms/step
# Epoch 25/100
# 169/169 - 0s - loss: 0.0152 - mse: 0.0152 - val_loss: 0.0163 - val_mse: 0.0163 - 413ms/epoch - 2ms/step
# Epoch 26/100
# 169/169 - 0s - loss: 0.0151 - mse: 0.0151 - val_loss: 0.0161 - val_mse: 0.0161 - 409ms/epoch - 2ms/step
# Epoch 27/100
# 169/169 - 0s - loss: 0.0150 - mse: 0.0150 - val_loss: 0.0159 - val_mse: 0.0159 - 411ms/epoch - 2ms/step
# Epoch 28/100
# 169/169 - 0s - loss: 0.0149 - mse: 0.0149 - val_loss: 0.0157 - val_mse: 0.0157 - 411ms/epoch - 2ms/step
# Epoch 29/100
# 169/169 - 0s - loss: 0.0148 - mse: 0.0148 - val_loss: 0.0156 - val_mse: 0.0156 - 409ms/epoch - 2ms/step
# Epoch 30/100
# 169/169 - 0s - loss: 0.0147 - mse: 0.0147 - val_loss: 0.0154 - val_mse: 0.0154 - 406ms/epoch - 2ms/step
# Epoch 31/100
# 169/169 - 0s - loss: 0.0146 - mse: 0.0146 - val_loss: 0.0153 - val_mse: 0.0153 - 409ms/epoch - 2ms/step
# Epoch 32/100
# 169/169 - 0s - loss: 0.0145 - mse: 0.0145 - val_loss: 0.0151 - val_mse: 0.0151 - 409ms/epoch - 2ms/step
# Epoch 33/100
# 169/169 - 0s - loss: 0.0144 - mse: 0.0144 - val_loss: 0.0150 - val_mse: 0.0150 - 410ms/epoch - 2ms/step
# Epoch 34/100
# 169/169 - 0s - loss: 0.0143 - mse: 0.0143 - val_loss: 0.0149 - val_mse: 0.0149 - 408ms/epoch - 2ms/step
# Epoch 35/100
# 169/169 - 0s - loss: 0.0142 - mse: 0.0142 - val_loss: 0.0148 - val_mse: 0.0148 - 410ms/epoch - 2ms/step
# Epoch 36/100
# 169/169 - 0s - loss: 0.0141 - mse: 0.0141 - val_loss: 0.0146 - val_mse: 0.0146 - 412ms/epoch - 2ms/step
# Epoch 37/100
# 169/169 - 0s - loss: 0.0140 - mse: 0.0140 - val_loss: 0.0145 - val_mse: 0.0145 - 415ms/epoch - 2ms/step
# Epoch 38/100
# 169/169 - 0s - loss: 0.0139 - mse: 0.0139 - val_loss: 0.0144 - val_mse: 0.0144 - 414ms/epoch - 2ms/step
# Epoch 39/100
# 169/169 - 0s - loss: 0.0139 - mse: 0.0139 - val_loss: 0.0143 - val_mse: 0.0143 - 411ms/epoch - 2ms/step
# Epoch 40/100
# 169/169 - 0s - loss: 0.0138 - mse: 0.0138 - val_loss: 0.0142 - val_mse: 0.0142 - 410ms/epoch - 2ms/step
# Epoch 41/100
# 169/169 - 0s - loss: 0.0137 - mse: 0.0137 - val_loss: 0.0141 - val_mse: 0.0141 - 411ms/epoch - 2ms/step
# Epoch 42/100
# 169/169 - 0s - loss: 0.0136 - mse: 0.0136 - val_loss: 0.0139 - val_mse: 0.0139 - 410ms/epoch - 2ms/step
# Epoch 43/100
# 169/169 - 0s - loss: 0.0136 - mse: 0.0136 - val_loss: 0.0138 - val_mse: 0.0138 - 406ms/epoch - 2ms/step
# Epoch 44/100
# 169/169 - 0s - loss: 0.0135 - mse: 0.0135 - val_loss: 0.0137 - val_mse: 0.0137 - 408ms/epoch - 2ms/step
# Epoch 45/100
# 169/169 - 0s - loss: 0.0134 - mse: 0.0134 - val_loss: 0.0136 - val_mse: 0.0136 - 410ms/epoch - 2ms/step
# Epoch 46/100
# 169/169 - 0s - loss: 0.0133 - mse: 0.0133 - val_loss: 0.0135 - val_mse: 0.0135 - 412ms/epoch - 2ms/step
# Epoch 47/100
# 169/169 - 0s - loss: 0.0133 - mse: 0.0133 - val_loss: 0.0135 - val_mse: 0.0135 - 409ms/epoch - 2ms/step
# Epoch 48/100
# 169/169 - 0s - loss: 0.0132 - mse: 0.0132 - val_loss: 0.0134 - val_mse: 0.0134 - 410ms/epoch - 2ms/step
# Epoch 49/100
# 169/169 - 0s - loss: 0.0131 - mse: 0.0131 - val_loss: 0.0133 - val_mse: 0.0133 - 411ms/epoch - 2ms/step
# Epoch 50/100
# 169/169 - 0s - loss: 0.0131 - mse: 0.0131 - val_loss: 0.0132 - val_mse: 0.0132 - 412ms/epoch - 2ms/step
# Epoch 51/100
# 169/169 - 0s - loss: 0.0130 - mse: 0.0130 - val_loss: 0.0131 - val_mse: 0.0131 - 410ms/epoch - 2ms/step
# Epoch 52/100
# 169/169 - 0s - loss: 0.0130 - mse: 0.0130 - val_loss: 0.0130 - val_mse: 0.0130 - 412ms/epoch - 2ms/step
# Epoch 53/100
# 169/169 - 0s - loss: 0.0129 - mse: 0.0129 - val_loss: 0.0129 - val_mse: 0.0129 - 412ms/epoch - 2ms/step
# Epoch 54/100
# 169/169 - 0s - loss: 0.0128 - mse: 0.0128 - val_loss: 0.0129 - val_mse: 0.0129 - 412ms/epoch - 2ms/step
# Epoch 55/100
# 169/169 - 0s - loss: 0.0128 - mse: 0.0128 - val_loss: 0.0128 - val_mse: 0.0128 - 411ms/epoch - 2ms/step
# Epoch 56/100
# 169/169 - 0s - loss: 0.0127 - mse: 0.0127 - val_loss: 0.0127 - val_mse: 0.0127 - 406ms/epoch - 2ms/step
# Epoch 57/100
# 169/169 - 0s - loss: 0.0127 - mse: 0.0127 - val_loss: 0.0126 - val_mse: 0.0126 - 409ms/epoch - 2ms/step
# Epoch 58/100
# 169/169 - 0s - loss: 0.0126 - mse: 0.0126 - val_loss: 0.0125 - val_mse: 0.0125 - 407ms/epoch - 2ms/step
# Epoch 59/100
# 169/169 - 0s - loss: 0.0126 - mse: 0.0126 - val_loss: 0.0125 - val_mse: 0.0125 - 410ms/epoch - 2ms/step
# Epoch 60/100
# 169/169 - 0s - loss: 0.0125 - mse: 0.0125 - val_loss: 0.0124 - val_mse: 0.0124 - 410ms/epoch - 2ms/step
# Epoch 61/100
# 169/169 - 0s - loss: 0.0125 - mse: 0.0125 - val_loss: 0.0123 - val_mse: 0.0123 - 421ms/epoch - 2ms/step
# Epoch 62/100
# 169/169 - 0s - loss: 0.0124 - mse: 0.0124 - val_loss: 0.0123 - val_mse: 0.0123 - 416ms/epoch - 2ms/step
# Epoch 63/100
# 169/169 - 0s - loss: 0.0124 - mse: 0.0124 - val_loss: 0.0122 - val_mse: 0.0122 - 414ms/epoch - 2ms/step
# Epoch 64/100
# 169/169 - 0s - loss: 0.0123 - mse: 0.0123 - val_loss: 0.0121 - val_mse: 0.0121 - 415ms/epoch - 2ms/step
# Epoch 65/100
# 169/169 - 0s - loss: 0.0123 - mse: 0.0123 - val_loss: 0.0121 - val_mse: 0.0121 - 418ms/epoch - 2ms/step
# Epoch 66/100
# 169/169 - 0s - loss: 0.0122 - mse: 0.0122 - val_loss: 0.0120 - val_mse: 0.0120 - 416ms/epoch - 2ms/step
# Epoch 67/100
# 169/169 - 0s - loss: 0.0122 - mse: 0.0122 - val_loss: 0.0119 - val_mse: 0.0119 - 415ms/epoch - 2ms/step
# Epoch 68/100
# 169/169 - 0s - loss: 0.0121 - mse: 0.0121 - val_loss: 0.0119 - val_mse: 0.0119 - 415ms/epoch - 2ms/step
# Epoch 69/100
# 169/169 - 0s - loss: 0.0121 - mse: 0.0121 - val_loss: 0.0118 - val_mse: 0.0118 - 414ms/epoch - 2ms/step
# Epoch 70/100
# 169/169 - 0s - loss: 0.0120 - mse: 0.0120 - val_loss: 0.0118 - val_mse: 0.0118 - 415ms/epoch - 2ms/step
# Epoch 71/100
# 169/169 - 0s - loss: 0.0120 - mse: 0.0120 - val_loss: 0.0117 - val_mse: 0.0117 - 415ms/epoch - 2ms/step
# Epoch 72/100
# 169/169 - 0s - loss: 0.0120 - mse: 0.0120 - val_loss: 0.0117 - val_mse: 0.0117 - 414ms/epoch - 2ms/step
# Epoch 73/100
# 169/169 - 0s - loss: 0.0119 - mse: 0.0119 - val_loss: 0.0116 - val_mse: 0.0116 - 411ms/epoch - 2ms/step
# Epoch 74/100
# 169/169 - 0s - loss: 0.0119 - mse: 0.0119 - val_loss: 0.0116 - val_mse: 0.0116 - 413ms/epoch - 2ms/step
# Epoch 75/100
# 169/169 - 0s - loss: 0.0118 - mse: 0.0118 - val_loss: 0.0115 - val_mse: 0.0115 - 413ms/epoch - 2ms/step
# Epoch 76/100
# 169/169 - 0s - loss: 0.0118 - mse: 0.0118 - val_loss: 0.0115 - val_mse: 0.0115 - 415ms/epoch - 2ms/step
# Epoch 77/100
# 169/169 - 0s - loss: 0.0118 - mse: 0.0118 - val_loss: 0.0114 - val_mse: 0.0114 - 416ms/epoch - 2ms/step
# Epoch 78/100
# 169/169 - 0s - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0114 - val_mse: 0.0114 - 416ms/epoch - 2ms/step
# Epoch 79/100
# 169/169 - 0s - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0113 - val_mse: 0.0113 - 415ms/epoch - 2ms/step
# Epoch 80/100
# 169/169 - 0s - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0113 - val_mse: 0.0113 - 411ms/epoch - 2ms/step
# Epoch 81/100
# 169/169 - 0s - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0112 - val_mse: 0.0112 - 415ms/epoch - 2ms/step
# Epoch 82/100
# 169/169 - 0s - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0112 - val_mse: 0.0112 - 411ms/epoch - 2ms/step
# Epoch 83/100
# 169/169 - 0s - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0112 - val_mse: 0.0112 - 415ms/epoch - 2ms/step
# Epoch 84/100
# 169/169 - 0s - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0111 - val_mse: 0.0111 - 414ms/epoch - 2ms/step
# Epoch 85/100
# 169/169 - 0s - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0111 - val_mse: 0.0111 - 411ms/epoch - 2ms/step
# Epoch 86/100
# 169/169 - 0s - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0110 - val_mse: 0.0110 - 413ms/epoch - 2ms/step
# Epoch 87/100
# 169/169 - 0s - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0110 - val_mse: 0.0110 - 416ms/epoch - 2ms/step
# Epoch 88/100
# 169/169 - 0s - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0110 - val_mse: 0.0110 - 413ms/epoch - 2ms/step
# Epoch 89/100
# 169/169 - 0s - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0109 - val_mse: 0.0109 - 416ms/epoch - 2ms/step
# Epoch 90/100
# 169/169 - 0s - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0109 - val_mse: 0.0109 - 413ms/epoch - 2ms/step
# Epoch 91/100
# 169/169 - 0s - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0109 - val_mse: 0.0109 - 412ms/epoch - 2ms/step
# Epoch 92/100
# 169/169 - 0s - loss: 0.0113 - mse: 0.0113 - val_loss: 0.0108 - val_mse: 0.0108 - 414ms/epoch - 2ms/step
# Epoch 93/100
# 169/169 - 0s - loss: 0.0113 - mse: 0.0113 - val_loss: 0.0108 - val_mse: 0.0108 - 412ms/epoch - 2ms/step
# Epoch 94/100
# 169/169 - 0s - loss: 0.0113 - mse: 0.0113 - val_loss: 0.0108 - val_mse: 0.0108 - 409ms/epoch - 2ms/step
# Epoch 95/100
# 169/169 - 0s - loss: 0.0113 - mse: 0.0113 - val_loss: 0.0107 - val_mse: 0.0107 - 414ms/epoch - 2ms/step
# Epoch 96/100
# 169/169 - 0s - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0107 - val_mse: 0.0107 - 410ms/epoch - 2ms/step
# Epoch 97/100
# 169/169 - 0s - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0107 - val_mse: 0.0107 - 411ms/epoch - 2ms/step
# Epoch 98/100
# 169/169 - 0s - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0106 - val_mse: 0.0106 - 406ms/epoch - 2ms/step
# Epoch 99/100
# 169/169 - 0s - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0106 - val_mse: 0.0106 - 411ms/epoch - 2ms/step
# Epoch 100/100
# 169/169 - 0s - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0106 - val_mse: 0.0106 - 408ms/epoch - 2ms/step
# Epoch 1/100
# 169/169 - 2s - loss: 0.0424 - mse: 0.0424 - val_loss: 0.0307 - val_mse: 0.0307 - 2s/epoch - 10ms/step
# Epoch 2/100
# 169/169 - 0s - loss: 0.0268 - mse: 0.0268 - val_loss: 0.0285 - val_mse: 0.0285 - 400ms/epoch - 2ms/step
# Epoch 3/100
# 169/169 - 0s - loss: 0.0255 - mse: 0.0255 - val_loss: 0.0266 - val_mse: 0.0266 - 402ms/epoch - 2ms/step
# Epoch 4/100
# 169/169 - 0s - loss: 0.0245 - mse: 0.0245 - val_loss: 0.0251 - val_mse: 0.0251 - 398ms/epoch - 2ms/step
# Epoch 5/100
# 169/169 - 0s - loss: 0.0236 - mse: 0.0236 - val_loss: 0.0239 - val_mse: 0.0239 - 402ms/epoch - 2ms/step
# Epoch 6/100
# 169/169 - 0s - loss: 0.0229 - mse: 0.0229 - val_loss: 0.0228 - val_mse: 0.0228 - 400ms/epoch - 2ms/step
# Epoch 7/100
# 169/169 - 0s - loss: 0.0222 - mse: 0.0222 - val_loss: 0.0219 - val_mse: 0.0219 - 401ms/epoch - 2ms/step
# Epoch 8/100
# 169/169 - 0s - loss: 0.0217 - mse: 0.0217 - val_loss: 0.0212 - val_mse: 0.0212 - 402ms/epoch - 2ms/step
# Epoch 9/100
# 169/169 - 0s - loss: 0.0212 - mse: 0.0212 - val_loss: 0.0205 - val_mse: 0.0205 - 400ms/epoch - 2ms/step
# Epoch 10/100
# 169/169 - 0s - loss: 0.0208 - mse: 0.0208 - val_loss: 0.0199 - val_mse: 0.0199 - 410ms/epoch - 2ms/step
# Epoch 11/100
# 169/169 - 0s - loss: 0.0205 - mse: 0.0205 - val_loss: 0.0194 - val_mse: 0.0194 - 402ms/epoch - 2ms/step
# Epoch 12/100
# 169/169 - 0s - loss: 0.0201 - mse: 0.0201 - val_loss: 0.0189 - val_mse: 0.0189 - 400ms/epoch - 2ms/step
# Epoch 13/100
# 169/169 - 0s - loss: 0.0198 - mse: 0.0198 - val_loss: 0.0185 - val_mse: 0.0185 - 403ms/epoch - 2ms/step
# Epoch 14/100
# 169/169 - 0s - loss: 0.0196 - mse: 0.0196 - val_loss: 0.0181 - val_mse: 0.0181 - 403ms/epoch - 2ms/step
# Epoch 15/100
# 169/169 - 0s - loss: 0.0193 - mse: 0.0193 - val_loss: 0.0177 - val_mse: 0.0177 - 401ms/epoch - 2ms/step
# Epoch 16/100
# 169/169 - 0s - loss: 0.0191 - mse: 0.0191 - val_loss: 0.0174 - val_mse: 0.0174 - 402ms/epoch - 2ms/step
# Epoch 17/100
# 169/169 - 0s - loss: 0.0189 - mse: 0.0189 - val_loss: 0.0171 - val_mse: 0.0171 - 402ms/epoch - 2ms/step
# Epoch 18/100
# 169/169 - 0s - loss: 0.0186 - mse: 0.0186 - val_loss: 0.0168 - val_mse: 0.0168 - 401ms/epoch - 2ms/step
# Epoch 19/100
# 169/169 - 0s - loss: 0.0184 - mse: 0.0184 - val_loss: 0.0165 - val_mse: 0.0165 - 404ms/epoch - 2ms/step
# Epoch 20/100
# 169/169 - 0s - loss: 0.0183 - mse: 0.0183 - val_loss: 0.0162 - val_mse: 0.0162 - 399ms/epoch - 2ms/step
# Epoch 21/100
# 169/169 - 0s - loss: 0.0181 - mse: 0.0181 - val_loss: 0.0160 - val_mse: 0.0160 - 406ms/epoch - 2ms/step
# Epoch 22/100
# 169/169 - 0s - loss: 0.0179 - mse: 0.0179 - val_loss: 0.0158 - val_mse: 0.0158 - 407ms/epoch - 2ms/step
# Epoch 23/100
# 169/169 - 0s - loss: 0.0177 - mse: 0.0177 - val_loss: 0.0155 - val_mse: 0.0155 - 404ms/epoch - 2ms/step
# Epoch 24/100
# 169/169 - 0s - loss: 0.0176 - mse: 0.0176 - val_loss: 0.0153 - val_mse: 0.0153 - 403ms/epoch - 2ms/step
# Epoch 25/100
# 169/169 - 0s - loss: 0.0174 - mse: 0.0174 - val_loss: 0.0151 - val_mse: 0.0151 - 405ms/epoch - 2ms/step
# Epoch 26/100
# 169/169 - 0s - loss: 0.0173 - mse: 0.0173 - val_loss: 0.0149 - val_mse: 0.0149 - 404ms/epoch - 2ms/step
# Epoch 27/100
# 169/169 - 0s - loss: 0.0171 - mse: 0.0171 - val_loss: 0.0147 - val_mse: 0.0147 - 400ms/epoch - 2ms/step
# Epoch 28/100
# 169/169 - 0s - loss: 0.0170 - mse: 0.0170 - val_loss: 0.0146 - val_mse: 0.0146 - 407ms/epoch - 2ms/step
# Epoch 29/100
# 169/169 - 0s - loss: 0.0169 - mse: 0.0169 - val_loss: 0.0144 - val_mse: 0.0144 - 405ms/epoch - 2ms/step
# Epoch 30/100
# 169/169 - 0s - loss: 0.0167 - mse: 0.0167 - val_loss: 0.0142 - val_mse: 0.0142 - 401ms/epoch - 2ms/step
# Epoch 31/100
# 169/169 - 0s - loss: 0.0166 - mse: 0.0166 - val_loss: 0.0141 - val_mse: 0.0141 - 405ms/epoch - 2ms/step
# Epoch 32/100
# 169/169 - 0s - loss: 0.0165 - mse: 0.0165 - val_loss: 0.0139 - val_mse: 0.0139 - 405ms/epoch - 2ms/step
# Epoch 33/100
# 169/169 - 0s - loss: 0.0164 - mse: 0.0164 - val_loss: 0.0138 - val_mse: 0.0138 - 406ms/epoch - 2ms/step
# Epoch 34/100
# 169/169 - 0s - loss: 0.0162 - mse: 0.0162 - val_loss: 0.0136 - val_mse: 0.0136 - 396ms/epoch - 2ms/step
# Epoch 35/100
# 169/169 - 0s - loss: 0.0161 - mse: 0.0161 - val_loss: 0.0135 - val_mse: 0.0135 - 397ms/epoch - 2ms/step
# Epoch 36/100
# 169/169 - 0s - loss: 0.0160 - mse: 0.0160 - val_loss: 0.0133 - val_mse: 0.0133 - 398ms/epoch - 2ms/step
# Epoch 37/100
# 169/169 - 0s - loss: 0.0159 - mse: 0.0159 - val_loss: 0.0132 - val_mse: 0.0132 - 398ms/epoch - 2ms/step
# Epoch 38/100
# 169/169 - 0s - loss: 0.0158 - mse: 0.0158 - val_loss: 0.0131 - val_mse: 0.0131 - 396ms/epoch - 2ms/step
# Epoch 39/100
# 169/169 - 0s - loss: 0.0157 - mse: 0.0157 - val_loss: 0.0129 - val_mse: 0.0129 - 398ms/epoch - 2ms/step
# Epoch 40/100
# 169/169 - 0s - loss: 0.0156 - mse: 0.0156 - val_loss: 0.0128 - val_mse: 0.0128 - 397ms/epoch - 2ms/step
# Epoch 41/100
# 169/169 - 0s - loss: 0.0155 - mse: 0.0155 - val_loss: 0.0127 - val_mse: 0.0127 - 405ms/epoch - 2ms/step
# Epoch 42/100
# 169/169 - 0s - loss: 0.0154 - mse: 0.0154 - val_loss: 0.0126 - val_mse: 0.0126 - 406ms/epoch - 2ms/step
# Epoch 43/100
# 169/169 - 0s - loss: 0.0154 - mse: 0.0154 - val_loss: 0.0125 - val_mse: 0.0125 - 406ms/epoch - 2ms/step
# Epoch 44/100
# 169/169 - 0s - loss: 0.0153 - mse: 0.0153 - val_loss: 0.0124 - val_mse: 0.0124 - 399ms/epoch - 2ms/step
# Epoch 45/100
# 169/169 - 0s - loss: 0.0152 - mse: 0.0152 - val_loss: 0.0123 - val_mse: 0.0123 - 395ms/epoch - 2ms/step
# Epoch 46/100
# 169/169 - 0s - loss: 0.0151 - mse: 0.0151 - val_loss: 0.0122 - val_mse: 0.0122 - 399ms/epoch - 2ms/step
# Epoch 47/100
# 169/169 - 0s - loss: 0.0150 - mse: 0.0150 - val_loss: 0.0121 - val_mse: 0.0121 - 405ms/epoch - 2ms/step
# Epoch 48/100
# 169/169 - 0s - loss: 0.0150 - mse: 0.0150 - val_loss: 0.0120 - val_mse: 0.0120 - 404ms/epoch - 2ms/step
# Epoch 49/100
# 169/169 - 0s - loss: 0.0149 - mse: 0.0149 - val_loss: 0.0119 - val_mse: 0.0119 - 404ms/epoch - 2ms/step
# Epoch 50/100
# 169/169 - 0s - loss: 0.0148 - mse: 0.0148 - val_loss: 0.0118 - val_mse: 0.0118 - 398ms/epoch - 2ms/step
# Epoch 51/100
# 169/169 - 0s - loss: 0.0147 - mse: 0.0147 - val_loss: 0.0117 - val_mse: 0.0117 - 403ms/epoch - 2ms/step
# Epoch 52/100
# 169/169 - 0s - loss: 0.0147 - mse: 0.0147 - val_loss: 0.0116 - val_mse: 0.0116 - 401ms/epoch - 2ms/step
# Epoch 53/100
# 169/169 - 0s - loss: 0.0146 - mse: 0.0146 - val_loss: 0.0116 - val_mse: 0.0116 - 401ms/epoch - 2ms/step
# Epoch 54/100
# 169/169 - 0s - loss: 0.0146 - mse: 0.0146 - val_loss: 0.0115 - val_mse: 0.0115 - 404ms/epoch - 2ms/step
# Epoch 55/100
# 169/169 - 0s - loss: 0.0145 - mse: 0.0145 - val_loss: 0.0114 - val_mse: 0.0114 - 400ms/epoch - 2ms/step
# Epoch 56/100
# 169/169 - 0s - loss: 0.0144 - mse: 0.0144 - val_loss: 0.0113 - val_mse: 0.0113 - 403ms/epoch - 2ms/step
# Epoch 57/100
# 169/169 - 0s - loss: 0.0144 - mse: 0.0144 - val_loss: 0.0113 - val_mse: 0.0113 - 406ms/epoch - 2ms/step
# Epoch 58/100
# 169/169 - 0s - loss: 0.0143 - mse: 0.0143 - val_loss: 0.0112 - val_mse: 0.0112 - 401ms/epoch - 2ms/step
# Epoch 59/100
# 169/169 - 0s - loss: 0.0143 - mse: 0.0143 - val_loss: 0.0111 - val_mse: 0.0111 - 401ms/epoch - 2ms/step
# Epoch 60/100
# 169/169 - 0s - loss: 0.0142 - mse: 0.0142 - val_loss: 0.0111 - val_mse: 0.0111 - 402ms/epoch - 2ms/step
# Epoch 61/100
# 169/169 - 0s - loss: 0.0142 - mse: 0.0142 - val_loss: 0.0110 - val_mse: 0.0110 - 402ms/epoch - 2ms/step
# Epoch 62/100
# 169/169 - 0s - loss: 0.0141 - mse: 0.0141 - val_loss: 0.0110 - val_mse: 0.0110 - 403ms/epoch - 2ms/step
# Epoch 63/100
# 169/169 - 0s - loss: 0.0141 - mse: 0.0141 - val_loss: 0.0109 - val_mse: 0.0109 - 399ms/epoch - 2ms/step
# Epoch 64/100
# 169/169 - 0s - loss: 0.0140 - mse: 0.0140 - val_loss: 0.0108 - val_mse: 0.0108 - 397ms/epoch - 2ms/step
# Epoch 65/100
# 169/169 - 0s - loss: 0.0140 - mse: 0.0140 - val_loss: 0.0108 - val_mse: 0.0108 - 402ms/epoch - 2ms/step
# Epoch 66/100
# 169/169 - 0s - loss: 0.0140 - mse: 0.0140 - val_loss: 0.0107 - val_mse: 0.0107 - 405ms/epoch - 2ms/step
# Epoch 67/100
# 169/169 - 0s - loss: 0.0139 - mse: 0.0139 - val_loss: 0.0107 - val_mse: 0.0107 - 404ms/epoch - 2ms/step
# Epoch 68/100
# 169/169 - 0s - loss: 0.0139 - mse: 0.0139 - val_loss: 0.0106 - val_mse: 0.0106 - 402ms/epoch - 2ms/step
# Epoch 69/100
# 169/169 - 0s - loss: 0.0138 - mse: 0.0138 - val_loss: 0.0106 - val_mse: 0.0106 - 406ms/epoch - 2ms/step
# Epoch 70/100
# 169/169 - 0s - loss: 0.0138 - mse: 0.0138 - val_loss: 0.0105 - val_mse: 0.0105 - 404ms/epoch - 2ms/step
# Epoch 71/100
# 169/169 - 0s - loss: 0.0138 - mse: 0.0138 - val_loss: 0.0105 - val_mse: 0.0105 - 404ms/epoch - 2ms/step
# Epoch 72/100
# 169/169 - 0s - loss: 0.0137 - mse: 0.0137 - val_loss: 0.0105 - val_mse: 0.0105 - 402ms/epoch - 2ms/step
# Epoch 73/100
# 169/169 - 0s - loss: 0.0137 - mse: 0.0137 - val_loss: 0.0104 - val_mse: 0.0104 - 401ms/epoch - 2ms/step
# Epoch 74/100
# 169/169 - 0s - loss: 0.0137 - mse: 0.0137 - val_loss: 0.0104 - val_mse: 0.0104 - 404ms/epoch - 2ms/step
# Epoch 75/100
# 169/169 - 0s - loss: 0.0136 - mse: 0.0136 - val_loss: 0.0103 - val_mse: 0.0103 - 404ms/epoch - 2ms/step
# Epoch 76/100
# 169/169 - 0s - loss: 0.0136 - mse: 0.0136 - val_loss: 0.0103 - val_mse: 0.0103 - 403ms/epoch - 2ms/step
# Epoch 77/100
# 169/169 - 0s - loss: 0.0136 - mse: 0.0136 - val_loss: 0.0103 - val_mse: 0.0103 - 404ms/epoch - 2ms/step
# Epoch 78/100
# 169/169 - 0s - loss: 0.0136 - mse: 0.0136 - val_loss: 0.0102 - val_mse: 0.0102 - 404ms/epoch - 2ms/step
# Epoch 79/100
# 169/169 - 0s - loss: 0.0135 - mse: 0.0135 - val_loss: 0.0102 - val_mse: 0.0102 - 404ms/epoch - 2ms/step
# Epoch 80/100
# 169/169 - 0s - loss: 0.0135 - mse: 0.0135 - val_loss: 0.0102 - val_mse: 0.0102 - 402ms/epoch - 2ms/step
# Epoch 81/100
# 169/169 - 0s - loss: 0.0135 - mse: 0.0135 - val_loss: 0.0101 - val_mse: 0.0101 - 399ms/epoch - 2ms/step
# Epoch 82/100
# 169/169 - 0s - loss: 0.0134 - mse: 0.0134 - val_loss: 0.0101 - val_mse: 0.0101 - 410ms/epoch - 2ms/step
# Epoch 83/100
# 169/169 - 0s - loss: 0.0134 - mse: 0.0134 - val_loss: 0.0101 - val_mse: 0.0101 - 459ms/epoch - 3ms/step
# Epoch 84/100
# 169/169 - 0s - loss: 0.0134 - mse: 0.0134 - val_loss: 0.0100 - val_mse: 0.0100 - 453ms/epoch - 3ms/step
# Epoch 85/100
# 169/169 - 0s - loss: 0.0134 - mse: 0.0134 - val_loss: 0.0100 - val_mse: 0.0100 - 454ms/epoch - 3ms/step
# Epoch 86/100
# 169/169 - 0s - loss: 0.0134 - mse: 0.0134 - val_loss: 0.0100 - val_mse: 0.0100 - 436ms/epoch - 3ms/step
# Epoch 87/100
# 169/169 - 0s - loss: 0.0133 - mse: 0.0133 - val_loss: 0.0100 - val_mse: 0.0100 - 430ms/epoch - 3ms/step
# Epoch 88/100
# 169/169 - 0s - loss: 0.0133 - mse: 0.0133 - val_loss: 0.0099 - val_mse: 0.0099 - 418ms/epoch - 2ms/step
# Epoch 89/100
# 169/169 - 0s - loss: 0.0133 - mse: 0.0133 - val_loss: 0.0099 - val_mse: 0.0099 - 413ms/epoch - 2ms/step
# Epoch 90/100
# 169/169 - 0s - loss: 0.0133 - mse: 0.0133 - val_loss: 0.0099 - val_mse: 0.0099 - 411ms/epoch - 2ms/step
# Epoch 91/100
# 169/169 - 0s - loss: 0.0132 - mse: 0.0132 - val_loss: 0.0098 - val_mse: 0.0098 - 407ms/epoch - 2ms/step
# Epoch 92/100
# 169/169 - 0s - loss: 0.0132 - mse: 0.0132 - val_loss: 0.0098 - val_mse: 0.0098 - 411ms/epoch - 2ms/step
# Epoch 93/100
# 169/169 - 0s - loss: 0.0132 - mse: 0.0132 - val_loss: 0.0098 - val_mse: 0.0098 - 408ms/epoch - 2ms/step
# Epoch 94/100
# 169/169 - 0s - loss: 0.0132 - mse: 0.0132 - val_loss: 0.0098 - val_mse: 0.0098 - 412ms/epoch - 2ms/step
# Epoch 95/100
# 169/169 - 0s - loss: 0.0132 - mse: 0.0132 - val_loss: 0.0098 - val_mse: 0.0098 - 410ms/epoch - 2ms/step
# Epoch 96/100
# 169/169 - 0s - loss: 0.0131 - mse: 0.0131 - val_loss: 0.0097 - val_mse: 0.0097 - 410ms/epoch - 2ms/step
# Epoch 97/100
# 169/169 - 0s - loss: 0.0131 - mse: 0.0131 - val_loss: 0.0097 - val_mse: 0.0097 - 408ms/epoch - 2ms/step
# Epoch 98/100
# 169/169 - 0s - loss: 0.0131 - mse: 0.0131 - val_loss: 0.0097 - val_mse: 0.0097 - 408ms/epoch - 2ms/step
# Epoch 99/100
# 169/169 - 0s - loss: 0.0131 - mse: 0.0131 - val_loss: 0.0097 - val_mse: 0.0097 - 410ms/epoch - 2ms/step
# Epoch 100/100
# 169/169 - 0s - loss: 0.0131 - mse: 0.0131 - val_loss: 0.0097 - val_mse: 0.0097 - 410ms/epoch - 2ms/step
# Epoch 1/100
# 169/169 - 2s - loss: 0.0390 - mse: 0.0390 - val_loss: 0.0264 - val_mse: 0.0264 - 2s/epoch - 10ms/step
# Epoch 2/100
# 169/169 - 0s - loss: 0.0244 - mse: 0.0244 - val_loss: 0.0250 - val_mse: 0.0250 - 406ms/epoch - 2ms/step
# Epoch 3/100
# 169/169 - 0s - loss: 0.0234 - mse: 0.0234 - val_loss: 0.0238 - val_mse: 0.0238 - 409ms/epoch - 2ms/step
# Epoch 4/100
# 169/169 - 0s - loss: 0.0226 - mse: 0.0226 - val_loss: 0.0228 - val_mse: 0.0228 - 410ms/epoch - 2ms/step
# Epoch 5/100
# 169/169 - 0s - loss: 0.0219 - mse: 0.0219 - val_loss: 0.0219 - val_mse: 0.0219 - 407ms/epoch - 2ms/step
# Epoch 6/100
# 169/169 - 0s - loss: 0.0213 - mse: 0.0213 - val_loss: 0.0212 - val_mse: 0.0212 - 408ms/epoch - 2ms/step
# Epoch 7/100
# 169/169 - 0s - loss: 0.0207 - mse: 0.0207 - val_loss: 0.0206 - val_mse: 0.0206 - 409ms/epoch - 2ms/step
# Epoch 8/100
# 169/169 - 0s - loss: 0.0203 - mse: 0.0203 - val_loss: 0.0201 - val_mse: 0.0201 - 416ms/epoch - 2ms/step
# Epoch 9/100
# 169/169 - 0s - loss: 0.0199 - mse: 0.0199 - val_loss: 0.0196 - val_mse: 0.0196 - 408ms/epoch - 2ms/step
# Epoch 10/100
# 169/169 - 0s - loss: 0.0196 - mse: 0.0196 - val_loss: 0.0191 - val_mse: 0.0191 - 405ms/epoch - 2ms/step
# Epoch 11/100
# 169/169 - 0s - loss: 0.0192 - mse: 0.0192 - val_loss: 0.0188 - val_mse: 0.0188 - 409ms/epoch - 2ms/step
# Epoch 12/100
# 169/169 - 0s - loss: 0.0190 - mse: 0.0190 - val_loss: 0.0184 - val_mse: 0.0184 - 410ms/epoch - 2ms/step
# Epoch 13/100
# 169/169 - 0s - loss: 0.0187 - mse: 0.0187 - val_loss: 0.0181 - val_mse: 0.0181 - 411ms/epoch - 2ms/step
# Epoch 14/100
# 169/169 - 0s - loss: 0.0185 - mse: 0.0185 - val_loss: 0.0178 - val_mse: 0.0178 - 411ms/epoch - 2ms/step
# Epoch 15/100
# 169/169 - 0s - loss: 0.0183 - mse: 0.0183 - val_loss: 0.0175 - val_mse: 0.0175 - 408ms/epoch - 2ms/step
# Epoch 16/100
# 169/169 - 0s - loss: 0.0180 - mse: 0.0180 - val_loss: 0.0172 - val_mse: 0.0172 - 409ms/epoch - 2ms/step
# Epoch 17/100
# 169/169 - 0s - loss: 0.0179 - mse: 0.0179 - val_loss: 0.0170 - val_mse: 0.0170 - 407ms/epoch - 2ms/step
# Epoch 18/100
# 169/169 - 0s - loss: 0.0177 - mse: 0.0177 - val_loss: 0.0168 - val_mse: 0.0168 - 409ms/epoch - 2ms/step
# Epoch 19/100
# 169/169 - 0s - loss: 0.0175 - mse: 0.0175 - val_loss: 0.0166 - val_mse: 0.0166 - 412ms/epoch - 2ms/step
# Epoch 20/100
# 169/169 - 0s - loss: 0.0173 - mse: 0.0173 - val_loss: 0.0163 - val_mse: 0.0163 - 412ms/epoch - 2ms/step
# Epoch 21/100
# 169/169 - 0s - loss: 0.0172 - mse: 0.0172 - val_loss: 0.0161 - val_mse: 0.0161 - 409ms/epoch - 2ms/step
# Epoch 22/100
# 169/169 - 0s - loss: 0.0170 - mse: 0.0170 - val_loss: 0.0160 - val_mse: 0.0160 - 414ms/epoch - 2ms/step
# Epoch 23/100
# 169/169 - 0s - loss: 0.0169 - mse: 0.0169 - val_loss: 0.0158 - val_mse: 0.0158 - 415ms/epoch - 2ms/step
# Epoch 24/100
# 169/169 - 0s - loss: 0.0167 - mse: 0.0167 - val_loss: 0.0156 - val_mse: 0.0156 - 411ms/epoch - 2ms/step
# Epoch 25/100
# 169/169 - 0s - loss: 0.0166 - mse: 0.0166 - val_loss: 0.0154 - val_mse: 0.0154 - 409ms/epoch - 2ms/step
# Epoch 26/100
# 169/169 - 0s - loss: 0.0165 - mse: 0.0165 - val_loss: 0.0153 - val_mse: 0.0153 - 411ms/epoch - 2ms/step
# Epoch 27/100
# 169/169 - 0s - loss: 0.0163 - mse: 0.0163 - val_loss: 0.0151 - val_mse: 0.0151 - 420ms/epoch - 2ms/step
# Epoch 28/100
# 169/169 - 0s - loss: 0.0162 - mse: 0.0162 - val_loss: 0.0150 - val_mse: 0.0150 - 414ms/epoch - 2ms/step
# Epoch 29/100
# 169/169 - 0s - loss: 0.0161 - mse: 0.0161 - val_loss: 0.0148 - val_mse: 0.0148 - 411ms/epoch - 2ms/step
# Epoch 30/100
# 169/169 - 0s - loss: 0.0160 - mse: 0.0160 - val_loss: 0.0147 - val_mse: 0.0147 - 414ms/epoch - 2ms/step
# Epoch 31/100
# 169/169 - 0s - loss: 0.0159 - mse: 0.0159 - val_loss: 0.0145 - val_mse: 0.0145 - 413ms/epoch - 2ms/step
# Epoch 32/100
# 169/169 - 0s - loss: 0.0157 - mse: 0.0157 - val_loss: 0.0144 - val_mse: 0.0144 - 416ms/epoch - 2ms/step
# Epoch 33/100
# 169/169 - 0s - loss: 0.0156 - mse: 0.0156 - val_loss: 0.0143 - val_mse: 0.0143 - 416ms/epoch - 2ms/step
# Epoch 34/100
# 169/169 - 0s - loss: 0.0155 - mse: 0.0155 - val_loss: 0.0141 - val_mse: 0.0141 - 411ms/epoch - 2ms/step
# Epoch 35/100
# 169/169 - 0s - loss: 0.0154 - mse: 0.0154 - val_loss: 0.0140 - val_mse: 0.0140 - 416ms/epoch - 2ms/step
# Epoch 36/100
# 169/169 - 0s - loss: 0.0153 - mse: 0.0153 - val_loss: 0.0139 - val_mse: 0.0139 - 410ms/epoch - 2ms/step
# Epoch 37/100
# 169/169 - 0s - loss: 0.0152 - mse: 0.0152 - val_loss: 0.0138 - val_mse: 0.0138 - 415ms/epoch - 2ms/step
# Epoch 38/100
# 169/169 - 0s - loss: 0.0151 - mse: 0.0151 - val_loss: 0.0136 - val_mse: 0.0136 - 415ms/epoch - 2ms/step
# Epoch 39/100
# 169/169 - 0s - loss: 0.0150 - mse: 0.0150 - val_loss: 0.0135 - val_mse: 0.0135 - 413ms/epoch - 2ms/step
# Epoch 40/100
# 169/169 - 0s - loss: 0.0150 - mse: 0.0150 - val_loss: 0.0134 - val_mse: 0.0134 - 414ms/epoch - 2ms/step
# Epoch 41/100
# 169/169 - 0s - loss: 0.0149 - mse: 0.0149 - val_loss: 0.0133 - val_mse: 0.0133 - 413ms/epoch - 2ms/step
# Epoch 42/100
# 169/169 - 0s - loss: 0.0148 - mse: 0.0148 - val_loss: 0.0132 - val_mse: 0.0132 - 408ms/epoch - 2ms/step
# Epoch 43/100
# 169/169 - 0s - loss: 0.0147 - mse: 0.0147 - val_loss: 0.0131 - val_mse: 0.0131 - 408ms/epoch - 2ms/step
# Epoch 44/100
# 169/169 - 0s - loss: 0.0146 - mse: 0.0146 - val_loss: 0.0130 - val_mse: 0.0130 - 407ms/epoch - 2ms/step
# Epoch 45/100
# 169/169 - 0s - loss: 0.0145 - mse: 0.0145 - val_loss: 0.0129 - val_mse: 0.0129 - 405ms/epoch - 2ms/step
# Epoch 46/100
# 169/169 - 0s - loss: 0.0145 - mse: 0.0145 - val_loss: 0.0128 - val_mse: 0.0128 - 407ms/epoch - 2ms/step
# Epoch 47/100
# 169/169 - 0s - loss: 0.0144 - mse: 0.0144 - val_loss: 0.0127 - val_mse: 0.0127 - 405ms/epoch - 2ms/step
# Epoch 48/100
# 169/169 - 0s - loss: 0.0143 - mse: 0.0143 - val_loss: 0.0126 - val_mse: 0.0126 - 407ms/epoch - 2ms/step
# Epoch 49/100
# 169/169 - 0s - loss: 0.0142 - mse: 0.0142 - val_loss: 0.0125 - val_mse: 0.0125 - 410ms/epoch - 2ms/step
# Epoch 50/100
# 169/169 - 0s - loss: 0.0142 - mse: 0.0142 - val_loss: 0.0125 - val_mse: 0.0125 - 411ms/epoch - 2ms/step
# Epoch 51/100
# 169/169 - 0s - loss: 0.0141 - mse: 0.0141 - val_loss: 0.0124 - val_mse: 0.0124 - 409ms/epoch - 2ms/step
# Epoch 52/100
# 169/169 - 0s - loss: 0.0140 - mse: 0.0140 - val_loss: 0.0123 - val_mse: 0.0123 - 410ms/epoch - 2ms/step
# Epoch 53/100
# 169/169 - 0s - loss: 0.0140 - mse: 0.0140 - val_loss: 0.0122 - val_mse: 0.0122 - 408ms/epoch - 2ms/step
# Epoch 54/100
# 169/169 - 0s - loss: 0.0139 - mse: 0.0139 - val_loss: 0.0121 - val_mse: 0.0121 - 407ms/epoch - 2ms/step
# Epoch 55/100
# 169/169 - 0s - loss: 0.0138 - mse: 0.0138 - val_loss: 0.0121 - val_mse: 0.0121 - 405ms/epoch - 2ms/step
# Epoch 56/100
# 169/169 - 0s - loss: 0.0138 - mse: 0.0138 - val_loss: 0.0120 - val_mse: 0.0120 - 411ms/epoch - 2ms/step
# Epoch 57/100
# 169/169 - 0s - loss: 0.0137 - mse: 0.0137 - val_loss: 0.0119 - val_mse: 0.0119 - 408ms/epoch - 2ms/step
# Epoch 58/100
# 169/169 - 0s - loss: 0.0137 - mse: 0.0137 - val_loss: 0.0119 - val_mse: 0.0119 - 409ms/epoch - 2ms/step
# Epoch 59/100
# 169/169 - 0s - loss: 0.0136 - mse: 0.0136 - val_loss: 0.0118 - val_mse: 0.0118 - 414ms/epoch - 2ms/step
# Epoch 60/100
# 169/169 - 0s - loss: 0.0136 - mse: 0.0136 - val_loss: 0.0117 - val_mse: 0.0117 - 408ms/epoch - 2ms/step
# Epoch 61/100
# 169/169 - 0s - loss: 0.0135 - mse: 0.0135 - val_loss: 0.0117 - val_mse: 0.0117 - 409ms/epoch - 2ms/step
# Epoch 62/100
# 169/169 - 0s - loss: 0.0135 - mse: 0.0135 - val_loss: 0.0116 - val_mse: 0.0116 - 407ms/epoch - 2ms/step
# Epoch 63/100
# 169/169 - 0s - loss: 0.0134 - mse: 0.0134 - val_loss: 0.0115 - val_mse: 0.0115 - 408ms/epoch - 2ms/step
# Epoch 64/100
# 169/169 - 0s - loss: 0.0134 - mse: 0.0134 - val_loss: 0.0115 - val_mse: 0.0115 - 410ms/epoch - 2ms/step
# Epoch 65/100
# 169/169 - 0s - loss: 0.0133 - mse: 0.0133 - val_loss: 0.0114 - val_mse: 0.0114 - 411ms/epoch - 2ms/step
# Epoch 66/100
# 169/169 - 0s - loss: 0.0133 - mse: 0.0133 - val_loss: 0.0114 - val_mse: 0.0114 - 408ms/epoch - 2ms/step
# Epoch 67/100
# 169/169 - 0s - loss: 0.0132 - mse: 0.0132 - val_loss: 0.0113 - val_mse: 0.0113 - 409ms/epoch - 2ms/step
# Epoch 68/100
# 169/169 - 0s - loss: 0.0132 - mse: 0.0132 - val_loss: 0.0113 - val_mse: 0.0113 - 409ms/epoch - 2ms/step
# Epoch 69/100
# 169/169 - 0s - loss: 0.0131 - mse: 0.0131 - val_loss: 0.0112 - val_mse: 0.0112 - 409ms/epoch - 2ms/step
# Epoch 70/100
# 169/169 - 0s - loss: 0.0131 - mse: 0.0131 - val_loss: 0.0112 - val_mse: 0.0112 - 408ms/epoch - 2ms/step
# Epoch 71/100
# 169/169 - 0s - loss: 0.0131 - mse: 0.0131 - val_loss: 0.0111 - val_mse: 0.0111 - 412ms/epoch - 2ms/step
# Epoch 72/100
# 169/169 - 0s - loss: 0.0130 - mse: 0.0130 - val_loss: 0.0111 - val_mse: 0.0111 - 406ms/epoch - 2ms/step
# Epoch 73/100
# 169/169 - 0s - loss: 0.0130 - mse: 0.0130 - val_loss: 0.0110 - val_mse: 0.0110 - 405ms/epoch - 2ms/step
# Epoch 74/100
# 169/169 - 0s - loss: 0.0129 - mse: 0.0129 - val_loss: 0.0110 - val_mse: 0.0110 - 406ms/epoch - 2ms/step
# Epoch 75/100
# 169/169 - 0s - loss: 0.0129 - mse: 0.0129 - val_loss: 0.0109 - val_mse: 0.0109 - 406ms/epoch - 2ms/step
# Epoch 76/100
# 169/169 - 0s - loss: 0.0129 - mse: 0.0129 - val_loss: 0.0109 - val_mse: 0.0109 - 405ms/epoch - 2ms/step
# Epoch 77/100
# 169/169 - 0s - loss: 0.0128 - mse: 0.0128 - val_loss: 0.0109 - val_mse: 0.0109 - 404ms/epoch - 2ms/step
# Epoch 78/100
# 169/169 - 0s - loss: 0.0128 - mse: 0.0128 - val_loss: 0.0108 - val_mse: 0.0108 - 401ms/epoch - 2ms/step
# Epoch 79/100
# 169/169 - 0s - loss: 0.0128 - mse: 0.0128 - val_loss: 0.0108 - val_mse: 0.0108 - 404ms/epoch - 2ms/step
# Epoch 80/100
# 169/169 - 0s - loss: 0.0128 - mse: 0.0128 - val_loss: 0.0108 - val_mse: 0.0108 - 408ms/epoch - 2ms/step
# Epoch 81/100
# 169/169 - 0s - loss: 0.0127 - mse: 0.0127 - val_loss: 0.0107 - val_mse: 0.0107 - 403ms/epoch - 2ms/step
# Epoch 82/100
# 169/169 - 0s - loss: 0.0127 - mse: 0.0127 - val_loss: 0.0107 - val_mse: 0.0107 - 404ms/epoch - 2ms/step
# Epoch 83/100
# 169/169 - 0s - loss: 0.0127 - mse: 0.0127 - val_loss: 0.0107 - val_mse: 0.0107 - 408ms/epoch - 2ms/step
# Epoch 84/100
# 169/169 - 0s - loss: 0.0126 - mse: 0.0126 - val_loss: 0.0106 - val_mse: 0.0106 - 408ms/epoch - 2ms/step
# Epoch 85/100
# 169/169 - 0s - loss: 0.0126 - mse: 0.0126 - val_loss: 0.0106 - val_mse: 0.0106 - 405ms/epoch - 2ms/step
# Epoch 86/100
# 169/169 - 0s - loss: 0.0126 - mse: 0.0126 - val_loss: 0.0106 - val_mse: 0.0106 - 407ms/epoch - 2ms/step
# Epoch 87/100
# 169/169 - 0s - loss: 0.0126 - mse: 0.0126 - val_loss: 0.0105 - val_mse: 0.0105 - 406ms/epoch - 2ms/step
# Epoch 88/100
# 169/169 - 0s - loss: 0.0125 - mse: 0.0125 - val_loss: 0.0105 - val_mse: 0.0105 - 404ms/epoch - 2ms/step
# Epoch 89/100
# 169/169 - 0s - loss: 0.0125 - mse: 0.0125 - val_loss: 0.0105 - val_mse: 0.0105 - 405ms/epoch - 2ms/step
# Epoch 90/100
# 169/169 - 0s - loss: 0.0125 - mse: 0.0125 - val_loss: 0.0104 - val_mse: 0.0104 - 401ms/epoch - 2ms/step
# Epoch 91/100
# 169/169 - 0s - loss: 0.0125 - mse: 0.0125 - val_loss: 0.0104 - val_mse: 0.0104 - 406ms/epoch - 2ms/step
# Epoch 92/100
# 169/169 - 0s - loss: 0.0124 - mse: 0.0124 - val_loss: 0.0104 - val_mse: 0.0104 - 407ms/epoch - 2ms/step
# Epoch 93/100
# 169/169 - 0s - loss: 0.0124 - mse: 0.0124 - val_loss: 0.0104 - val_mse: 0.0104 - 404ms/epoch - 2ms/step
# Epoch 94/100
# 169/169 - 0s - loss: 0.0124 - mse: 0.0124 - val_loss: 0.0103 - val_mse: 0.0103 - 405ms/epoch - 2ms/step
# Epoch 95/100
# 169/169 - 0s - loss: 0.0124 - mse: 0.0124 - val_loss: 0.0103 - val_mse: 0.0103 - 406ms/epoch - 2ms/step
# Epoch 96/100
# 169/169 - 0s - loss: 0.0124 - mse: 0.0124 - val_loss: 0.0103 - val_mse: 0.0103 - 406ms/epoch - 2ms/step
# Epoch 97/100
# 169/169 - 0s - loss: 0.0123 - mse: 0.0123 - val_loss: 0.0103 - val_mse: 0.0103 - 406ms/epoch - 2ms/step
# Epoch 98/100
# 169/169 - 0s - loss: 0.0123 - mse: 0.0123 - val_loss: 0.0102 - val_mse: 0.0102 - 410ms/epoch - 2ms/step
# Epoch 99/100
# 169/169 - 0s - loss: 0.0123 - mse: 0.0123 - val_loss: 0.0102 - val_mse: 0.0102 - 406ms/epoch - 2ms/step
# Epoch 100/100
# 169/169 - 0s - loss: 0.0123 - mse: 0.0123 - val_loss: 0.0102 - val_mse: 0.0102 - 406ms/epoch - 2ms/step
# Epoch 1/100
# 169/169 - 2s - loss: 0.0441 - mse: 0.0441 - val_loss: 0.0304 - val_mse: 0.0304 - 2s/epoch - 10ms/step
# Epoch 2/100
# 169/169 - 0s - loss: 0.0261 - mse: 0.0261 - val_loss: 0.0281 - val_mse: 0.0281 - 414ms/epoch - 2ms/step
# Epoch 3/100
# 169/169 - 0s - loss: 0.0245 - mse: 0.0245 - val_loss: 0.0262 - val_mse: 0.0262 - 413ms/epoch - 2ms/step
# Epoch 4/100
# 169/169 - 0s - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0247 - val_mse: 0.0247 - 414ms/epoch - 2ms/step
# Epoch 5/100
# 169/169 - 0s - loss: 0.0222 - mse: 0.0222 - val_loss: 0.0234 - val_mse: 0.0234 - 412ms/epoch - 2ms/step
# Epoch 6/100
# 169/169 - 0s - loss: 0.0213 - mse: 0.0213 - val_loss: 0.0223 - val_mse: 0.0223 - 417ms/epoch - 2ms/step
# Epoch 7/100
# 169/169 - 0s - loss: 0.0206 - mse: 0.0206 - val_loss: 0.0214 - val_mse: 0.0214 - 415ms/epoch - 2ms/step
# Epoch 8/100
# 169/169 - 0s - loss: 0.0200 - mse: 0.0200 - val_loss: 0.0206 - val_mse: 0.0206 - 418ms/epoch - 2ms/step
# Epoch 9/100
# 169/169 - 0s - loss: 0.0194 - mse: 0.0194 - val_loss: 0.0199 - val_mse: 0.0199 - 416ms/epoch - 2ms/step
# Epoch 10/100
# 169/169 - 0s - loss: 0.0189 - mse: 0.0189 - val_loss: 0.0193 - val_mse: 0.0193 - 416ms/epoch - 2ms/step
# Epoch 11/100
# 169/169 - 0s - loss: 0.0185 - mse: 0.0185 - val_loss: 0.0188 - val_mse: 0.0188 - 410ms/epoch - 2ms/step
# Epoch 12/100
# 169/169 - 0s - loss: 0.0181 - mse: 0.0181 - val_loss: 0.0183 - val_mse: 0.0183 - 410ms/epoch - 2ms/step
# Epoch 13/100
# 169/169 - 0s - loss: 0.0178 - mse: 0.0178 - val_loss: 0.0179 - val_mse: 0.0179 - 414ms/epoch - 2ms/step
# Epoch 14/100
# 169/169 - 0s - loss: 0.0175 - mse: 0.0175 - val_loss: 0.0175 - val_mse: 0.0175 - 412ms/epoch - 2ms/step
# Epoch 15/100
# 169/169 - 0s - loss: 0.0172 - mse: 0.0172 - val_loss: 0.0172 - val_mse: 0.0172 - 416ms/epoch - 2ms/step
# Epoch 16/100
# 169/169 - 0s - loss: 0.0170 - mse: 0.0170 - val_loss: 0.0168 - val_mse: 0.0168 - 413ms/epoch - 2ms/step
# Epoch 17/100
# 169/169 - 0s - loss: 0.0167 - mse: 0.0167 - val_loss: 0.0165 - val_mse: 0.0165 - 414ms/epoch - 2ms/step
# Epoch 18/100
# 169/169 - 0s - loss: 0.0165 - mse: 0.0165 - val_loss: 0.0162 - val_mse: 0.0162 - 414ms/epoch - 2ms/step
# Epoch 19/100
# 169/169 - 0s - loss: 0.0163 - mse: 0.0163 - val_loss: 0.0160 - val_mse: 0.0160 - 411ms/epoch - 2ms/step
# Epoch 20/100
# 169/169 - 0s - loss: 0.0161 - mse: 0.0161 - val_loss: 0.0157 - val_mse: 0.0157 - 408ms/epoch - 2ms/step
# Epoch 21/100
# 169/169 - 0s - loss: 0.0159 - mse: 0.0159 - val_loss: 0.0155 - val_mse: 0.0155 - 411ms/epoch - 2ms/step
# Epoch 22/100
# 169/169 - 0s - loss: 0.0157 - mse: 0.0157 - val_loss: 0.0153 - val_mse: 0.0153 - 411ms/epoch - 2ms/step
# Epoch 23/100
# 169/169 - 0s - loss: 0.0155 - mse: 0.0155 - val_loss: 0.0150 - val_mse: 0.0150 - 420ms/epoch - 2ms/step
# Epoch 24/100
# 169/169 - 0s - loss: 0.0154 - mse: 0.0154 - val_loss: 0.0148 - val_mse: 0.0148 - 413ms/epoch - 2ms/step
# Epoch 25/100
# 169/169 - 0s - loss: 0.0152 - mse: 0.0152 - val_loss: 0.0146 - val_mse: 0.0146 - 413ms/epoch - 2ms/step
# Epoch 26/100
# 169/169 - 0s - loss: 0.0150 - mse: 0.0150 - val_loss: 0.0144 - val_mse: 0.0144 - 411ms/epoch - 2ms/step
# Epoch 27/100
# 169/169 - 0s - loss: 0.0149 - mse: 0.0149 - val_loss: 0.0143 - val_mse: 0.0143 - 411ms/epoch - 2ms/step
# Epoch 28/100
# 169/169 - 0s - loss: 0.0147 - mse: 0.0147 - val_loss: 0.0141 - val_mse: 0.0141 - 410ms/epoch - 2ms/step
# Epoch 29/100
# 169/169 - 0s - loss: 0.0146 - mse: 0.0146 - val_loss: 0.0139 - val_mse: 0.0139 - 407ms/epoch - 2ms/step
# Epoch 30/100
# 169/169 - 0s - loss: 0.0145 - mse: 0.0145 - val_loss: 0.0137 - val_mse: 0.0137 - 413ms/epoch - 2ms/step
# Epoch 31/100
# 169/169 - 0s - loss: 0.0143 - mse: 0.0143 - val_loss: 0.0136 - val_mse: 0.0136 - 410ms/epoch - 2ms/step
# Epoch 32/100
# 169/169 - 0s - loss: 0.0142 - mse: 0.0142 - val_loss: 0.0134 - val_mse: 0.0134 - 412ms/epoch - 2ms/step
# Epoch 33/100
# 169/169 - 0s - loss: 0.0141 - mse: 0.0141 - val_loss: 0.0133 - val_mse: 0.0133 - 410ms/epoch - 2ms/step
# Epoch 34/100
# 169/169 - 0s - loss: 0.0139 - mse: 0.0139 - val_loss: 0.0131 - val_mse: 0.0131 - 407ms/epoch - 2ms/step
# Epoch 35/100
# 169/169 - 0s - loss: 0.0138 - mse: 0.0138 - val_loss: 0.0130 - val_mse: 0.0130 - 412ms/epoch - 2ms/step
# Epoch 36/100
# 169/169 - 0s - loss: 0.0137 - mse: 0.0137 - val_loss: 0.0129 - val_mse: 0.0129 - 410ms/epoch - 2ms/step
# Epoch 37/100
# 169/169 - 0s - loss: 0.0136 - mse: 0.0136 - val_loss: 0.0127 - val_mse: 0.0127 - 407ms/epoch - 2ms/step
# Epoch 38/100
# 169/169 - 0s - loss: 0.0135 - mse: 0.0135 - val_loss: 0.0126 - val_mse: 0.0126 - 410ms/epoch - 2ms/step
# Epoch 39/100
# 169/169 - 0s - loss: 0.0134 - mse: 0.0134 - val_loss: 0.0125 - val_mse: 0.0125 - 403ms/epoch - 2ms/step
# Epoch 40/100
# 169/169 - 0s - loss: 0.0133 - mse: 0.0133 - val_loss: 0.0123 - val_mse: 0.0123 - 406ms/epoch - 2ms/step
# Epoch 41/100
# 169/169 - 0s - loss: 0.0132 - mse: 0.0132 - val_loss: 0.0122 - val_mse: 0.0122 - 405ms/epoch - 2ms/step
# Epoch 42/100
# 169/169 - 0s - loss: 0.0131 - mse: 0.0131 - val_loss: 0.0121 - val_mse: 0.0121 - 406ms/epoch - 2ms/step
# Epoch 43/100
# 169/169 - 0s - loss: 0.0130 - mse: 0.0130 - val_loss: 0.0120 - val_mse: 0.0120 - 406ms/epoch - 2ms/step
# Epoch 44/100
# 169/169 - 0s - loss: 0.0129 - mse: 0.0129 - val_loss: 0.0119 - val_mse: 0.0119 - 407ms/epoch - 2ms/step
# Epoch 45/100
# 169/169 - 0s - loss: 0.0128 - mse: 0.0128 - val_loss: 0.0118 - val_mse: 0.0118 - 406ms/epoch - 2ms/step
# Epoch 46/100
# 169/169 - 0s - loss: 0.0127 - mse: 0.0127 - val_loss: 0.0117 - val_mse: 0.0117 - 412ms/epoch - 2ms/step
# Epoch 47/100
# 169/169 - 0s - loss: 0.0127 - mse: 0.0127 - val_loss: 0.0116 - val_mse: 0.0116 - 409ms/epoch - 2ms/step
# Epoch 48/100
# 169/169 - 0s - loss: 0.0126 - mse: 0.0126 - val_loss: 0.0115 - val_mse: 0.0115 - 411ms/epoch - 2ms/step
# Epoch 49/100
# 169/169 - 0s - loss: 0.0125 - mse: 0.0125 - val_loss: 0.0114 - val_mse: 0.0114 - 405ms/epoch - 2ms/step
# Epoch 50/100
# 169/169 - 0s - loss: 0.0124 - mse: 0.0124 - val_loss: 0.0113 - val_mse: 0.0113 - 408ms/epoch - 2ms/step
# Epoch 51/100
# 169/169 - 0s - loss: 0.0124 - mse: 0.0124 - val_loss: 0.0113 - val_mse: 0.0113 - 408ms/epoch - 2ms/step
# Epoch 52/100
# 169/169 - 0s - loss: 0.0123 - mse: 0.0123 - val_loss: 0.0112 - val_mse: 0.0112 - 409ms/epoch - 2ms/step
# Epoch 53/100
# 169/169 - 0s - loss: 0.0122 - mse: 0.0122 - val_loss: 0.0111 - val_mse: 0.0111 - 407ms/epoch - 2ms/step
# Epoch 54/100
# 169/169 - 0s - loss: 0.0122 - mse: 0.0122 - val_loss: 0.0110 - val_mse: 0.0110 - 411ms/epoch - 2ms/step
# Epoch 55/100
# 169/169 - 0s - loss: 0.0121 - mse: 0.0121 - val_loss: 0.0109 - val_mse: 0.0109 - 411ms/epoch - 2ms/step
# Epoch 56/100
# 169/169 - 0s - loss: 0.0120 - mse: 0.0120 - val_loss: 0.0109 - val_mse: 0.0109 - 417ms/epoch - 2ms/step
# Epoch 57/100
# 169/169 - 0s - loss: 0.0120 - mse: 0.0120 - val_loss: 0.0108 - val_mse: 0.0108 - 414ms/epoch - 2ms/step
# Epoch 58/100
# 169/169 - 0s - loss: 0.0119 - mse: 0.0119 - val_loss: 0.0107 - val_mse: 0.0107 - 414ms/epoch - 2ms/step
# Epoch 59/100
# 169/169 - 0s - loss: 0.0119 - mse: 0.0119 - val_loss: 0.0107 - val_mse: 0.0107 - 415ms/epoch - 2ms/step
# Epoch 60/100
# 169/169 - 0s - loss: 0.0118 - mse: 0.0118 - val_loss: 0.0106 - val_mse: 0.0106 - 415ms/epoch - 2ms/step
# Epoch 61/100
# 169/169 - 0s - loss: 0.0118 - mse: 0.0118 - val_loss: 0.0106 - val_mse: 0.0106 - 417ms/epoch - 2ms/step
# Epoch 62/100
# 169/169 - 0s - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0105 - val_mse: 0.0105 - 417ms/epoch - 2ms/step
# Epoch 63/100
# 169/169 - 0s - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0105 - val_mse: 0.0105 - 414ms/epoch - 2ms/step
# Epoch 64/100
# 169/169 - 0s - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0104 - val_mse: 0.0104 - 415ms/epoch - 2ms/step
# Epoch 65/100
# 169/169 - 0s - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0104 - val_mse: 0.0104 - 412ms/epoch - 2ms/step
# Epoch 66/100
# 169/169 - 0s - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0103 - val_mse: 0.0103 - 417ms/epoch - 2ms/step
# Epoch 67/100
# 169/169 - 0s - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0103 - val_mse: 0.0103 - 414ms/epoch - 2ms/step
# Epoch 68/100
# 169/169 - 0s - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0102 - val_mse: 0.0102 - 418ms/epoch - 2ms/step
# Epoch 69/100
# 169/169 - 0s - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0102 - val_mse: 0.0102 - 418ms/epoch - 2ms/step
# Epoch 70/100
# 169/169 - 0s - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0101 - val_mse: 0.0101 - 415ms/epoch - 2ms/step
# Epoch 71/100
# 169/169 - 0s - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0101 - val_mse: 0.0101 - 411ms/epoch - 2ms/step
# Epoch 72/100
# 169/169 - 0s - loss: 0.0113 - mse: 0.0113 - val_loss: 0.0101 - val_mse: 0.0101 - 409ms/epoch - 2ms/step
# Epoch 73/100
# 169/169 - 0s - loss: 0.0113 - mse: 0.0113 - val_loss: 0.0100 - val_mse: 0.0100 - 410ms/epoch - 2ms/step
# Epoch 74/100
# 169/169 - 0s - loss: 0.0113 - mse: 0.0113 - val_loss: 0.0100 - val_mse: 0.0100 - 412ms/epoch - 2ms/step
# Epoch 75/100
# 169/169 - 0s - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0099 - val_mse: 0.0099 - 411ms/epoch - 2ms/step
# Epoch 76/100
# 169/169 - 0s - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0099 - val_mse: 0.0099 - 411ms/epoch - 2ms/step
# Epoch 77/100
# 169/169 - 0s - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0099 - val_mse: 0.0099 - 414ms/epoch - 2ms/step
# Epoch 78/100
# 169/169 - 0s - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0099 - val_mse: 0.0099 - 411ms/epoch - 2ms/step
# Epoch 79/100
# 169/169 - 0s - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0098 - val_mse: 0.0098 - 413ms/epoch - 2ms/step
# Epoch 80/100
# 169/169 - 0s - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0098 - val_mse: 0.0098 - 413ms/epoch - 2ms/step
# Epoch 81/100
# 169/169 - 0s - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0098 - val_mse: 0.0098 - 411ms/epoch - 2ms/step
# Epoch 82/100
# 169/169 - 0s - loss: 0.0110 - mse: 0.0110 - val_loss: 0.0097 - val_mse: 0.0097 - 412ms/epoch - 2ms/step
# Epoch 83/100
# 169/169 - 0s - loss: 0.0110 - mse: 0.0110 - val_loss: 0.0097 - val_mse: 0.0097 - 408ms/epoch - 2ms/step
# Epoch 84/100
# 169/169 - 0s - loss: 0.0110 - mse: 0.0110 - val_loss: 0.0097 - val_mse: 0.0097 - 413ms/epoch - 2ms/step
# Epoch 85/100
# 169/169 - 0s - loss: 0.0110 - mse: 0.0110 - val_loss: 0.0097 - val_mse: 0.0097 - 414ms/epoch - 2ms/step
# Epoch 86/100
# 169/169 - 0s - loss: 0.0109 - mse: 0.0109 - val_loss: 0.0096 - val_mse: 0.0096 - 409ms/epoch - 2ms/step
# Epoch 87/100
# 169/169 - 0s - loss: 0.0109 - mse: 0.0109 - val_loss: 0.0096 - val_mse: 0.0096 - 411ms/epoch - 2ms/step
# Epoch 88/100
# 169/169 - 0s - loss: 0.0109 - mse: 0.0109 - val_loss: 0.0096 - val_mse: 0.0096 - 412ms/epoch - 2ms/step
# Epoch 89/100
# 169/169 - 0s - loss: 0.0109 - mse: 0.0109 - val_loss: 0.0096 - val_mse: 0.0096 - 412ms/epoch - 2ms/step
# Epoch 90/100
# 169/169 - 0s - loss: 0.0109 - mse: 0.0109 - val_loss: 0.0096 - val_mse: 0.0096 - 414ms/epoch - 2ms/step
# Epoch 91/100
# 169/169 - 0s - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0095 - val_mse: 0.0095 - 400ms/epoch - 2ms/step
# Epoch 92/100
# 169/169 - 0s - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0095 - val_mse: 0.0095 - 397ms/epoch - 2ms/step
# Epoch 93/100
# 169/169 - 0s - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0095 - val_mse: 0.0095 - 400ms/epoch - 2ms/step
# Epoch 94/100
# 169/169 - 0s - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0095 - val_mse: 0.0095 - 400ms/epoch - 2ms/step
# Epoch 95/100
# 169/169 - 0s - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0095 - val_mse: 0.0095 - 397ms/epoch - 2ms/step
# Epoch 96/100
# 169/169 - 0s - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0094 - val_mse: 0.0094 - 398ms/epoch - 2ms/step
# Epoch 97/100
# 169/169 - 0s - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0094 - val_mse: 0.0094 - 401ms/epoch - 2ms/step
# Epoch 98/100
# 169/169 - 0s - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0094 - val_mse: 0.0094 - 400ms/epoch - 2ms/step
# Epoch 99/100
# 169/169 - 0s - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0094 - val_mse: 0.0094 - 412ms/epoch - 2ms/step
# Epoch 100/100
# 169/169 - 0s - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0094 - val_mse: 0.0094 - 407ms/epoch - 2ms/step
# Epoch 1/100
# 169/169 - 2s - loss: 0.0346 - mse: 0.0346 - val_loss: 0.0193 - val_mse: 0.0193 - 2s/epoch - 11ms/step
# Epoch 2/100
# 169/169 - 0s - loss: 0.0197 - mse: 0.0197 - val_loss: 0.0185 - val_mse: 0.0185 - 407ms/epoch - 2ms/step
# Epoch 3/100
# 169/169 - 0s - loss: 0.0192 - mse: 0.0192 - val_loss: 0.0179 - val_mse: 0.0179 - 413ms/epoch - 2ms/step
# Epoch 4/100
# 169/169 - 0s - loss: 0.0187 - mse: 0.0187 - val_loss: 0.0173 - val_mse: 0.0173 - 413ms/epoch - 2ms/step
# Epoch 5/100
# 169/169 - 0s - loss: 0.0183 - mse: 0.0183 - val_loss: 0.0168 - val_mse: 0.0168 - 409ms/epoch - 2ms/step
# Epoch 6/100
# 169/169 - 0s - loss: 0.0179 - mse: 0.0179 - val_loss: 0.0163 - val_mse: 0.0163 - 409ms/epoch - 2ms/step
# Epoch 7/100
# 169/169 - 0s - loss: 0.0175 - mse: 0.0175 - val_loss: 0.0159 - val_mse: 0.0159 - 410ms/epoch - 2ms/step
# Epoch 8/100
# 169/169 - 0s - loss: 0.0172 - mse: 0.0172 - val_loss: 0.0155 - val_mse: 0.0155 - 408ms/epoch - 2ms/step
# Epoch 9/100
# 169/169 - 0s - loss: 0.0169 - mse: 0.0169 - val_loss: 0.0151 - val_mse: 0.0151 - 413ms/epoch - 2ms/step
# Epoch 10/100
# 169/169 - 0s - loss: 0.0167 - mse: 0.0167 - val_loss: 0.0148 - val_mse: 0.0148 - 405ms/epoch - 2ms/step
# Epoch 11/100
# ...
# Epoch 65/100
# 169/169 - 0s - loss: 0.0119 - mse: 0.0119 - val_loss: 0.0092 - val_mse: 0.0092 - 397ms/epoch - 2ms/step
# Epoch 66/100
# 169/169 - 0s - loss: 0.0119 - mse: 0.0119 - val_loss: 0.0092 - val_mse: 0.0092 - 396ms/epoch - 2ms/step
# Epoch 67/100
# 169/169 - 0s - loss: 0.0119 - mse: 0.0119 - val_loss: 0.0092 - val_mse: 0.0092 - 403ms/epoch - 2ms/step
# Epoch 68/100
# 169/169 - 0s - loss: 0.0118 - mse: 0.0118 - val_loss: 0.0091 - val_mse: 0.0091 - 401ms/epoch - 2ms/step
# Epoch 69/100
# 169/169 - 0s - loss: 0.0118 - mse: 0.0118 - val_loss: 0.0091 - val_mse: 0.0091 - 403ms/epoch - 2ms/step
# Epoch 70/100
# 169/169 - 0s - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0090 - val_mse: 0.0090 - 397ms/epoch - 2ms/step
# Epoch 71/100
# 169/169 - 0s - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0090 - val_mse: 0.0090 - 397ms/epoch - 2ms/step
# Epoch 72/100
# 169/169 - 0s - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0090 - val_mse: 0.0090 - 400ms/epoch - 2ms/step
# Epoch 73/100
# 169/169 - 0s - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0089 - val_mse: 0.0089 - 404ms/epoch - 2ms/step
# Epoch 74/100
# 169/169 - 0s - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0089 - val_mse: 0.0089 - 395ms/epoch - 2ms/step
# Epoch 75/100
# 169/169 - 0s - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0089 - val_mse: 0.0089 - 390ms/epoch - 2ms/step
# Epoch 76/100
# 169/169 - 0s - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0088 - val_mse: 0.0088 - 394ms/epoch - 2ms/step
# Epoch 77/100
# 169/169 - 0s - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0088 - val_mse: 0.0088 - 394ms/epoch - 2ms/step
# Epoch 78/100
# 169/169 - 0s - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0088 - val_mse: 0.0088 - 400ms/epoch - 2ms/step
# Epoch 79/100
# 169/169 - 0s - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0087 - val_mse: 0.0087 - 399ms/epoch - 2ms/step
# Epoch 80/100
# 169/169 - 0s - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0087 - val_mse: 0.0087 - 397ms/epoch - 2ms/step
# Epoch 81/100
# 169/169 - 0s - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0087 - val_mse: 0.0087 - 400ms/epoch - 2ms/step
# Epoch 82/100
# 169/169 - 0s - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0087 - val_mse: 0.0087 - 394ms/epoch - 2ms/step
# Epoch 83/100
# 169/169 - 0s - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0086 - val_mse: 0.0086 - 404ms/epoch - 2ms/step
# Epoch 84/100
# 169/169 - 0s - loss: 0.0113 - mse: 0.0113 - val_loss: 0.0086 - val_mse: 0.0086 - 403ms/epoch - 2ms/step
# Epoch 85/100
# 169/169 - 0s - loss: 0.0113 - mse: 0.0113 - val_loss: 0.0086 - val_mse: 0.0086 - 400ms/epoch - 2ms/step
# Epoch 86/100
# 169/169 - 0s - loss: 0.0113 - mse: 0.0113 - val_loss: 0.0086 - val_mse: 0.0086 - 397ms/epoch - 2ms/step
# Epoch 87/100
# 169/169 - 0s - loss: 0.0113 - mse: 0.0113 - val_loss: 0.0085 - val_mse: 0.0085 - 400ms/epoch - 2ms/step
# Epoch 88/100
# 169/169 - 0s - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0085 - val_mse: 0.0085 - 399ms/epoch - 2ms/step
# Epoch 89/100
# 169/169 - 0s - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0085 - val_mse: 0.0085 - 393ms/epoch - 2ms/step
# Epoch 90/100
# 169/169 - 0s - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0085 - val_mse: 0.0085 - 395ms/epoch - 2ms/step
# Epoch 91/100
# 169/169 - 0s - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0084 - val_mse: 0.0084 - 404ms/epoch - 2ms/step
# Epoch 92/100
# 169/169 - 0s - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0084 - val_mse: 0.0084 - 397ms/epoch - 2ms/step
# Epoch 93/100
# 169/169 - 0s - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0084 - val_mse: 0.0084 - 398ms/epoch - 2ms/step
# Epoch 94/100
# 169/169 - 0s - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0084 - val_mse: 0.0084 - 396ms/epoch - 2ms/step
# Epoch 95/100
# 169/169 - 0s - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0083 - val_mse: 0.0083 - 399ms/epoch - 2ms/step
# Epoch 96/100
# 169/169 - 0s - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0083 - val_mse: 0.0083 - 401ms/epoch - 2ms/step
# Epoch 97/100
# 169/169 - 0s - loss: 0.0110 - mse: 0.0110 - val_loss: 0.0083 - val_mse: 0.0083 - 398ms/epoch - 2ms/step
# Epoch 98/100
# 169/169 - 0s - loss: 0.0110 - mse: 0.0110 - val_loss: 0.0083 - val_mse: 0.0083 - 400ms/epoch - 2ms/step
# Epoch 99/100
# 169/169 - 0s - loss: 0.0110 - mse: 0.0110 - val_loss: 0.0083 - val_mse: 0.0083 - 397ms/epoch - 2ms/step
# Epoch 100/100
# 169/169 - 0s - loss: 0.0110 - mse: 0.0110 - val_loss: 0.0082 - val_mse: 0.0082 - 397ms/epoch - 2ms/step
# Epoch 1/100
# 169/169 - 2s - loss: 0.0325 - mse: 0.0325 - val_loss: 0.0162 - val_mse: 0.0162 - 2s/epoch - 10ms/step
# Epoch 2/100
# 169/169 - 0s - loss: 0.0168 - mse: 0.0168 - val_loss: 0.0156 - val_mse: 0.0156 - 402ms/epoch - 2ms/step
# Epoch 3/100
# 169/169 - 0s - loss: 0.0163 - mse: 0.0163 - val_loss: 0.0151 - val_mse: 0.0151 - 400ms/epoch - 2ms/step
# Epoch 4/100
# 169/169 - 0s - loss: 0.0159 - mse: 0.0159 - val_loss: 0.0146 - val_mse: 0.0146 - 400ms/epoch - 2ms/step
# Epoch 5/100
# 169/169 - 0s - loss: 0.0155 - mse: 0.0155 - val_loss: 0.0142 - val_mse: 0.0142 - 400ms/epoch - 2ms/step
# Epoch 6/100
# 169/169 - 0s - loss: 0.0152 - mse: 0.0152 - val_loss: 0.0138 - val_mse: 0.0138 - 399ms/epoch - 2ms/step
# Epoch 7/100
# 169/169 - 0s - loss: 0.0149 - mse: 0.0149 - val_loss: 0.0134 - val_mse: 0.0134 - 397ms/epoch - 2ms/step
# Epoch 8/100
# 169/169 - 0s - loss: 0.0146 - mse: 0.0146 - val_loss: 0.0131 - val_mse: 0.0131 - 400ms/epoch - 2ms/step
# Epoch 9/100
# 169/169 - 0s - loss: 0.0144 - mse: 0.0144 - val_loss: 0.0128 - val_mse: 0.0128 - 397ms/epoch - 2ms/step
# Epoch 10/100
# 169/169 - 0s - loss: 0.0141 - mse: 0.0141 - val_loss: 0.0126 - val_mse: 0.0126 - 401ms/epoch - 2ms/step
# Epoch 11/100
# 169/169 - 0s - loss: 0.0139 - mse: 0.0139 - val_loss: 0.0123 - val_mse: 0.0123 - 401ms/epoch - 2ms/step
# Epoch 12/100
# 169/169 - 0s - loss: 0.0137 - mse: 0.0137 - val_loss: 0.0121 - val_mse: 0.0121 - 404ms/epoch - 2ms/step
# Epoch 13/100
# 169/169 - 0s - loss: 0.0135 - mse: 0.0135 - val_loss: 0.0119 - val_mse: 0.0119 - 403ms/epoch - 2ms/step
# Epoch 14/100
# 169/169 - 0s - loss: 0.0134 - mse: 0.0134 - val_loss: 0.0117 - val_mse: 0.0117 - 410ms/epoch - 2ms/step
# Epoch 15/100
# 169/169 - 0s - loss: 0.0132 - mse: 0.0132 - val_loss: 0.0115 - val_mse: 0.0115 - 406ms/epoch - 2ms/step
# Epoch 16/100
# 169/169 - 0s - loss: 0.0131 - mse: 0.0131 - val_loss: 0.0114 - val_mse: 0.0114 - 399ms/epoch - 2ms/step
# Epoch 17/100
# 169/169 - 0s - loss: 0.0129 - mse: 0.0129 - val_loss: 0.0112 - val_mse: 0.0112 - 403ms/epoch - 2ms/step
# Epoch 18/100
# 169/169 - 0s - loss: 0.0128 - mse: 0.0128 - val_loss: 0.0111 - val_mse: 0.0111 - 404ms/epoch - 2ms/step
# Epoch 19/100
# 169/169 - 0s - loss: 0.0127 - mse: 0.0127 - val_loss: 0.0109 - val_mse: 0.0109 - 404ms/epoch - 2ms/step
# Epoch 20/100
# 169/169 - 0s - loss: 0.0126 - mse: 0.0126 - val_loss: 0.0108 - val_mse: 0.0108 - 403ms/epoch - 2ms/step
# Epoch 21/100
# 169/169 - 0s - loss: 0.0125 - mse: 0.0125 - val_loss: 0.0107 - val_mse: 0.0107 - 402ms/epoch - 2ms/step
# Epoch 22/100
# 169/169 - 0s - loss: 0.0124 - mse: 0.0124 - val_loss: 0.0106 - val_mse: 0.0106 - 398ms/epoch - 2ms/step
# Epoch 23/100
# 169/169 - 0s - loss: 0.0123 - mse: 0.0123 - val_loss: 0.0104 - val_mse: 0.0104 - 402ms/epoch - 2ms/step
# Epoch 24/100
# 169/169 - 0s - loss: 0.0122 - mse: 0.0122 - val_loss: 0.0103 - val_mse: 0.0103 - 400ms/epoch - 2ms/step
# Epoch 25/100
# 169/169 - 0s - loss: 0.0121 - mse: 0.0121 - val_loss: 0.0102 - val_mse: 0.0102 - 399ms/epoch - 2ms/step
# Epoch 26/100
# 169/169 - 0s - loss: 0.0120 - mse: 0.0120 - val_loss: 0.0101 - val_mse: 0.0101 - 406ms/epoch - 2ms/step
# Epoch 27/100
# 169/169 - 0s - loss: 0.0119 - mse: 0.0119 - val_loss: 0.0100 - val_mse: 0.0100 - 403ms/epoch - 2ms/step
# Epoch 28/100
# 169/169 - 0s - loss: 0.0118 - mse: 0.0118 - val_loss: 0.0099 - val_mse: 0.0099 - 400ms/epoch - 2ms/step
# Epoch 29/100
# 169/169 - 0s - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0098 - val_mse: 0.0098 - 403ms/epoch - 2ms/step
# Epoch 30/100
# 169/169 - 0s - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0097 - val_mse: 0.0097 - 407ms/epoch - 2ms/step
# Epoch 31/100
# 169/169 - 0s - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0097 - val_mse: 0.0097 - 404ms/epoch - 2ms/step
# Epoch 32/100
# 169/169 - 0s - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0096 - val_mse: 0.0096 - 405ms/epoch - 2ms/step
# Epoch 33/100
# 169/169 - 0s - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0095 - val_mse: 0.0095 - 402ms/epoch - 2ms/step
# Epoch 34/100
# 169/169 - 0s - loss: 0.0113 - mse: 0.0113 - val_loss: 0.0094 - val_mse: 0.0094 - 404ms/epoch - 2ms/step
# Epoch 35/100
# 169/169 - 0s - loss: 0.0113 - mse: 0.0113 - val_loss: 0.0093 - val_mse: 0.0093 - 402ms/epoch - 2ms/step
# Epoch 36/100
# 169/169 - 0s - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0093 - val_mse: 0.0093 - 402ms/epoch - 2ms/step
# Epoch 37/100
# 169/169 - 0s - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0092 - val_mse: 0.0092 - 402ms/epoch - 2ms/step
# Epoch 38/100
# 169/169 - 0s - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0091 - val_mse: 0.0091 - 400ms/epoch - 2ms/step
# Epoch 39/100
# 169/169 - 0s - loss: 0.0110 - mse: 0.0110 - val_loss: 0.0091 - val_mse: 0.0091 - 395ms/epoch - 2ms/step
# Epoch 40/100
# 169/169 - 0s - loss: 0.0109 - mse: 0.0109 - val_loss: 0.0090 - val_mse: 0.0090 - 394ms/epoch - 2ms/step
# Epoch 41/100
# 169/169 - 0s - loss: 0.0109 - mse: 0.0109 - val_loss: 0.0089 - val_mse: 0.0089 - 396ms/epoch - 2ms/step
# Epoch 42/100
# 169/169 - 0s - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0089 - val_mse: 0.0089 - 397ms/epoch - 2ms/step
# Epoch 43/100
# 169/169 - 0s - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0088 - val_mse: 0.0088 - 400ms/epoch - 2ms/step
# Epoch 44/100
# 169/169 - 0s - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0087 - val_mse: 0.0087 - 402ms/epoch - 2ms/step
# Epoch 45/100
# 169/169 - 0s - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0087 - val_mse: 0.0087 - 405ms/epoch - 2ms/step
# Epoch 46/100
# 169/169 - 0s - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0086 - val_mse: 0.0086 - 396ms/epoch - 2ms/step
# Epoch 47/100
# 169/169 - 0s - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0086 - val_mse: 0.0086 - 397ms/epoch - 2ms/step
# Epoch 48/100
# 169/169 - 0s - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0085 - val_mse: 0.0085 - 394ms/epoch - 2ms/step
# Epoch 49/100
# 169/169 - 0s - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0085 - val_mse: 0.0085 - 396ms/epoch - 2ms/step
# Epoch 50/100
# 169/169 - 0s - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0084 - val_mse: 0.0084 - 398ms/epoch - 2ms/step
# Epoch 51/100
# 169/169 - 0s - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0084 - val_mse: 0.0084 - 395ms/epoch - 2ms/step
# Epoch 52/100
# 169/169 - 0s - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0083 - val_mse: 0.0083 - 395ms/epoch - 2ms/step
# Epoch 53/100
# 169/169 - 0s - loss: 0.0102 - mse: 0.0102 - val_loss: 0.0083 - val_mse: 0.0083 - 394ms/epoch - 2ms/step
# Epoch 54/100
# 169/169 - 0s - loss: 0.0102 - mse: 0.0102 - val_loss: 0.0082 - val_mse: 0.0082 - 396ms/epoch - 2ms/step
# Epoch 55/100
# 169/169 - 0s - loss: 0.0101 - mse: 0.0101 - val_loss: 0.0082 - val_mse: 0.0082 - 397ms/epoch - 2ms/step
# Epoch 56/100
# 169/169 - 0s - loss: 0.0101 - mse: 0.0101 - val_loss: 0.0081 - val_mse: 0.0081 - 414ms/epoch - 2ms/step
# Epoch 57/100
# 169/169 - 0s - loss: 0.0100 - mse: 0.0100 - val_loss: 0.0081 - val_mse: 0.0081 - 398ms/epoch - 2ms/step
# Epoch 58/100
# 169/169 - 0s - loss: 0.0100 - mse: 0.0100 - val_loss: 0.0080 - val_mse: 0.0080 - 397ms/epoch - 2ms/step
# Epoch 59/100
# 169/169 - 0s - loss: 0.0100 - mse: 0.0100 - val_loss: 0.0080 - val_mse: 0.0080 - 396ms/epoch - 2ms/step
# Epoch 60/100
# 169/169 - 0s - loss: 0.0099 - mse: 0.0099 - val_loss: 0.0080 - val_mse: 0.0080 - 404ms/epoch - 2ms/step
# Epoch 61/100
# 169/169 - 0s - loss: 0.0099 - mse: 0.0099 - val_loss: 0.0079 - val_mse: 0.0079 - 398ms/epoch - 2ms/step
# Epoch 62/100
# 169/169 - 0s - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0079 - val_mse: 0.0079 - 400ms/epoch - 2ms/step
# Epoch 63/100
# 169/169 - 0s - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0078 - val_mse: 0.0078 - 397ms/epoch - 2ms/step
# Epoch 64/100
# 169/169 - 0s - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0078 - val_mse: 0.0078 - 395ms/epoch - 2ms/step
# Epoch 65/100
# 169/169 - 0s - loss: 0.0097 - mse: 0.0097 - val_loss: 0.0078 - val_mse: 0.0078 - 397ms/epoch - 2ms/step
# Epoch 66/100
# 169/169 - 0s - loss: 0.0097 - mse: 0.0097 - val_loss: 0.0077 - val_mse: 0.0077 - 395ms/epoch - 2ms/step
# Epoch 67/100
# 169/169 - 0s - loss: 0.0096 - mse: 0.0096 - val_loss: 0.0077 - val_mse: 0.0077 - 394ms/epoch - 2ms/step
# Epoch 68/100
# 169/169 - 0s - loss: 0.0096 - mse: 0.0096 - val_loss: 0.0077 - val_mse: 0.0077 - 399ms/epoch - 2ms/step
# Epoch 69/100
# 169/169 - 0s - loss: 0.0096 - mse: 0.0096 - val_loss: 0.0076 - val_mse: 0.0076 - 401ms/epoch - 2ms/step
# Epoch 70/100
# 169/169 - 0s - loss: 0.0095 - mse: 0.0095 - val_loss: 0.0076 - val_mse: 0.0076 - 403ms/epoch - 2ms/step
# Epoch 71/100
# 169/169 - 0s - loss: 0.0095 - mse: 0.0095 - val_loss: 0.0076 - val_mse: 0.0076 - 401ms/epoch - 2ms/step
# Epoch 72/100
# 169/169 - 0s - loss: 0.0095 - mse: 0.0095 - val_loss: 0.0075 - val_mse: 0.0075 - 397ms/epoch - 2ms/step
# Epoch 73/100
# 169/169 - 0s - loss: 0.0094 - mse: 0.0094 - val_loss: 0.0075 - val_mse: 0.0075 - 397ms/epoch - 2ms/step
# Epoch 74/100
# 169/169 - 0s - loss: 0.0094 - mse: 0.0094 - val_loss: 0.0075 - val_mse: 0.0075 - 410ms/epoch - 2ms/step
# Epoch 75/100
# 169/169 - 0s - loss: 0.0094 - mse: 0.0094 - val_loss: 0.0075 - val_mse: 0.0075 - 407ms/epoch - 2ms/step
# Epoch 76/100
# 169/169 - 0s - loss: 0.0094 - mse: 0.0094 - val_loss: 0.0074 - val_mse: 0.0074 - 409ms/epoch - 2ms/step
# Epoch 77/100
# 169/169 - 0s - loss: 0.0093 - mse: 0.0093 - val_loss: 0.0074 - val_mse: 0.0074 - 407ms/epoch - 2ms/step
# Epoch 78/100
# 169/169 - 0s - loss: 0.0093 - mse: 0.0093 - val_loss: 0.0074 - val_mse: 0.0074 - 407ms/epoch - 2ms/step
# Epoch 79/100
# 169/169 - 0s - loss: 0.0093 - mse: 0.0093 - val_loss: 0.0074 - val_mse: 0.0074 - 408ms/epoch - 2ms/step
# Epoch 80/100
# 169/169 - 0s - loss: 0.0093 - mse: 0.0093 - val_loss: 0.0073 - val_mse: 0.0073 - 407ms/epoch - 2ms/step
# Epoch 81/100
# 169/169 - 0s - loss: 0.0092 - mse: 0.0092 - val_loss: 0.0073 - val_mse: 0.0073 - 408ms/epoch - 2ms/step
# Epoch 82/100
# 169/169 - 0s - loss: 0.0092 - mse: 0.0092 - val_loss: 0.0073 - val_mse: 0.0073 - 408ms/epoch - 2ms/step
# Epoch 83/100
# 169/169 - 0s - loss: 0.0092 - mse: 0.0092 - val_loss: 0.0073 - val_mse: 0.0073 - 406ms/epoch - 2ms/step
# Epoch 84/100
# 169/169 - 0s - loss: 0.0092 - mse: 0.0092 - val_loss: 0.0072 - val_mse: 0.0072 - 411ms/epoch - 2ms/step
# Epoch 85/100
# 169/169 - 0s - loss: 0.0091 - mse: 0.0091 - val_loss: 0.0072 - val_mse: 0.0072 - 407ms/epoch - 2ms/step
# Epoch 86/100
# 169/169 - 0s - loss: 0.0091 - mse: 0.0091 - val_loss: 0.0072 - val_mse: 0.0072 - 409ms/epoch - 2ms/step
# Epoch 87/100
# 169/169 - 0s - loss: 0.0091 - mse: 0.0091 - val_loss: 0.0072 - val_mse: 0.0072 - 409ms/epoch - 2ms/step
# Epoch 88/100
# 169/169 - 0s - loss: 0.0091 - mse: 0.0091 - val_loss: 0.0071 - val_mse: 0.0071 - 413ms/epoch - 2ms/step
# Epoch 89/100
# 169/169 - 0s - loss: 0.0091 - mse: 0.0091 - val_loss: 0.0071 - val_mse: 0.0071 - 407ms/epoch - 2ms/step
# Epoch 90/100
# 169/169 - 0s - loss: 0.0090 - mse: 0.0090 - val_loss: 0.0071 - val_mse: 0.0071 - 413ms/epoch - 2ms/step
# Epoch 91/100
# 169/169 - 0s - loss: 0.0090 - mse: 0.0090 - val_loss: 0.0071 - val_mse: 0.0071 - 406ms/epoch - 2ms/step
# Epoch 92/100
# 169/169 - 0s - loss: 0.0090 - mse: 0.0090 - val_loss: 0.0071 - val_mse: 0.0071 - 405ms/epoch - 2ms/step
# Epoch 93/100
# 169/169 - 0s - loss: 0.0090 - mse: 0.0090 - val_loss: 0.0071 - val_mse: 0.0071 - 408ms/epoch - 2ms/step
# Epoch 94/100
# 169/169 - 0s - loss: 0.0090 - mse: 0.0090 - val_loss: 0.0070 - val_mse: 0.0070 - 413ms/epoch - 2ms/step
# Epoch 95/100
# 169/169 - 0s - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0070 - val_mse: 0.0070 - 416ms/epoch - 2ms/step
# Epoch 96/100
# 169/169 - 0s - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0070 - val_mse: 0.0070 - 404ms/epoch - 2ms/step
# Epoch 97/100
# 169/169 - 0s - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0070 - val_mse: 0.0070 - 410ms/epoch - 2ms/step
# Epoch 98/100
# 169/169 - 0s - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0070 - val_mse: 0.0070 - 401ms/epoch - 2ms/step
# Epoch 99/100
# 169/169 - 0s - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0070 - val_mse: 0.0070 - 405ms/epoch - 2ms/step
# Epoch 100/100
# 169/169 - 0s - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0069 - val_mse: 0.0069 - 402ms/epoch - 2ms/step

# %%
# Resumen del entrenamiento
n_rows = 2
n_cols = 3

fig, ax = plt.subplots(n_rows, n_cols, figsize=(14,8))
fig.suptitle('Model loss SPI_6')
plt.subplots_adjust(hspace=0.3, wspace=0.3)
for i, (key, value) in enumerate(model_history_dict.items()):
    if i<n_cols:
        ax[0, i].plot(value.history['loss'])
        ax[0, i].plot(value.history['val_loss'])
        ax[0, i].set_title(key, fontsize=10)
        ax[0, i].set_ylabel('loss')
        ax[0, i].set_xlabel('epoch')
        ax[0, i].legend(['train', 'test'], loc='upper right')
    else:
        ax[1, i-n_cols].plot(value.history['loss'])
        ax[1, i-n_cols].plot(value.history['val_loss'])
        ax[1, i-n_cols].set_title(key, fontsize=10)
        ax[1, i-n_cols].set_ylabel('loss')
        ax[1, i-n_cols].set_xlabel('epoch')
        ax[1, i-n_cols].legend(['train', 'test'], loc='upper right')

# %% [markdown]
# # Evaluación del modelo

# %%
test_score_values = []
for key in spi_6_dict.keys():
    print('Evaluación '+ key)
    train_prediction = model.predict(X_train_dict[key], verbose=0)
    test_prediction = model.predict(X_test_dict[key], verbose=0)
    train_score = model.evaluate(X_train_dict[key], y_train_dict[key], verbose=0)
    test_score = model.evaluate(X_test_dict[key], y_test_dict[key], verbose=0)
    test_score_values.append(test_score[0])
    print('Train score: {} MSE'.format(train_score[0]))
    print('Test score: {} MSE'.format(test_score[0]))
    print('')

mean_test_score = sum(test_score_values) / len(test_score_values)
print('LSTM SPI_6 Mean Test score: {} MSE'.format(mean_test_score))
# Out:
# Evaluación Demarcación Hidrográfica de las Cuencas Mediterráneas Andaluzas
# Train score: 0.01527577918022871 MSE
# Test score: 0.015751579776406288 MSE
#
# Evaluación Cuenca hidrográfica del Guadalquivir
# Train score: 0.016507720574736595 MSE
# Test score: 0.012835739180445671 MSE
#
# Evaluación Cuenca hidrográfica del Guadiana
# Train score: 0.015295800752937794 MSE
# Test score: 0.013349181972444057 MSE
#
# Evaluación Cuenca hidrográfica del Segura
# Train score: 0.013685534708201885 MSE
# Test score: 0.012855609878897667 MSE
#
# Evaluación Demarcación Hidrográfica Guadalete-Barbate
# Train score: 0.013310456648468971 MSE
# Test score: 0.010562580078840256 MSE
#
# Evaluación Demarcación Hidrográfica Tinto, Odiel y Piedras
# Train score: 0.009302006103098392 MSE
# Test score: 0.006943381857126951 MSE
#
# LSTM SPI_6 Mean Test score: 0.012049678790693482 MSE

# %% [markdown]
# # Visualización de la predicción

# %%
# Gráfica con los valores reales frente a los datos de predicción
# Se usa como ejemplo la predicción de la Demarcación Hidrográfica Tinto, Odiel y Piedras
plt.figure(figsize=(12, 8))
train_stamp = np.arange(3+sequence_size, sequence_size + 3+X_train_dict[keys_names[5]].shape[0])
test_stamp = np.arange(3+2 * sequence_size + X_train_dict[keys_names[5]].shape[0], 3+len(spi_6_dict[keys_names[5]]))
plt.plot(spi_6_dict[keys_names[5]], label='Valores reales')
plt.plot(train_stamp, train_prediction, label='train prediction')
plt.plot(test_stamp, test_prediction, label = 'test prediction')
plt.title('Predicción SPI_6 '+ keys_names[5])
plt.legend()
plt.show()
