# %%
# Librerias utilizadas
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow import keras
from tensorflow.keras import layers
from keras.callbacks import EarlyStopping
from scikeras.wrappers import KerasRegressor
from sklearn.model_selection import GridSearchCV
import warnings

# %% [markdown]
# # Importación de datos

# %%
csv_names  = ['df_DHCMA', 'df_CHG', 'df_CHGUADIANA',
            'df_CHS', 'df_DHGB', 'df_DHTOP']
path = '..\\DATA\\'
keys_names = ['Demarcación Hidrográfica de las Cuencas Mediterráneas Andaluzas', 'Cuenca hidrográfica del Guadalquivir', 'Cuenca hidrográfica del Guadiana',
              'Cuenca hidrográfica del Segura', 'Demarcación Hidrográfica Guadalete-Barbate', 'Demarcación Hidrográfica Tinto, Odiel y Piedras']
df_dict = {key: pd.read_csv(path+value+'.csv', sep=',', encoding='ISO-8859-1')
           for key, value in zip(keys_names, csv_names)}

# %% [markdown]
# ### Procesado de datos de entrada

# %%
# Función de creación de dataset sequencial con arrays de valores input/output
# Este dataset tiene la estructura adecuada para los datos de entrada
# en la red neuronal
def to_sequences(seq_size, obs):
    x = []
    y = []

    for i in range(len(obs)-seq_size):
        window = obs.iloc[i:(i+seq_size)]
        after_window = obs.iloc[i+seq_size]
        window = [[x] for x in window]
        x.append(window)
        y.append(after_window)
        
    return np.array(x),np.array(y)

# %%
# Creación del dataset de indice SPI_3
spi_3_dict =  {key: value['spi_3']
           for key, value in df_dict.items()}

# Eliminación valores vacios iniciales
for key, df in spi_3_dict.items():           
    spi_3_dict[key] = df.dropna(how='all')

# %%
# Separación en conjunto de entrenamiento y de prueba
# Los datos de prueba empiezan a partir de 2011
spi_3_train_dict, spi_3_test_dict = {}, {}
for key, df in spi_3_dict.items():
    df_train, df_test = train_test_split(df, test_size=0.13, shuffle=False)
    spi_3_train_dict[key] = df_train
    spi_3_test_dict[key] = df_test

# %%
# Cálculo de datasets sequenciales
sequence_size = 10
X_train_dict, y_train_dict, X_test_dict,y_test_dict = {}, {}, {}, {}

for key, df in spi_3_train_dict.items():
    X_train,y_train = to_sequences(sequence_size, df)
    X_train_dict[key] = X_train
    y_train_dict[key] = y_train

for key, df in spi_3_test_dict.items():
    X_test,y_test = to_sequences(sequence_size, df)
    X_test_dict[key] = X_test
    y_test_dict[key] = y_test

print("Dimensiones del training set: {}".format(X_train_dict[keys_names[0]].shape))
print("Dimensiones del test set: {}".format(X_test_dict[keys_names[0]].shape))
# Out:
# Dimensiones del training set: (844, 10, 1)
# Dimensiones del test set: (118, 10, 1)

# %% [markdown]
# # Transformer encoder

# %%
# Extraido de https://keras.io/examples/timeseries/timeseries_transformer_classification/
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    # Normalization and Attention
    x = layers.LayerNormalization(epsilon=1e-6)(inputs)
    x = layers.MultiHeadAttention(
        key_dim=head_size, num_heads=num_heads, dropout=dropout
    )(x, x)
    x = layers.Dropout(dropout)(x)
    res = x + inputs

    # Feed Forward Part
    x = layers.LayerNormalization(epsilon=1e-6)(res)
    x = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(x)
    x = layers.Dropout(dropout)(x)
    x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
    return x + res

# %% [markdown]
# # Construccion del modelo

# %%
# Funcion de construccion del modelo
# Extraida de https://keras.io/examples/timeseries/timeseries_transformer_classification/
def build_model(
    input_shape,
    head_size,
    num_heads,
    ff_dim,
    num_transformer_blocks,
    mlp_units,
    dropout=0,
    mlp_dropout=0,
):
    inputs = keras.Input(shape=input_shape)
    x = inputs
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

    x = layers.GlobalAveragePooling1D(data_format="channels_first")(x)
    for dim in mlp_units:
        x = layers.Dense(dim, activation="relu")(x)
        x = layers.Dropout(mlp_dropout)(x)
    outputs = layers.Dense(1)(x)
    return keras.Model(inputs, outputs)

# %% [markdown]
# # Definición del modelo

# %%
input_shape = X_train.shape[1:]
def create_model(optimizer='adam'):
    # Arquitectura del modelo
    model = build_model(
        input_shape,
        head_size=256, 
        num_heads=4, # Numero de capas de atencion paralelas
        ff_dim=4, 
        num_transformer_blocks=2, 
        mlp_units=[128], 
        mlp_dropout=0.4,
        dropout=0.25,
    )
    model.compile(loss='mean_squared_error', optimizer=optimizer, metrics=['mse'])
    
    return model

#  Early stopping para evitar overfitting
es = EarlyStopping(monitor='val_loss', verbose=1, patience=3)

# %% [markdown]
# ### Grid search: búsqueda de mejores parámetros

# %%
# Transformación del modelo para aplicar grid search
model = KerasRegressor(model=create_model, epochs=100, batch_size=10, verbose=0)

# Parámetros de búsqueda
param_grid = {
    'epochs': [50, 100],
    'batch_size' : [5,10],
    'optimizer' : ['SGD', 'adam']
}


# Se ignoran avisos de ejecución del grid search
warnings.simplefilter("ignore")

# Cálculo de grid search
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=8)
grid_result_dict = {}
for key in spi_3_train_dict.keys():
    grid_result_dict[key] = grid.fit(X_train_dict[key], y_train_dict[key], callbacks=[es], shuffle=False, validation_data=(
        X_test_dict[key], y_test_dict[key]))
    print(key)
    print("Best: %f using %s" % (grid_result_dict[key].best_score_, grid_result_dict[key].best_params_))
    print('')
# Out:
# Demarcación Hidrográfica de las Cuencas Mediterráneas Andaluzas
# Best: 0.414352 using {'batch_size': 10, 'epochs': 50, 'optimizer': 'SGD'}
#
# Cuenca hidrográfica del Guadalquivir
# Best: 0.422567 using {'batch_size': 10, 'epochs': 50, 'optimizer': 'SGD'}
#
# Cuenca hidrográfica del Guadiana
# Best: 0.463674 using {'batch_size': 10, 'epochs': 100, 'optimizer': 'SGD'}
#
# Cuenca hidrográfica del Segura
# Best: 0.509179 using {'batch_size': 10, 'epochs': 50, 'optimizer': 'adam'}
#
# Demarcación Hidrográfica Guadalete-Barbate
# Best: 0.386622 using {'batch_size': 10, 'epochs': 50, 'optimizer': 'adam'}
#
# Demarcación Hidrográfica Tinto, Odiel y Piedras
# Best: 0.398352 using {'batch_size': 10, 'epochs': 50, 'optimizer': 'SGD'}

# %% [markdown]
# # Entrenamiento del modelo

# %%
model_history_dict = {}

for key in spi_3_train_dict.keys():
    model = create_model( grid_result_dict[key].best_params_['optimizer'])

    model_history_dict[key] = model.fit(X_train_dict[key], y_train_dict[key], epochs=grid_result_dict[key].best_params_['epochs'],
        batch_size=grid_result_dict[key].best_params_['batch_size'],
        validation_data=(
        X_test_dict[key], y_test_dict[key]), verbose=2, shuffle=False, callbacks=[es]
        )
# Out:
# Epoch 1/50
# 85/85 - 2s - loss: 0.0625 - mse: 0.0625 - val_loss: 0.0286 - val_mse: 0.0286 - 2s/epoch - 25ms/step
# Epoch 2/50
# 85/85 - 1s - loss: 0.0378 - mse: 0.0378 - val_loss: 0.0261 - val_mse: 0.0261 - 590ms/epoch - 7ms/step
# Epoch 3/50
# 85/85 - 1s - loss: 0.0330 - mse: 0.0330 - val_loss: 0.0246 - val_mse: 0.0246 - 623ms/epoch - 7ms/step
# Epoch 4/50
# 85/85 - 1s - loss: 0.0284 - mse: 0.0284 - val_loss: 0.0229 - val_mse: 0.0229 - 643ms/epoch - 8ms/step
# Epoch 5/50
# 85/85 - 1s - loss: 0.0270 - mse: 0.0270 - val_loss: 0.0225 - val_mse: 0.0225 - 629ms/epoch - 7ms/step
# Epoch 6/50
# 85/85 - 1s - loss: 0.0248 - mse: 0.0248 - val_loss: 0.0214 - val_mse: 0.0214 - 639ms/epoch - 8ms/step
# Epoch 7/50
# 85/85 - 1s - loss: 0.0247 - mse: 0.0247 - val_loss: 0.0201 - val_mse: 0.0201 - 595ms/epoch - 7ms/step
# Epoch 8/50
# 85/85 - 1s - loss: 0.0236 - mse: 0.0236 - val_loss: 0.0192 - val_mse: 0.0192 - 617ms/epoch - 7ms/step
# Epoch 9/50
# 85/85 - 1s - loss: 0.0227 - mse: 0.0227 - val_loss: 0.0194 - val_mse: 0.0194 - 625ms/epoch - 7ms/step
# Epoch 10/50
# 85/85 - 1s - loss: 0.0229 - mse: 0.0229 - val_loss: 0.0185 - val_mse: 0.0185 - 588ms/epoch - 7ms/step
# Epoch 11/50
# 85/85 - 1s - loss: 0.0216 - mse: 0.0216 - val_loss: 0.0183 - val_mse: 0.0183 - 592ms/epoch - 7ms/step
# Epoch 12/50
# 85/85 - 1s - loss: 0.0213 - mse: 0.0213 - val_loss: 0.0187 - val_mse: 0.0187 - 591ms/epoch - 7ms/step
# Epoch 13/50
# 85/85 - 1s - loss: 0.0219 - mse: 0.0219 - val_loss: 0.0182 - val_mse: 0.0182 - 596ms/epoch - 7ms/step
# Epoch 14/50
# 85/85 - 1s - loss: 0.0212 - mse: 0.0212 - val_loss: 0.0176 - val_mse: 0.0176 - 592ms/epoch - 7ms/step
# Epoch 15/50
# 85/85 - 1s - loss: 0.0195 - mse: 0.0195 - val_loss: 0.0176 - val_mse: 0.0176 - 594ms/epoch - 7ms/step
# Epoch 16/50
# 85/85 - 1s - loss: 0.0201 - mse: 0.0201 - val_loss: 0.0170 - val_mse: 0.0170 - 596ms/epoch - 7ms/step
# Epoch 17/50
# 85/85 - 1s - loss: 0.0211 - mse: 0.0211 - val_loss: 0.0169 - val_mse: 0.0169 - 591ms/epoch - 7ms/step
# Epoch 18/50
# 85/85 - 1s - loss: 0.0194 - mse: 0.0194 - val_loss: 0.0169 - val_mse: 0.0169 - 606ms/epoch - 7ms/step
# Epoch 19/50
# 85/85 - 1s - loss: 0.0187 - mse: 0.0187 - val_loss: 0.0169 - val_mse: 0.0169 - 618ms/epoch - 7ms/step
# Epoch 20/50
# 85/85 - 1s - loss: 0.0190 - mse: 0.0190 - val_loss: 0.0165 - val_mse: 0.0165 - 626ms/epoch - 7ms/step
# Epoch 21/50
# 85/85 - 1s - loss: 0.0194 - mse: 0.0194 - val_loss: 0.0167 - val_mse: 0.0167 - 636ms/epoch - 7ms/step
# Epoch 22/50
# 85/85 - 1s - loss: 0.0189 - mse: 0.0189 - val_loss: 0.0163 - val_mse: 0.0163 - 612ms/epoch - 7ms/step
# Epoch 23/50
# 85/85 - 1s - loss: 0.0182 - mse: 0.0182 - val_loss: 0.0167 - val_mse: 0.0167 - 610ms/epoch - 7ms/step
# Epoch 24/50
# 85/85 - 1s - loss: 0.0181 - mse: 0.0181 - val_loss: 0.0158 - val_mse: 0.0158 - 584ms/epoch - 7ms/step
# Epoch 25/50
# 85/85 - 1s - loss: 0.0180 - mse: 0.0180 - val_loss: 0.0160 - val_mse: 0.0160 - 585ms/epoch - 7ms/step
# Epoch 26/50
# 85/85 - 1s - loss: 0.0188 - mse: 0.0188 - val_loss: 0.0155 - val_mse: 0.0155 - 606ms/epoch - 7ms/step
# Epoch 27/50
# 85/85 - 1s - loss: 0.0174 - mse: 0.0174 - val_loss: 0.0159 - val_mse: 0.0159 - 596ms/epoch - 7ms/step
# Epoch 28/50
# 85/85 - 1s - loss: 0.0185 - mse: 0.0185 - val_loss: 0.0158 - val_mse: 0.0158 - 607ms/epoch - 7ms/step
# Epoch 29/50
# 85/85 - 1s - loss: 0.0174 - mse: 0.0174 - val_loss: 0.0161 - val_mse: 0.0161 - 603ms/epoch - 7ms/step
# Epoch 29: early stopping
# Epoch 1/50
# 85/85 - 2s - loss: 0.0699 - mse: 0.0699 - val_loss: 0.0241 - val_mse: 0.0241 - 2s/epoch - 25ms/step
# Epoch 2/50
# 85/85 - 1s - loss: 0.0400 - mse: 0.0400 - val_loss: 0.0227 - val_mse: 0.0227 - 611ms/epoch - 7ms/step
# Epoch 3/50
# 85/85 - 1s - loss: 0.0353 - mse: 0.0353 - val_loss: 0.0216 - val_mse: 0.0216 - 597ms/epoch - 7ms/step
# Epoch 4/50
# 85/85 - 1s - loss: 0.0321 - mse: 0.0321 - val_loss: 0.0206 - val_mse: 0.0206 - 596ms/epoch - 7ms/step
# Epoch 5/50
# 85/85 - 1s - loss: 0.0287 - mse: 0.0287 - val_loss: 0.0195 - val_mse: 0.0195 - 594ms/epoch - 7ms/step
# Epoch 6/50
# 85/85 - 1s - loss: 0.0289 - mse: 0.0289 - val_loss: 0.0187 - val_mse: 0.0187 - 595ms/epoch - 7ms/step
# Epoch 7/50
# 85/85 - 1s - loss: 0.0263 - mse: 0.0263 - val_loss: 0.0183 - val_mse: 0.0183 - 596ms/epoch - 7ms/step
# Epoch 8/50
# 85/85 - 1s - loss: 0.0239 - mse: 0.0239 - val_loss: 0.0177 - val_mse: 0.0177 - 596ms/epoch - 7ms/step
# Epoch 9/50
# 85/85 - 1s - loss: 0.0239 - mse: 0.0239 - val_loss: 0.0175 - val_mse: 0.0175 - 593ms/epoch - 7ms/step
# Epoch 10/50
# 85/85 - 1s - loss: 0.0250 - mse: 0.0250 - val_loss: 0.0170 - val_mse: 0.0170 - 600ms/epoch - 7ms/step
# Epoch 11/50
# 85/85 - 1s - loss: 0.0225 - mse: 0.0225 - val_loss: 0.0168 - val_mse: 0.0168 - 592ms/epoch - 7ms/step
# Epoch 12/50
# 85/85 - 1s - loss: 0.0230 - mse: 0.0230 - val_loss: 0.0172 - val_mse: 0.0172 - 593ms/epoch - 7ms/step
# Epoch 13/50
# 85/85 - 1s - loss: 0.0220 - mse: 0.0220 - val_loss: 0.0169 - val_mse: 0.0169 - 606ms/epoch - 7ms/step
# Epoch 14/50
# 85/85 - 1s - loss: 0.0219 - mse: 0.0219 - val_loss: 0.0167 - val_mse: 0.0167 - 619ms/epoch - 7ms/step
# Epoch 15/50
# 85/85 - 1s - loss: 0.0219 - mse: 0.0219 - val_loss: 0.0164 - val_mse: 0.0164 - 605ms/epoch - 7ms/step
# Epoch 16/50
# 85/85 - 1s - loss: 0.0211 - mse: 0.0211 - val_loss: 0.0162 - val_mse: 0.0162 - 598ms/epoch - 7ms/step
# Epoch 17/50
# 85/85 - 1s - loss: 0.0217 - mse: 0.0217 - val_loss: 0.0162 - val_mse: 0.0162 - 597ms/epoch - 7ms/step
# Epoch 18/50
# 85/85 - 1s - loss: 0.0207 - mse: 0.0207 - val_loss: 0.0161 - val_mse: 0.0161 - 593ms/epoch - 7ms/step
# Epoch 19/50
# 85/85 - 1s - loss: 0.0197 - mse: 0.0197 - val_loss: 0.0161 - val_mse: 0.0161 - 629ms/epoch - 7ms/step
# Epoch 20/50
# 85/85 - 1s - loss: 0.0197 - mse: 0.0197 - val_loss: 0.0159 - val_mse: 0.0159 - 603ms/epoch - 7ms/step
# Epoch 21/50
# 85/85 - 1s - loss: 0.0192 - mse: 0.0192 - val_loss: 0.0159 - val_mse: 0.0159 - 595ms/epoch - 7ms/step
# Epoch 22/50
# 85/85 - 1s - loss: 0.0196 - mse: 0.0196 - val_loss: 0.0157 - val_mse: 0.0157 - 604ms/epoch - 7ms/step
# Epoch 23/50
# 85/85 - 1s - loss: 0.0187 - mse: 0.0187 - val_loss: 0.0158 - val_mse: 0.0158 - 607ms/epoch - 7ms/step
# Epoch 24/50
# 85/85 - 1s - loss: 0.0190 - mse: 0.0190 - val_loss: 0.0155 - val_mse: 0.0155 - 595ms/epoch - 7ms/step
# Epoch 25/50
# 85/85 - 1s - loss: 0.0193 - mse: 0.0193 - val_loss: 0.0157 - val_mse: 0.0157 - 596ms/epoch - 7ms/step
# Epoch 26/50
# 85/85 - 1s - loss: 0.0189 - mse: 0.0189 - val_loss: 0.0157 - val_mse: 0.0157 - 612ms/epoch - 7ms/step
# Epoch 27/50
# 85/85 - 1s - loss: 0.0185 - mse: 0.0185 - val_loss: 0.0155 - val_mse: 0.0155 - 592ms/epoch - 7ms/step
# Epoch 27: early stopping
# Epoch 1/50
# 85/85 - 2s - loss: 0.0742 - mse: 0.0742 - val_loss: 0.0249 - val_mse: 0.0249 - 2s/epoch - 26ms/step
# Epoch 2/50
# 85/85 - 1s - loss: 0.0417 - mse: 0.0417 - val_loss: 0.0250 - val_mse: 0.0250 - 604ms/epoch - 7ms/step
# Epoch 3/50
# 85/85 - 1s - loss: 0.0373 - mse: 0.0373 - val_loss: 0.0222 - val_mse: 0.0222 - 615ms/epoch - 7ms/step
# Epoch 4/50
# 85/85 - 1s - loss: 0.0338 - mse: 0.0338 - val_loss: 0.0201 - val_mse: 0.0201 - 612ms/epoch - 7ms/step
# Epoch 5/50
# 85/85 - 1s - loss: 0.0281 - mse: 0.0281 - val_loss: 0.0183 - val_mse: 0.0183 - 605ms/epoch - 7ms/step
# Epoch 6/50
# 85/85 - 1s - loss: 0.0260 - mse: 0.0260 - val_loss: 0.0177 - val_mse: 0.0177 - 616ms/epoch - 7ms/step
# Epoch 7/50
# 85/85 - 1s - loss: 0.0248 - mse: 0.0248 - val_loss: 0.0168 - val_mse: 0.0168 - 613ms/epoch - 7ms/step
# Epoch 8/50
# 85/85 - 1s - loss: 0.0240 - mse: 0.0240 - val_loss: 0.0163 - val_mse: 0.0163 - 622ms/epoch - 7ms/step
# Epoch 9/50
# 85/85 - 1s - loss: 0.0220 - mse: 0.0220 - val_loss: 0.0161 - val_mse: 0.0161 - 609ms/epoch - 7ms/step
# Epoch 10/50
# 85/85 - 1s - loss: 0.0211 - mse: 0.0211 - val_loss: 0.0160 - val_mse: 0.0160 - 610ms/epoch - 7ms/step
# Epoch 11/50
# 85/85 - 1s - loss: 0.0203 - mse: 0.0203 - val_loss: 0.0150 - val_mse: 0.0150 - 611ms/epoch - 7ms/step
# Epoch 12/50
# 85/85 - 1s - loss: 0.0190 - mse: 0.0190 - val_loss: 0.0147 - val_mse: 0.0147 - 615ms/epoch - 7ms/step
# Epoch 13/50
# 85/85 - 1s - loss: 0.0206 - mse: 0.0206 - val_loss: 0.0145 - val_mse: 0.0145 - 610ms/epoch - 7ms/step
# Epoch 14/50
# 85/85 - 1s - loss: 0.0195 - mse: 0.0195 - val_loss: 0.0145 - val_mse: 0.0145 - 610ms/epoch - 7ms/step
# Epoch 15/50
# 85/85 - 1s - loss: 0.0176 - mse: 0.0176 - val_loss: 0.0144 - val_mse: 0.0144 - 609ms/epoch - 7ms/step
# Epoch 16/50
# 85/85 - 1s - loss: 0.0178 - mse: 0.0178 - val_loss: 0.0144 - val_mse: 0.0144 - 607ms/epoch - 7ms/step
# Epoch 17/50
# 85/85 - 1s - loss: 0.0186 - mse: 0.0186 - val_loss: 0.0143 - val_mse: 0.0143 - 603ms/epoch - 7ms/step
# Epoch 18/50
# 85/85 - 1s - loss: 0.0182 - mse: 0.0182 - val_loss: 0.0141 - val_mse: 0.0141 - 605ms/epoch - 7ms/step
# Epoch 19/50
# 85/85 - 1s - loss: 0.0166 - mse: 0.0166 - val_loss: 0.0138 - val_mse: 0.0138 - 608ms/epoch - 7ms/step
# Epoch 20/50
# 85/85 - 1s - loss: 0.0170 - mse: 0.0170 - val_loss: 0.0135 - val_mse: 0.0135 - 609ms/epoch - 7ms/step
# Epoch 21/50
# 85/85 - 1s - loss: 0.0174 - mse: 0.0174 - val_loss: 0.0134 - val_mse: 0.0134 - 615ms/epoch - 7ms/step
# Epoch 22/50
# 85/85 - 1s - loss: 0.0175 - mse: 0.0175 - val_loss: 0.0135 - val_mse: 0.0135 - 621ms/epoch - 7ms/step
# Epoch 23/50
# 85/85 - 1s - loss: 0.0164 - mse: 0.0164 - val_loss: 0.0138 - val_mse: 0.0138 - 610ms/epoch - 7ms/step
# Epoch 24/50
# 85/85 - 1s - loss: 0.0170 - mse: 0.0170 - val_loss: 0.0134 - val_mse: 0.0134 - 613ms/epoch - 7ms/step
# Epoch 25/50
# 85/85 - 1s - loss: 0.0165 - mse: 0.0165 - val_loss: 0.0131 - val_mse: 0.0131 - 612ms/epoch - 7ms/step
# Epoch 26/50
# 85/85 - 1s - loss: 0.0159 - mse: 0.0159 - val_loss: 0.0130 - val_mse: 0.0130 - 628ms/epoch - 7ms/step
# Epoch 27/50
# 85/85 - 1s - loss: 0.0163 - mse: 0.0163 - val_loss: 0.0134 - val_mse: 0.0134 - 635ms/epoch - 7ms/step
# Epoch 28/50
# 85/85 - 1s - loss: 0.0160 - mse: 0.0160 - val_loss: 0.0131 - val_mse: 0.0131 - 601ms/epoch - 7ms/step
# Epoch 29/50
# 85/85 - 1s - loss: 0.0153 - mse: 0.0153 - val_loss: 0.0130 - val_mse: 0.0130 - 624ms/epoch - 7ms/step
# Epoch 30/50
# 85/85 - 1s - loss: 0.0166 - mse: 0.0166 - val_loss: 0.0132 - val_mse: 0.0132 - 632ms/epoch - 7ms/step
# Epoch 31/50
# 85/85 - 1s - loss: 0.0158 - mse: 0.0158 - val_loss: 0.0129 - val_mse: 0.0129 - 615ms/epoch - 7ms/step
# Epoch 32/50
# 85/85 - 1s - loss: 0.0162 - mse: 0.0162 - val_loss: 0.0130 - val_mse: 0.0130 - 656ms/epoch - 8ms/step
# Epoch 33/50
# 85/85 - 1s - loss: 0.0155 - mse: 0.0155 - val_loss: 0.0132 - val_mse: 0.0132 - 620ms/epoch - 7ms/step
# Epoch 34/50
# 85/85 - 1s - loss: 0.0162 - mse: 0.0162 - val_loss: 0.0131 - val_mse: 0.0131 - 642ms/epoch - 8ms/step
# Epoch 34: early stopping
# Epoch 1/50
# 85/85 - 2s - loss: 0.0770 - mse: 0.0770 - val_loss: 0.0228 - val_mse: 0.0228 - 2s/epoch - 27ms/step
# Epoch 2/50
# 85/85 - 1s - loss: 0.0423 - mse: 0.0423 - val_loss: 0.0225 - val_mse: 0.0225 - 607ms/epoch - 7ms/step
# Epoch 3/50
# 85/85 - 1s - loss: 0.0341 - mse: 0.0341 - val_loss: 0.0237 - val_mse: 0.0237 - 597ms/epoch - 7ms/step
# Epoch 4/50
# 85/85 - 1s - loss: 0.0307 - mse: 0.0307 - val_loss: 0.0196 - val_mse: 0.0196 - 604ms/epoch - 7ms/step
# Epoch 5/50
# 85/85 - 1s - loss: 0.0281 - mse: 0.0281 - val_loss: 0.0192 - val_mse: 0.0192 - 605ms/epoch - 7ms/step
# Epoch 6/50
# 85/85 - 1s - loss: 0.0246 - mse: 0.0246 - val_loss: 0.0176 - val_mse: 0.0176 - 593ms/epoch - 7ms/step
# Epoch 7/50
# 85/85 - 1s - loss: 0.0237 - mse: 0.0237 - val_loss: 0.0169 - val_mse: 0.0169 - 601ms/epoch - 7ms/step
# Epoch 8/50
# 85/85 - 1s - loss: 0.0211 - mse: 0.0211 - val_loss: 0.0164 - val_mse: 0.0164 - 593ms/epoch - 7ms/step
# Epoch 9/50
# 85/85 - 1s - loss: 0.0205 - mse: 0.0205 - val_loss: 0.0160 - val_mse: 0.0160 - 590ms/epoch - 7ms/step
# Epoch 10/50
# 85/85 - 1s - loss: 0.0198 - mse: 0.0198 - val_loss: 0.0156 - val_mse: 0.0156 - 593ms/epoch - 7ms/step
# Epoch 11/50
# 85/85 - 1s - loss: 0.0182 - mse: 0.0182 - val_loss: 0.0151 - val_mse: 0.0151 - 599ms/epoch - 7ms/step
# Epoch 12/50
# 85/85 - 1s - loss: 0.0173 - mse: 0.0173 - val_loss: 0.0146 - val_mse: 0.0146 - 595ms/epoch - 7ms/step
# Epoch 13/50
# 85/85 - 1s - loss: 0.0178 - mse: 0.0178 - val_loss: 0.0145 - val_mse: 0.0145 - 603ms/epoch - 7ms/step
# Epoch 14/50
# 85/85 - 1s - loss: 0.0172 - mse: 0.0172 - val_loss: 0.0141 - val_mse: 0.0141 - 606ms/epoch - 7ms/step
# Epoch 15/50
# 85/85 - 1s - loss: 0.0160 - mse: 0.0160 - val_loss: 0.0140 - val_mse: 0.0140 - 651ms/epoch - 8ms/step
# Epoch 16/50
# 85/85 - 1s - loss: 0.0167 - mse: 0.0167 - val_loss: 0.0138 - val_mse: 0.0138 - 627ms/epoch - 7ms/step
# Epoch 17/50
# 85/85 - 1s - loss: 0.0155 - mse: 0.0155 - val_loss: 0.0136 - val_mse: 0.0136 - 626ms/epoch - 7ms/step
# Epoch 18/50
# 85/85 - 1s - loss: 0.0153 - mse: 0.0153 - val_loss: 0.0135 - val_mse: 0.0135 - 608ms/epoch - 7ms/step
# Epoch 19/50
# 85/85 - 1s - loss: 0.0151 - mse: 0.0151 - val_loss: 0.0134 - val_mse: 0.0134 - 602ms/epoch - 7ms/step
# Epoch 20/50
# 85/85 - 1s - loss: 0.0150 - mse: 0.0150 - val_loss: 0.0134 - val_mse: 0.0134 - 598ms/epoch - 7ms/step
# Epoch 21/50
# 85/85 - 1s - loss: 0.0148 - mse: 0.0148 - val_loss: 0.0130 - val_mse: 0.0130 - 621ms/epoch - 7ms/step
# Epoch 22/50
# 85/85 - 1s - loss: 0.0143 - mse: 0.0143 - val_loss: 0.0131 - val_mse: 0.0131 - 603ms/epoch - 7ms/step
# Epoch 23/50
# 85/85 - 1s - loss: 0.0141 - mse: 0.0141 - val_loss: 0.0130 - val_mse: 0.0130 - 608ms/epoch - 7ms/step
# Epoch 24/50
# 85/85 - 1s - loss: 0.0148 - mse: 0.0148 - val_loss: 0.0129 - val_mse: 0.0129 - 595ms/epoch - 7ms/step
# Epoch 25/50
# 85/85 - 1s - loss: 0.0146 - mse: 0.0146 - val_loss: 0.0129 - val_mse: 0.0129 - 593ms/epoch - 7ms/step
# Epoch 26/50
# 85/85 - 1s - loss: 0.0132 - mse: 0.0132 - val_loss: 0.0128 - val_mse: 0.0128 - 591ms/epoch - 7ms/step
# Epoch 27/50
# 85/85 - 1s - loss: 0.0141 - mse: 0.0141 - val_loss: 0.0130 - val_mse: 0.0130 - 594ms/epoch - 7ms/step
# Epoch 28/50
# 85/85 - 1s - loss: 0.0140 - mse: 0.0140 - val_loss: 0.0126 - val_mse: 0.0126 - 595ms/epoch - 7ms/step
# Epoch 29/50
# 85/85 - 1s - loss: 0.0134 - mse: 0.0134 - val_loss: 0.0128 - val_mse: 0.0128 - 597ms/epoch - 7ms/step
# Epoch 30/50
# 85/85 - 1s - loss: 0.0129 - mse: 0.0129 - val_loss: 0.0129 - val_mse: 0.0129 - 618ms/epoch - 7ms/step
# Epoch 31/50
# 85/85 - 1s - loss: 0.0126 - mse: 0.0126 - val_loss: 0.0129 - val_mse: 0.0129 - 654ms/epoch - 8ms/step
# Epoch 31: early stopping
# Epoch 1/50
# 85/85 - 2s - loss: 0.0643 - mse: 0.0643 - val_loss: 0.0183 - val_mse: 0.0183 - 2s/epoch - 26ms/step
# Epoch 2/50
# 85/85 - 1s - loss: 0.0372 - mse: 0.0372 - val_loss: 0.0175 - val_mse: 0.0175 - 628ms/epoch - 7ms/step
# Epoch 3/50
# 85/85 - 1s - loss: 0.0358 - mse: 0.0358 - val_loss: 0.0169 - val_mse: 0.0169 - 630ms/epoch - 7ms/step
# Epoch 4/50
# 85/85 - 1s - loss: 0.0314 - mse: 0.0314 - val_loss: 0.0162 - val_mse: 0.0162 - 614ms/epoch - 7ms/step
# Epoch 5/50
# 85/85 - 1s - loss: 0.0286 - mse: 0.0286 - val_loss: 0.0157 - val_mse: 0.0157 - 623ms/epoch - 7ms/step
# Epoch 6/50
# 85/85 - 1s - loss: 0.0282 - mse: 0.0282 - val_loss: 0.0155 - val_mse: 0.0155 - 622ms/epoch - 7ms/step
# Epoch 7/50
# 85/85 - 1s - loss: 0.0259 - mse: 0.0259 - val_loss: 0.0153 - val_mse: 0.0153 - 617ms/epoch - 7ms/step
# Epoch 8/50
# 85/85 - 1s - loss: 0.0245 - mse: 0.0245 - val_loss: 0.0149 - val_mse: 0.0149 - 600ms/epoch - 7ms/step
# Epoch 9/50
# 85/85 - 1s - loss: 0.0245 - mse: 0.0245 - val_loss: 0.0145 - val_mse: 0.0145 - 601ms/epoch - 7ms/step
# Epoch 10/50
# 85/85 - 1s - loss: 0.0234 - mse: 0.0234 - val_loss: 0.0148 - val_mse: 0.0148 - 595ms/epoch - 7ms/step
# Epoch 11/50
# 85/85 - 1s - loss: 0.0222 - mse: 0.0222 - val_loss: 0.0142 - val_mse: 0.0142 - 602ms/epoch - 7ms/step
# Epoch 12/50
# 85/85 - 1s - loss: 0.0208 - mse: 0.0208 - val_loss: 0.0141 - val_mse: 0.0141 - 598ms/epoch - 7ms/step
# Epoch 13/50
# 85/85 - 1s - loss: 0.0215 - mse: 0.0215 - val_loss: 0.0140 - val_mse: 0.0140 - 596ms/epoch - 7ms/step
# Epoch 14/50
# 85/85 - 1s - loss: 0.0223 - mse: 0.0223 - val_loss: 0.0139 - val_mse: 0.0139 - 594ms/epoch - 7ms/step
# Epoch 15/50
# 85/85 - 1s - loss: 0.0219 - mse: 0.0219 - val_loss: 0.0138 - val_mse: 0.0138 - 602ms/epoch - 7ms/step
# Epoch 16/50
# 85/85 - 1s - loss: 0.0215 - mse: 0.0215 - val_loss: 0.0138 - val_mse: 0.0138 - 598ms/epoch - 7ms/step
# Epoch 17/50
# 85/85 - 1s - loss: 0.0217 - mse: 0.0217 - val_loss: 0.0135 - val_mse: 0.0135 - 591ms/epoch - 7ms/step
# Epoch 18/50
# 85/85 - 1s - loss: 0.0207 - mse: 0.0207 - val_loss: 0.0136 - val_mse: 0.0136 - 594ms/epoch - 7ms/step
# Epoch 19/50
# 85/85 - 1s - loss: 0.0216 - mse: 0.0216 - val_loss: 0.0134 - val_mse: 0.0134 - 600ms/epoch - 7ms/step
# Epoch 20/50
# 85/85 - 1s - loss: 0.0208 - mse: 0.0208 - val_loss: 0.0134 - val_mse: 0.0134 - 622ms/epoch - 7ms/step
# Epoch 21/50
# 85/85 - 1s - loss: 0.0210 - mse: 0.0210 - val_loss: 0.0132 - val_mse: 0.0132 - 610ms/epoch - 7ms/step
# Epoch 22/50
# 85/85 - 1s - loss: 0.0200 - mse: 0.0200 - val_loss: 0.0133 - val_mse: 0.0133 - 604ms/epoch - 7ms/step
# Epoch 23/50
# 85/85 - 1s - loss: 0.0202 - mse: 0.0202 - val_loss: 0.0130 - val_mse: 0.0130 - 613ms/epoch - 7ms/step
# Epoch 24/50
# 85/85 - 1s - loss: 0.0204 - mse: 0.0204 - val_loss: 0.0129 - val_mse: 0.0129 - 602ms/epoch - 7ms/step
# Epoch 25/50
# 85/85 - 1s - loss: 0.0203 - mse: 0.0203 - val_loss: 0.0129 - val_mse: 0.0129 - 608ms/epoch - 7ms/step
# Epoch 26/50
# 85/85 - 1s - loss: 0.0207 - mse: 0.0207 - val_loss: 0.0127 - val_mse: 0.0127 - 605ms/epoch - 7ms/step
# Epoch 27/50
# 85/85 - 1s - loss: 0.0196 - mse: 0.0196 - val_loss: 0.0128 - val_mse: 0.0128 - 599ms/epoch - 7ms/step
# Epoch 28/50
# 85/85 - 1s - loss: 0.0193 - mse: 0.0193 - val_loss: 0.0127 - val_mse: 0.0127 - 591ms/epoch - 7ms/step
# Epoch 29/50
# 85/85 - 1s - loss: 0.0196 - mse: 0.0196 - val_loss: 0.0129 - val_mse: 0.0129 - 595ms/epoch - 7ms/step
# Epoch 29: early stopping
# Epoch 1/50
# 85/85 - 2s - loss: 0.0750 - mse: 0.0750 - val_loss: 0.0218 - val_mse: 0.0218 - 2s/epoch - 25ms/step
# Epoch 2/50
# 85/85 - 1s - loss: 0.0507 - mse: 0.0507 - val_loss: 0.0219 - val_mse: 0.0219 - 603ms/epoch - 7ms/step
# Epoch 3/50
# 85/85 - 1s - loss: 0.0398 - mse: 0.0398 - val_loss: 0.0198 - val_mse: 0.0198 - 600ms/epoch - 7ms/step
# Epoch 4/50
# 85/85 - 1s - loss: 0.0369 - mse: 0.0369 - val_loss: 0.0185 - val_mse: 0.0185 - 609ms/epoch - 7ms/step
# Epoch 5/50
# 85/85 - 1s - loss: 0.0323 - mse: 0.0323 - val_loss: 0.0170 - val_mse: 0.0170 - 621ms/epoch - 7ms/step
# Epoch 6/50
# 85/85 - 1s - loss: 0.0319 - mse: 0.0319 - val_loss: 0.0164 - val_mse: 0.0164 - 597ms/epoch - 7ms/step
# Epoch 7/50
# 85/85 - 1s - loss: 0.0289 - mse: 0.0289 - val_loss: 0.0157 - val_mse: 0.0157 - 596ms/epoch - 7ms/step
# Epoch 8/50
# 85/85 - 1s - loss: 0.0287 - mse: 0.0287 - val_loss: 0.0152 - val_mse: 0.0152 - 603ms/epoch - 7ms/step
# Epoch 9/50
# 85/85 - 1s - loss: 0.0274 - mse: 0.0274 - val_loss: 0.0148 - val_mse: 0.0148 - 609ms/epoch - 7ms/step
# Epoch 10/50
# 85/85 - 1s - loss: 0.0241 - mse: 0.0241 - val_loss: 0.0145 - val_mse: 0.0145 - 601ms/epoch - 7ms/step
# Epoch 11/50
# 85/85 - 1s - loss: 0.0232 - mse: 0.0232 - val_loss: 0.0142 - val_mse: 0.0142 - 611ms/epoch - 7ms/step
# Epoch 12/50
# 85/85 - 1s - loss: 0.0242 - mse: 0.0242 - val_loss: 0.0137 - val_mse: 0.0137 - 605ms/epoch - 7ms/step
# Epoch 13/50
# 85/85 - 1s - loss: 0.0225 - mse: 0.0225 - val_loss: 0.0136 - val_mse: 0.0136 - 647ms/epoch - 8ms/step
# Epoch 14/50
# 85/85 - 1s - loss: 0.0205 - mse: 0.0205 - val_loss: 0.0135 - val_mse: 0.0135 - 616ms/epoch - 7ms/step
# Epoch 15/50
# 85/85 - 1s - loss: 0.0214 - mse: 0.0214 - val_loss: 0.0131 - val_mse: 0.0131 - 610ms/epoch - 7ms/step
# Epoch 16/50
# 85/85 - 1s - loss: 0.0206 - mse: 0.0206 - val_loss: 0.0131 - val_mse: 0.0131 - 642ms/epoch - 8ms/step
# Epoch 17/50
# 85/85 - 1s - loss: 0.0208 - mse: 0.0208 - val_loss: 0.0131 - val_mse: 0.0131 - 628ms/epoch - 7ms/step
# Epoch 18/50
# 85/85 - 1s - loss: 0.0199 - mse: 0.0199 - val_loss: 0.0131 - val_mse: 0.0131 - 620ms/epoch - 7ms/step
# Epoch 18: early stopping

# %%
# Resumen del entrenamiento
n_rows = 2
n_cols = 3

fig, ax = plt.subplots(n_rows, n_cols, figsize=(14,8))
fig.suptitle('Model loss SPI_3')
plt.subplots_adjust(hspace=0.3, wspace=0.3)
for i, (key, value) in enumerate(model_history_dict.items()):
    if i<n_cols:
        ax[0, i].plot(value.history['loss'])
        ax[0, i].plot(value.history['val_loss'])
        ax[0, i].set_title(key, fontsize=10)
        ax[0, i].set_ylabel('loss')
        ax[0, i].set_xlabel('epoch')
        ax[0, i].legend(['train', 'test'], loc='upper right')
    else:
        ax[1, i-n_cols].plot(value.history['loss'])
        ax[1, i-n_cols].plot(value.history['val_loss'])
        ax[1, i-n_cols].set_title(key, fontsize=10)
        ax[1, i-n_cols].set_ylabel('loss')
        ax[1, i-n_cols].set_xlabel('epoch')
        ax[1, i-n_cols].legend(['train', 'test'], loc='upper right')

# %% [markdown]
# # Evaluación del modelo

# %%
test_score_values = []
for key in spi_3_dict.keys():
    print('Evaluación '+ key)
    train_prediction = model.predict(X_train_dict[key], verbose=0)
    test_prediction = model.predict(X_test_dict[key], verbose=0)
    train_score = model.evaluate(X_train_dict[key], y_train_dict[key], verbose=0)
    test_score = model.evaluate(X_test_dict[key], y_test_dict[key], verbose=0)
    test_score_values.append(test_score[0])
    print('Train score: {} MSE'.format(train_score[0]))
    print('Test score: {} MSE'.format(test_score[0]))
    print('')

mean_test_score = sum(test_score_values) / len(test_score_values)
print('Mean Test score: {} MSE'.format(mean_test_score))
# Out:
# Evaluación Demarcación Hidrográfica de las Cuencas Mediterráneas Andaluzas
# Train score: 0.021413346752524376 MSE
# Test score: 0.023852666839957237 MSE
#
# Evaluación Cuenca hidrográfica del Guadalquivir
# Train score: 0.01895398460328579 MSE
# Test score: 0.018179940059781075 MSE
#
# Evaluación Cuenca hidrográfica del Guadiana
# Train score: 0.015694113448262215 MSE
# Test score: 0.015104396268725395 MSE
#
# Evaluación Cuenca hidrográfica del Segura
# Train score: 0.013244029134511948 MSE
# Test score: 0.013989363797008991 MSE
#
# Evaluación Demarcación Hidrográfica Guadalete-Barbate
# Train score: 0.02107679657638073 MSE
# Test score: 0.016626382246613503 MSE
#
# Evaluación Demarcación Hidrográfica Tinto, Odiel y Piedras
# Train score: 0.0169016495347023 MSE
# Test score: 0.013085026293992996 MSE
#
# Mean Test score: 0.016806295917679865 MSE

# %% [markdown]
# # Visualización de la predicción

# %%
# Gráfica con los valores reales frente a los datos de predicción
# Se usa como ejemplo la predicción de la Demarcación Hidrográfica Tinto, Odiel y Piedras
plt.figure(figsize=(12, 8))
train_stamp = np.arange(sequence_size, sequence_size + X_train_dict[keys_names[5]].shape[0])
test_stamp = np.arange(2 * sequence_size + X_train_dict[keys_names[5]].shape[0], len(spi_3_dict[keys_names[5]]))
plt.plot(spi_3_dict[keys_names[5]], label='Valores reales')
plt.plot(train_stamp, train_prediction, label='train prediction')
plt.plot(test_stamp, test_prediction, label = 'test prediction')
plt.title('Predicción SPI_3 '+ keys_names[5])
plt.legend()
plt.show()
