# %%
# Librerias utilizadas
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow import keras
from tensorflow.keras import layers
from keras.callbacks import EarlyStopping
from scikeras.wrappers import KerasRegressor
from sklearn.model_selection import GridSearchCV
import warnings

# %% [markdown]
# # Importación de datos

# %%
csv_names  = ['df_DHCMA', 'df_CHG', 'df_CHGUADIANA',
            'df_CHS', 'df_DHGB', 'df_DHTOP']
path = '..\\DATA\\'
keys_names = ['Demarcación Hidrográfica de las Cuencas Mediterráneas Andaluzas', 'Cuenca hidrográfica del Guadalquivir', 'Cuenca hidrográfica del Guadiana',
              'Cuenca hidrográfica del Segura', 'Demarcación Hidrográfica Guadalete-Barbate', 'Demarcación Hidrográfica Tinto, Odiel y Piedras']
df_dict = {key: pd.read_csv(path+value+'.csv', sep=',', encoding='ISO-8859-1')
           for key, value in zip(keys_names, csv_names)}

# %% [markdown]
# ### Procesado de datos de entrada

# %%
# Función de creación de dataset sequencial con arrays de valores input/output
# Este dataset tiene la estructura adecuada para los datos de entrada
# en la red neuronal
def to_sequences(seq_size, obs):
    x = []
    y = []

    for i in range(len(obs)-seq_size):
        window = obs.iloc[i:(i+seq_size)]
        after_window = obs.iloc[i+seq_size]
        window = [[x] for x in window]
        x.append(window)
        y.append(after_window)
        
    return np.array(x),np.array(y)

# %%
# Creación del dataset de indice IESP
iesp_dict =  {key: value['IESP']
           for key, value in df_dict.items()}

# Eliminación valores vacios iniciales
for key, df in iesp_dict.items():           
    iesp_dict[key] = df.dropna(how='all')

# %%
# Separación en conjunto de entrenamiento y de prueba
# Los datos de prueba empiezan a partir de 2011
iesp_train_dict, iesp_test_dict = {}, {}
for key, df in iesp_dict.items():
    df_train, df_test = train_test_split(df, test_size=0.13, shuffle=False)
    iesp_train_dict[key] = df_train
    iesp_test_dict[key] = df_test

# %%
# Cálculo de datasets sequenciales
sequence_size = 10
X_train_dict, y_train_dict, X_test_dict,y_test_dict = {}, {}, {}, {}

for key, df in iesp_train_dict.items():
    X_train,y_train = to_sequences(sequence_size, df)
    X_train_dict[key] = X_train
    y_train_dict[key] = y_train

for key, df in iesp_test_dict.items():
    X_test,y_test = to_sequences(sequence_size, df)
    X_test_dict[key] = X_test
    y_test_dict[key] = y_test

print("Dimensiones del training set: {}".format(X_train_dict[keys_names[0]].shape))
print("Dimensiones del test set: {}".format(X_test_dict[keys_names[0]].shape))
# Out:
# Dimensiones del training set: (846, 10, 1)
# Dimensiones del test set: (118, 10, 1)

# %% [markdown]
# # Transformer encoder

# %%
# Extraido de https://keras.io/examples/timeseries/timeseries_transformer_classification/
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    # Normalization and Attention
    x = layers.LayerNormalization(epsilon=1e-6)(inputs)
    x = layers.MultiHeadAttention(
        key_dim=head_size, num_heads=num_heads, dropout=dropout
    )(x, x)
    x = layers.Dropout(dropout)(x)
    res = x + inputs

    # Feed Forward Part
    x = layers.LayerNormalization(epsilon=1e-6)(res)
    x = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(x)
    x = layers.Dropout(dropout)(x)
    x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
    return x + res

# %% [markdown]
# # Construccion del modelo

# %%
# Funcion de construccion del modelo
# Extraida de https://keras.io/examples/timeseries/timeseries_transformer_classification/
def build_model(
    input_shape,
    head_size,
    num_heads,
    ff_dim,
    num_transformer_blocks,
    mlp_units,
    dropout=0,
    mlp_dropout=0,
):
    inputs = keras.Input(shape=input_shape)
    x = inputs
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

    x = layers.GlobalAveragePooling1D(data_format="channels_first")(x)
    for dim in mlp_units:
        x = layers.Dense(dim, activation="relu")(x)
        x = layers.Dropout(mlp_dropout)(x)
    outputs = layers.Dense(1)(x)
    return keras.Model(inputs, outputs)

# %% [markdown]
# # Definición del modelo

# %%
input_shape = X_train.shape[1:]
def create_model(optimizer='adam'):
    # Arquitectura del modelo
    model = build_model(
        input_shape,
        head_size=256, 
        num_heads=4, # Numero de capas de atencion paralelas
        ff_dim=4, 
        num_transformer_blocks=2, 
        mlp_units=[128], 
        mlp_dropout=0.4,
        dropout=0.25,
    )
    model.compile(loss='mean_squared_error', optimizer=optimizer, metrics=['mse'])
    
    return model

#  Early stopping para evitar overfitting
es = EarlyStopping(monitor='val_loss', verbose=1, patience=3)

# %% [markdown]
# ### Grid search: búsqueda de mejores parámetros

# %%
# Transformación del modelo para aplicar grid search
model = KerasRegressor(model=create_model, epochs=100, batch_size=10, verbose=0)

# Parámetros de búsqueda
param_grid = {
    'epochs': [50, 100],
    'batch_size' : [5,10],
    'optimizer' : ['SGD', 'adam']
}


# Se ignoran avisos de ejecución del grid search
warnings.simplefilter("ignore")

# Cálculo de grid search
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=2)
grid_result_dict = {}
for key in iesp_train_dict.keys():
    grid_result_dict[key] = grid.fit(X_train_dict[key], y_train_dict[key], callbacks=[es], shuffle=False, validation_data=(
        X_test_dict[key], y_test_dict[key]))
    print(key)
    print("Best: %f using %s" % (grid_result_dict[key].best_score_, grid_result_dict[key].best_params_))
    print('')
# Out:
# Demarcación Hidrográfica de las Cuencas Mediterráneas Andaluzas
# Best: 0.628102 using {'batch_size': 10, 'epochs': 50, 'optimizer': 'adam'}
#
# Cuenca hidrográfica del Guadalquivir
# Best: 0.572355 using {'batch_size': 10, 'epochs': 50, 'optimizer': 'adam'}
#
# Cuenca hidrográfica del Guadiana
# Best: 0.683949 using {'batch_size': 5, 'epochs': 100, 'optimizer': 'SGD'}
#
# Cuenca hidrográfica del Segura
# Best: 0.722512 using {'batch_size': 10, 'epochs': 100, 'optimizer': 'SGD'}
#
# Demarcación Hidrográfica Guadalete-Barbate
# Best: 0.489563 using {'batch_size': 10, 'epochs': 50, 'optimizer': 'adam'}
#
# Demarcación Hidrográfica Tinto, Odiel y Piedras
# Best: 0.555580 using {'batch_size': 5, 'epochs': 50, 'optimizer': 'SGD'}

# %% [markdown]
# # Entrenamiento del modelo

# %%
model_history_dict = {}

for key in iesp_train_dict.keys():
    model = create_model( grid_result_dict[key].best_params_['optimizer'])

    model_history_dict[key] = model.fit(X_train_dict[key], y_train_dict[key], epochs=grid_result_dict[key].best_params_['epochs'],
        batch_size=grid_result_dict[key].best_params_['batch_size'],
        validation_data=(
        X_test_dict[key], y_test_dict[key]), verbose=2, shuffle=False, callbacks=[es]
        )
# Out:
# Epoch 1/50
# 170/170 - 2s - loss: 0.0227 - mse: 0.0227 - val_loss: 0.0079 - val_mse: 0.0079 - 2s/epoch - 13ms/step
# Epoch 2/50
# 170/170 - 1s - loss: 0.0126 - mse: 0.0126 - val_loss: 0.0045 - val_mse: 0.0045 - 726ms/epoch - 4ms/step
# Epoch 3/50
# 170/170 - 1s - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0045 - val_mse: 0.0045 - 740ms/epoch - 4ms/step
# Epoch 4/50
# 170/170 - 1s - loss: 0.0100 - mse: 0.0100 - val_loss: 0.0040 - val_mse: 0.0040 - 765ms/epoch - 5ms/step
# Epoch 5/50
# 170/170 - 1s - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0081 - val_mse: 0.0081 - 737ms/epoch - 4ms/step
# Epoch 6/50
# 170/170 - 1s - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0048 - val_mse: 0.0048 - 727ms/epoch - 4ms/step
# Epoch 7/50
# 170/170 - 1s - loss: 0.0081 - mse: 0.0081 - val_loss: 0.0042 - val_mse: 0.0042 - 718ms/epoch - 4ms/step
# Epoch 7: early stopping
# Epoch 1/50
# 170/170 - 2s - loss: 0.0355 - mse: 0.0355 - val_loss: 0.0248 - val_mse: 0.0248 - 2s/epoch - 13ms/step
# Epoch 2/50
# 170/170 - 1s - loss: 0.0186 - mse: 0.0186 - val_loss: 0.0117 - val_mse: 0.0117 - 705ms/epoch - 4ms/step
# Epoch 3/50
# 170/170 - 1s - loss: 0.0153 - mse: 0.0153 - val_loss: 0.0226 - val_mse: 0.0226 - 707ms/epoch - 4ms/step
# Epoch 4/50
# 170/170 - 1s - loss: 0.0139 - mse: 0.0139 - val_loss: 0.0103 - val_mse: 0.0103 - 709ms/epoch - 4ms/step
# Epoch 5/50
# 170/170 - 1s - loss: 0.0121 - mse: 0.0121 - val_loss: 0.0104 - val_mse: 0.0104 - 709ms/epoch - 4ms/step
# Epoch 6/50
# 170/170 - 1s - loss: 0.0129 - mse: 0.0129 - val_loss: 0.0074 - val_mse: 0.0074 - 706ms/epoch - 4ms/step
# Epoch 7/50
# 170/170 - 1s - loss: 0.0113 - mse: 0.0113 - val_loss: 0.0137 - val_mse: 0.0137 - 707ms/epoch - 4ms/step
# Epoch 8/50
# 170/170 - 1s - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0149 - val_mse: 0.0149 - 710ms/epoch - 4ms/step
# Epoch 9/50
# 170/170 - 1s - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0110 - val_mse: 0.0110 - 704ms/epoch - 4ms/step
# Epoch 9: early stopping
# Epoch 1/50
# 170/170 - 2s - loss: 0.0323 - mse: 0.0323 - val_loss: 0.0204 - val_mse: 0.0204 - 2s/epoch - 13ms/step
# Epoch 2/50
# 170/170 - 1s - loss: 0.0153 - mse: 0.0153 - val_loss: 0.0213 - val_mse: 0.0213 - 689ms/epoch - 4ms/step
# Epoch 3/50
# 170/170 - 1s - loss: 0.0131 - mse: 0.0131 - val_loss: 0.0146 - val_mse: 0.0146 - 692ms/epoch - 4ms/step
# Epoch 4/50
# 170/170 - 1s - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0122 - val_mse: 0.0122 - 694ms/epoch - 4ms/step
# Epoch 5/50
# 170/170 - 1s - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0104 - val_mse: 0.0104 - 699ms/epoch - 4ms/step
# Epoch 6/50
# 170/170 - 1s - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0093 - val_mse: 0.0093 - 689ms/epoch - 4ms/step
# Epoch 7/50
# 170/170 - 1s - loss: 0.0095 - mse: 0.0095 - val_loss: 0.0075 - val_mse: 0.0075 - 696ms/epoch - 4ms/step
# Epoch 8/50
# 170/170 - 1s - loss: 0.0102 - mse: 0.0102 - val_loss: 0.0098 - val_mse: 0.0098 - 691ms/epoch - 4ms/step
# Epoch 9/50
# 170/170 - 1s - loss: 0.0100 - mse: 0.0100 - val_loss: 0.0075 - val_mse: 0.0075 - 693ms/epoch - 4ms/step
# Epoch 10/50
# 170/170 - 1s - loss: 0.0092 - mse: 0.0092 - val_loss: 0.0082 - val_mse: 0.0082 - 696ms/epoch - 4ms/step
# Epoch 10: early stopping
# Epoch 1/50
# 170/170 - 2s - loss: 0.0261 - mse: 0.0261 - val_loss: 0.0072 - val_mse: 0.0072 - 2s/epoch - 13ms/step
# Epoch 2/50
# 170/170 - 1s - loss: 0.0179 - mse: 0.0179 - val_loss: 0.0097 - val_mse: 0.0097 - 687ms/epoch - 4ms/step
# Epoch 3/50
# 170/170 - 1s - loss: 0.0147 - mse: 0.0147 - val_loss: 0.0053 - val_mse: 0.0053 - 701ms/epoch - 4ms/step
# Epoch 4/50
# 170/170 - 1s - loss: 0.0121 - mse: 0.0121 - val_loss: 0.0065 - val_mse: 0.0065 - 685ms/epoch - 4ms/step
# Epoch 5/50
# 170/170 - 1s - loss: 0.0110 - mse: 0.0110 - val_loss: 0.0086 - val_mse: 0.0086 - 685ms/epoch - 4ms/step
# Epoch 6/50
# 170/170 - 1s - loss: 0.0099 - mse: 0.0099 - val_loss: 0.0057 - val_mse: 0.0057 - 687ms/epoch - 4ms/step
# Epoch 6: early stopping
# Epoch 1/50
# 170/170 - 2s - loss: 0.0197 - mse: 0.0197 - val_loss: 0.0084 - val_mse: 0.0084 - 2s/epoch - 13ms/step
# Epoch 2/50
# 170/170 - 1s - loss: 0.0139 - mse: 0.0139 - val_loss: 0.0067 - val_mse: 0.0067 - 703ms/epoch - 4ms/step
# Epoch 3/50
# 170/170 - 1s - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0076 - val_mse: 0.0076 - 687ms/epoch - 4ms/step
# Epoch 4/50
# 170/170 - 1s - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0052 - val_mse: 0.0052 - 691ms/epoch - 4ms/step
# Epoch 5/50
# 170/170 - 1s - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0067 - val_mse: 0.0067 - 689ms/epoch - 4ms/step
# Epoch 6/50
# 170/170 - 1s - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0064 - val_mse: 0.0064 - 683ms/epoch - 4ms/step
# Epoch 7/50
# 170/170 - 1s - loss: 0.0096 - mse: 0.0096 - val_loss: 0.0065 - val_mse: 0.0065 - 685ms/epoch - 4ms/step
# Epoch 7: early stopping
# Epoch 1/50
# 170/170 - 2s - loss: 0.0279 - mse: 0.0279 - val_loss: 0.0054 - val_mse: 0.0054 - 2s/epoch - 13ms/step
# Epoch 2/50
# 170/170 - 1s - loss: 0.0188 - mse: 0.0188 - val_loss: 0.0062 - val_mse: 0.0062 - 790ms/epoch - 5ms/step
# Epoch 3/50
# 170/170 - 1s - loss: 0.0174 - mse: 0.0174 - val_loss: 0.0055 - val_mse: 0.0055 - 996ms/epoch - 6ms/step
# Epoch 4/50
# 170/170 - 1s - loss: 0.0154 - mse: 0.0154 - val_loss: 0.0053 - val_mse: 0.0053 - 994ms/epoch - 6ms/step
# Epoch 5/50
# 170/170 - 1s - loss: 0.0142 - mse: 0.0142 - val_loss: 0.0054 - val_mse: 0.0054 - 989ms/epoch - 6ms/step
# Epoch 6/50
# 170/170 - 1s - loss: 0.0136 - mse: 0.0136 - val_loss: 0.0066 - val_mse: 0.0066 - 894ms/epoch - 5ms/step
# Epoch 7/50
# 170/170 - 1s - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0041 - val_mse: 0.0041 - 814ms/epoch - 5ms/step
# Epoch 8/50
# 170/170 - 1s - loss: 0.0119 - mse: 0.0119 - val_loss: 0.0070 - val_mse: 0.0070 - 777ms/epoch - 5ms/step
# Epoch 9/50
# 170/170 - 1s - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0045 - val_mse: 0.0045 - 830ms/epoch - 5ms/step
# Epoch 10/50
# 170/170 - 1s - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0046 - val_mse: 0.0046 - 812ms/epoch - 5ms/step
# Epoch 10: early stopping

# %%
# Resumen del entrenamiento
n_rows = 2
n_cols = 3

fig, ax = plt.subplots(n_rows, n_cols, figsize=(14,8))
fig.suptitle('Model loss IESP')
plt.subplots_adjust(hspace=0.3, wspace=0.3)
for i, (key, value) in enumerate(model_history_dict.items()):
    if i<n_cols:
        ax[0, i].plot(value.history['loss'])
        ax[0, i].plot(value.history['val_loss'])
        ax[0, i].set_title(key, fontsize=10)
        ax[0, i].set_ylabel('loss')
        ax[0, i].set_xlabel('epoch')
        ax[0, i].legend(['train', 'test'], loc='upper right')
    else:
        ax[1, i-n_cols].plot(value.history['loss'])
        ax[1, i-n_cols].plot(value.history['val_loss'])
        ax[1, i-n_cols].set_title(key, fontsize=10)
        ax[1, i-n_cols].set_ylabel('loss')
        ax[1, i-n_cols].set_xlabel('epoch')
        ax[1, i-n_cols].legend(['train', 'test'], loc='upper right')

# %% [markdown]
# # Evaluación del modelo

# %%
test_score_values = []
for key in iesp_dict.keys():
    print('Evaluación '+ key)
    train_prediction = model.predict(X_train_dict[key], verbose=0)
    test_prediction = model.predict(X_test_dict[key], verbose=0)
    train_score = model.evaluate(X_train_dict[key], y_train_dict[key], verbose=0)
    test_score = model.evaluate(X_test_dict[key], y_test_dict[key], verbose=0)
    test_score_values.append(test_score[0])
    print('Train score: {} MSE'.format(train_score[0]))
    print('Test score: {} MSE'.format(test_score[0]))
    print('')

mean_test_score = sum(test_score_values) / len(test_score_values)
print('Mean Test score: {} MSE'.format(mean_test_score))
# Out:
# Evaluación Demarcación Hidrográfica de las Cuencas Mediterráneas Andaluzas
# Train score: 0.00594802713021636 MSE
# Test score: 0.0048497263342142105 MSE
#
# Evaluación Cuenca hidrográfica del Guadalquivir
# Train score: 0.008828356862068176 MSE
# Test score: 0.005868467036634684 MSE
#
# Evaluación Cuenca hidrográfica del Guadiana
# Train score: 0.00872754491865635 MSE
# Test score: 0.004324445966631174 MSE
#
# Evaluación Cuenca hidrográfica del Segura
# Train score: 0.006918508559465408 MSE
# Test score: 0.005191469565033913 MSE
#
# Evaluación Demarcación Hidrográfica Guadalete-Barbate
# Train score: 0.010799604468047619 MSE
# Test score: 0.007329525891691446 MSE
#
# Evaluación Demarcación Hidrográfica Tinto, Odiel y Piedras
# Train score: 0.009001685306429863 MSE
# Test score: 0.0045806472189724445 MSE
#
# Mean Test score: 0.005357380335529645 MSE

# %% [markdown]
# # Visualización de la predicción

# %%
# Gráfica con los valores reales frente a los datos de predicción
# Se usa como ejemplo la predicción de la Demarcación Hidrográfica Tinto, Odiel y Piedras
plt.figure(figsize=(12, 8))
train_stamp = np.arange(sequence_size-1, sequence_size + X_train_dict[keys_names[5]].shape[0]-1)
test_stamp = np.arange(2 * sequence_size-1 + X_train_dict[keys_names[5]].shape[0], len(iesp_dict[keys_names[5]])-1)
plt.plot(iesp_dict[keys_names[5]], label='Valores reales')
plt.plot(train_stamp, train_prediction, label='train prediction')
plt.plot(test_stamp, test_prediction, label = 'test prediction')
plt.title('Predicción IESP '+ keys_names[5])
plt.legend()
plt.show()
