# %%
# Librerias utilizadas
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow import keras
from tensorflow.keras import layers
from keras.callbacks import EarlyStopping
from scikeras.wrappers import KerasRegressor
from sklearn.model_selection import GridSearchCV
import warnings

# %% [markdown]
# # Importación de datos

# %%
csv_names  = ['df_DHCMA', 'df_CHG', 'df_CHGUADIANA',
            'df_CHS', 'df_DHGB', 'df_DHTOP']
path = '..\\DATA\\'
keys_names = ['Demarcación Hidrográfica de las Cuencas Mediterráneas Andaluzas', 'Cuenca hidrográfica del Guadalquivir', 'Cuenca hidrográfica del Guadiana',
              'Cuenca hidrográfica del Segura', 'Demarcación Hidrográfica Guadalete-Barbate', 'Demarcación Hidrográfica Tinto, Odiel y Piedras']
df_dict = {key: pd.read_csv(path+value+'.csv', sep=',', encoding='ISO-8859-1')
           for key, value in zip(keys_names, csv_names)}

# %% [markdown]
# ### Procesado de datos de entrada

# %%
# Función de creación de dataset sequencial con arrays de valores input/output
# Este dataset tiene la estructura adecuada para los datos de entrada
# en la red neuronal
def to_sequences(seq_size, obs):
    x = []
    y = []

    for i in range(len(obs)-seq_size):
        window = obs.iloc[i:(i+seq_size)]
        after_window = obs.iloc[i+seq_size]
        window = [[x] for x in window]
        x.append(window)
        y.append(after_window)
        
    return np.array(x),np.array(y)

# %%
# Creación del dataset de indice SPI_6
spi_6_dict =  {key: value['spi_6']
           for key, value in df_dict.items()}

# Eliminación valores vacios iniciales
for key, df in spi_6_dict.items():           
    spi_6_dict[key] = df.dropna(how='all')

# %%
# Separación en conjunto de entrenamiento y de prueba
# Los datos de prueba empiezan a partir de 2011
spi_6_train_dict, spi_6_test_dict = {}, {}
for key, df in spi_6_dict.items():
    df_train, df_test = train_test_split(df, test_size=0.13, shuffle=False)
    spi_6_train_dict[key] = df_train
    spi_6_test_dict[key] = df_test

# %%
# Cálculo de datasets sequenciales
sequence_size = 10
X_train_dict, y_train_dict, X_test_dict,y_test_dict = {}, {}, {}, {}

for key, df in spi_6_train_dict.items():
    X_train,y_train = to_sequences(sequence_size, df)
    X_train_dict[key] = X_train
    y_train_dict[key] = y_train

for key, df in spi_6_test_dict.items():
    X_test,y_test = to_sequences(sequence_size, df)
    X_test_dict[key] = X_test
    y_test_dict[key] = y_test

print("Dimensiones del training set: {}".format(X_train_dict[keys_names[0]].shape))
print("Dimensiones del test set: {}".format(X_test_dict[keys_names[0]].shape))
# Out:
# Dimensiones del training set: (841, 10, 1)
# Dimensiones del test set: (118, 10, 1)

# %% [markdown]
# # Transformer encoder

# %%
# Extraido de https://keras.io/examples/timeseries/timeseries_transformer_classification/
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    # Normalization and Attention
    x = layers.LayerNormalization(epsilon=1e-6)(inputs)
    x = layers.MultiHeadAttention(
        key_dim=head_size, num_heads=num_heads, dropout=dropout
    )(x, x)
    x = layers.Dropout(dropout)(x)
    res = x + inputs

    # Feed Forward Part
    x = layers.LayerNormalization(epsilon=1e-6)(res)
    x = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(x)
    x = layers.Dropout(dropout)(x)
    x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
    return x + res

# %% [markdown]
# # Construccion del modelo

# %%
# Funcion de construccion del modelo
# Extraida de https://keras.io/examples/timeseries/timeseries_transformer_classification/
def build_model(
    input_shape,
    head_size,
    num_heads,
    ff_dim,
    num_transformer_blocks,
    mlp_units,
    dropout=0,
    mlp_dropout=0,
):
    inputs = keras.Input(shape=input_shape)
    x = inputs
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

    x = layers.GlobalAveragePooling1D(data_format="channels_first")(x)
    for dim in mlp_units:
        x = layers.Dense(dim, activation="relu")(x)
        x = layers.Dropout(mlp_dropout)(x)
    outputs = layers.Dense(1)(x)
    return keras.Model(inputs, outputs)

# %% [markdown]
# # Definición del modelo

# %%
input_shape = X_train.shape[1:]
def create_model(optimizer='adam'):
    # Arquitectura del modelo
    model = build_model(
        input_shape,
        head_size=256, 
        num_heads=4, # Numero de capas de atencion paralelas
        ff_dim=4, 
        num_transformer_blocks=2, 
        mlp_units=[128], 
        mlp_dropout=0.4,
        dropout=0.25,
    )
    model.compile(loss='mean_squared_error', optimizer=optimizer, metrics=['mse'])
    
    return model

#  Early stopping para evitar overfitting
es = EarlyStopping(monitor='val_loss', verbose=1, patience=3)

# %% [markdown]
# ### Grid search: búsqueda de mejores parámetros

# %%
# Transformación del modelo para aplicar grid search
model = KerasRegressor(model=create_model, epochs=100, batch_size=10, verbose=0)

# Parámetros de búsqueda
param_grid = {
    'epochs': [50, 100],
    'batch_size' : [5,10],
    'optimizer' : ['SGD', 'adam']
}


# Se ignoran avisos de ejecución del grid search
warnings.simplefilter("ignore")

# Cálculo de grid search
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=4)
grid_result_dict = {}
for key in spi_6_train_dict.keys():
    grid_result_dict[key] = grid.fit(X_train_dict[key], y_train_dict[key], callbacks=[es], shuffle=False, validation_data=(
        X_test_dict[key], y_test_dict[key]))
    print(key)
    print("Best: %f using %s" % (grid_result_dict[key].best_score_, grid_result_dict[key].best_params_))
    print('')
# Out:
# Demarcación Hidrográfica de las Cuencas Mediterráneas Andaluzas
# Best: 0.664263 using {'batch_size': 10, 'epochs': 50, 'optimizer': 'SGD'}
#
# Cuenca hidrográfica del Guadalquivir
# Best: 0.671292 using {'batch_size': 10, 'epochs': 50, 'optimizer': 'adam'}
#
# Cuenca hidrográfica del Guadiana
# Best: 0.702148 using {'batch_size': 10, 'epochs': 50, 'optimizer': 'adam'}
#
# Cuenca hidrográfica del Segura
# Best: 0.778488 using {'batch_size': 5, 'epochs': 50, 'optimizer': 'SGD'}
#
# Demarcación Hidrográfica Guadalete-Barbate
# Best: 0.627214 using {'batch_size': 10, 'epochs': 50, 'optimizer': 'SGD'}
#
# Demarcación Hidrográfica Tinto, Odiel y Piedras
# Best: 0.675338 using {'batch_size': 10, 'epochs': 100, 'optimizer': 'SGD'}

# %% [markdown]
# # Entrenamiento del modelo

# %%
model_history_dict = {}

for key in spi_6_train_dict.keys():
    model = create_model( grid_result_dict[key].best_params_['optimizer'])

    model_history_dict[key] = model.fit(X_train_dict[key], y_train_dict[key], epochs=grid_result_dict[key].best_params_['epochs'],
        batch_size=grid_result_dict[key].best_params_['batch_size'],
        validation_data=(
        X_test_dict[key], y_test_dict[key]), verbose=2, shuffle=False, callbacks=[es]
        )
# Out:
# Epoch 1/100
# 85/85 - 3s - loss: 0.0742 - mse: 0.0742 - val_loss: 0.0253 - val_mse: 0.0253 - 3s/epoch - 38ms/step
# Epoch 2/100
# 85/85 - 1s - loss: 0.0354 - mse: 0.0354 - val_loss: 0.0221 - val_mse: 0.0221 - 834ms/epoch - 10ms/step
# Epoch 3/100
# 85/85 - 1s - loss: 0.0278 - mse: 0.0278 - val_loss: 0.0208 - val_mse: 0.0208 - 840ms/epoch - 10ms/step
# Epoch 4/100
# 85/85 - 1s - loss: 0.0227 - mse: 0.0227 - val_loss: 0.0158 - val_mse: 0.0158 - 840ms/epoch - 10ms/step
# Epoch 5/100
# 85/85 - 1s - loss: 0.0206 - mse: 0.0206 - val_loss: 0.0159 - val_mse: 0.0159 - 846ms/epoch - 10ms/step
# Epoch 6/100
# 85/85 - 1s - loss: 0.0204 - mse: 0.0204 - val_loss: 0.0164 - val_mse: 0.0164 - 868ms/epoch - 10ms/step
# Epoch 7/100
# 85/85 - 1s - loss: 0.0176 - mse: 0.0176 - val_loss: 0.0152 - val_mse: 0.0152 - 842ms/epoch - 10ms/step
# Epoch 8/100
# 85/85 - 1s - loss: 0.0167 - mse: 0.0167 - val_loss: 0.0116 - val_mse: 0.0116 - 835ms/epoch - 10ms/step
# Epoch 9/100
# 85/85 - 1s - loss: 0.0170 - mse: 0.0170 - val_loss: 0.0113 - val_mse: 0.0113 - 848ms/epoch - 10ms/step
# Epoch 10/100
# 85/85 - 1s - loss: 0.0156 - mse: 0.0156 - val_loss: 0.0111 - val_mse: 0.0111 - 842ms/epoch - 10ms/step
# Epoch 11/100
# 85/85 - 1s - loss: 0.0146 - mse: 0.0146 - val_loss: 0.0120 - val_mse: 0.0120 - 840ms/epoch - 10ms/step
# Epoch 12/100
# 85/85 - 1s - loss: 0.0155 - mse: 0.0155 - val_loss: 0.0109 - val_mse: 0.0109 - 835ms/epoch - 10ms/step
# Epoch 13/100
# 85/85 - 1s - loss: 0.0152 - mse: 0.0152 - val_loss: 0.0101 - val_mse: 0.0101 - 837ms/epoch - 10ms/step
# Epoch 14/100
# 85/85 - 1s - loss: 0.0141 - mse: 0.0141 - val_loss: 0.0110 - val_mse: 0.0110 - 844ms/epoch - 10ms/step
# Epoch 15/100
# 85/85 - 1s - loss: 0.0145 - mse: 0.0145 - val_loss: 0.0102 - val_mse: 0.0102 - 839ms/epoch - 10ms/step
# Epoch 16/100
# 85/85 - 1s - loss: 0.0132 - mse: 0.0132 - val_loss: 0.0095 - val_mse: 0.0095 - 837ms/epoch - 10ms/step
# Epoch 17/100
# 85/85 - 1s - loss: 0.0137 - mse: 0.0137 - val_loss: 0.0092 - val_mse: 0.0092 - 834ms/epoch - 10ms/step
# Epoch 18/100
# 85/85 - 1s - loss: 0.0132 - mse: 0.0132 - val_loss: 0.0093 - val_mse: 0.0093 - 837ms/epoch - 10ms/step
# Epoch 19/100
# 85/85 - 1s - loss: 0.0128 - mse: 0.0128 - val_loss: 0.0098 - val_mse: 0.0098 - 836ms/epoch - 10ms/step
# Epoch 20/100
# 85/85 - 1s - loss: 0.0132 - mse: 0.0132 - val_loss: 0.0084 - val_mse: 0.0084 - 837ms/epoch - 10ms/step
# Epoch 21/100
# 85/85 - 1s - loss: 0.0126 - mse: 0.0126 - val_loss: 0.0093 - val_mse: 0.0093 - 843ms/epoch - 10ms/step
# Epoch 22/100
# 85/85 - 1s - loss: 0.0128 - mse: 0.0128 - val_loss: 0.0083 - val_mse: 0.0083 - 840ms/epoch - 10ms/step
# Epoch 23/100
# 85/85 - 1s - loss: 0.0124 - mse: 0.0124 - val_loss: 0.0082 - val_mse: 0.0082 - 834ms/epoch - 10ms/step
# Epoch 24/100
# 85/85 - 1s - loss: 0.0126 - mse: 0.0126 - val_loss: 0.0090 - val_mse: 0.0090 - 837ms/epoch - 10ms/step
# Epoch 25/100
# 85/85 - 1s - loss: 0.0128 - mse: 0.0128 - val_loss: 0.0085 - val_mse: 0.0085 - 843ms/epoch - 10ms/step
# Epoch 26/100
# 85/85 - 1s - loss: 0.0122 - mse: 0.0122 - val_loss: 0.0090 - val_mse: 0.0090 - 838ms/epoch - 10ms/step
# Epoch 26: early stopping
# Epoch 1/100
# 85/85 - 3s - loss: 0.0554 - mse: 0.0554 - val_loss: 0.0203 - val_mse: 0.0203 - 3s/epoch - 39ms/step
# Epoch 2/100
# 85/85 - 1s - loss: 0.0348 - mse: 0.0348 - val_loss: 0.0178 - val_mse: 0.0178 - 785ms/epoch - 9ms/step
# Epoch 3/100
# 85/85 - 1s - loss: 0.0307 - mse: 0.0307 - val_loss: 0.0167 - val_mse: 0.0167 - 808ms/epoch - 10ms/step
# Epoch 4/100
# 85/85 - 1s - loss: 0.0278 - mse: 0.0278 - val_loss: 0.0145 - val_mse: 0.0145 - 812ms/epoch - 10ms/step
# Epoch 5/100
# 85/85 - 1s - loss: 0.0242 - mse: 0.0242 - val_loss: 0.0148 - val_mse: 0.0148 - 803ms/epoch - 9ms/step
# Epoch 6/100
# 85/85 - 1s - loss: 0.0249 - mse: 0.0249 - val_loss: 0.0120 - val_mse: 0.0120 - 817ms/epoch - 10ms/step
# Epoch 7/100
# 85/85 - 1s - loss: 0.0211 - mse: 0.0211 - val_loss: 0.0131 - val_mse: 0.0131 - 799ms/epoch - 9ms/step
# Epoch 8/100
# 85/85 - 1s - loss: 0.0209 - mse: 0.0209 - val_loss: 0.0134 - val_mse: 0.0134 - 775ms/epoch - 9ms/step
# Epoch 9/100
# 85/85 - 1s - loss: 0.0205 - mse: 0.0205 - val_loss: 0.0115 - val_mse: 0.0115 - 759ms/epoch - 9ms/step
# Epoch 10/100
# 85/85 - 1s - loss: 0.0197 - mse: 0.0197 - val_loss: 0.0132 - val_mse: 0.0132 - 776ms/epoch - 9ms/step
# Epoch 11/100
# 85/85 - 1s - loss: 0.0182 - mse: 0.0182 - val_loss: 0.0117 - val_mse: 0.0117 - 782ms/epoch - 9ms/step
# Epoch 12/100
# 85/85 - 1s - loss: 0.0174 - mse: 0.0174 - val_loss: 0.0099 - val_mse: 0.0099 - 786ms/epoch - 9ms/step
# Epoch 13/100
# 85/85 - 1s - loss: 0.0174 - mse: 0.0174 - val_loss: 0.0106 - val_mse: 0.0106 - 800ms/epoch - 9ms/step
# Epoch 14/100
# 85/85 - 1s - loss: 0.0172 - mse: 0.0172 - val_loss: 0.0098 - val_mse: 0.0098 - 804ms/epoch - 9ms/step
# Epoch 15/100
# 85/85 - 1s - loss: 0.0174 - mse: 0.0174 - val_loss: 0.0109 - val_mse: 0.0109 - 801ms/epoch - 9ms/step
# Epoch 16/100
# 85/85 - 1s - loss: 0.0162 - mse: 0.0162 - val_loss: 0.0118 - val_mse: 0.0118 - 808ms/epoch - 10ms/step
# Epoch 17/100
# 85/85 - 1s - loss: 0.0162 - mse: 0.0162 - val_loss: 0.0098 - val_mse: 0.0098 - 808ms/epoch - 10ms/step
# Epoch 18/100
# 85/85 - 1s - loss: 0.0155 - mse: 0.0155 - val_loss: 0.0094 - val_mse: 0.0094 - 831ms/epoch - 10ms/step
# Epoch 19/100
# 85/85 - 1s - loss: 0.0153 - mse: 0.0153 - val_loss: 0.0092 - val_mse: 0.0092 - 830ms/epoch - 10ms/step
# Epoch 20/100
# 85/85 - 1s - loss: 0.0148 - mse: 0.0148 - val_loss: 0.0092 - val_mse: 0.0092 - 834ms/epoch - 10ms/step
# Epoch 21/100
# 85/85 - 1s - loss: 0.0156 - mse: 0.0156 - val_loss: 0.0092 - val_mse: 0.0092 - 829ms/epoch - 10ms/step
# Epoch 22/100
# 85/85 - 1s - loss: 0.0147 - mse: 0.0147 - val_loss: 0.0096 - val_mse: 0.0096 - 830ms/epoch - 10ms/step
# Epoch 23/100
# 85/85 - 1s - loss: 0.0142 - mse: 0.0142 - val_loss: 0.0094 - val_mse: 0.0094 - 825ms/epoch - 10ms/step
# Epoch 23: early stopping
# Epoch 1/100
# 85/85 - 4s - loss: 0.0636 - mse: 0.0636 - val_loss: 0.0258 - val_mse: 0.0258 - 4s/epoch - 46ms/step
# Epoch 2/100
# 85/85 - 1s - loss: 0.0349 - mse: 0.0349 - val_loss: 0.0192 - val_mse: 0.0192 - 816ms/epoch - 10ms/step
# Epoch 3/100
# 85/85 - 1s - loss: 0.0283 - mse: 0.0283 - val_loss: 0.0161 - val_mse: 0.0161 - 813ms/epoch - 10ms/step
# Epoch 4/100
# 85/85 - 1s - loss: 0.0247 - mse: 0.0247 - val_loss: 0.0140 - val_mse: 0.0140 - 801ms/epoch - 9ms/step
# Epoch 5/100
# 85/85 - 1s - loss: 0.0232 - mse: 0.0232 - val_loss: 0.0156 - val_mse: 0.0156 - 812ms/epoch - 10ms/step
# Epoch 6/100
# 85/85 - 1s - loss: 0.0214 - mse: 0.0214 - val_loss: 0.0143 - val_mse: 0.0143 - 806ms/epoch - 9ms/step
# Epoch 7/100
# 85/85 - 1s - loss: 0.0202 - mse: 0.0202 - val_loss: 0.0116 - val_mse: 0.0116 - 800ms/epoch - 9ms/step
# Epoch 8/100
# 85/85 - 1s - loss: 0.0185 - mse: 0.0185 - val_loss: 0.0115 - val_mse: 0.0115 - 806ms/epoch - 9ms/step
# Epoch 9/100
# 85/85 - 1s - loss: 0.0175 - mse: 0.0175 - val_loss: 0.0116 - val_mse: 0.0116 - 809ms/epoch - 10ms/step
# Epoch 10/100
# 85/85 - 1s - loss: 0.0175 - mse: 0.0175 - val_loss: 0.0102 - val_mse: 0.0102 - 815ms/epoch - 10ms/step
# Epoch 11/100
# 85/85 - 1s - loss: 0.0162 - mse: 0.0162 - val_loss: 0.0105 - val_mse: 0.0105 - 804ms/epoch - 9ms/step
# Epoch 12/100
# 85/85 - 1s - loss: 0.0156 - mse: 0.0156 - val_loss: 0.0110 - val_mse: 0.0110 - 804ms/epoch - 9ms/step
# Epoch 13/100
# 85/85 - 1s - loss: 0.0157 - mse: 0.0157 - val_loss: 0.0098 - val_mse: 0.0098 - 785ms/epoch - 9ms/step
# Epoch 14/100
# 85/85 - 1s - loss: 0.0153 - mse: 0.0153 - val_loss: 0.0099 - val_mse: 0.0099 - 768ms/epoch - 9ms/step
# Epoch 15/100
# 85/85 - 1s - loss: 0.0150 - mse: 0.0150 - val_loss: 0.0104 - val_mse: 0.0104 - 773ms/epoch - 9ms/step
# Epoch 16/100
# 85/85 - 1s - loss: 0.0155 - mse: 0.0155 - val_loss: 0.0101 - val_mse: 0.0101 - 760ms/epoch - 9ms/step
# Epoch 16: early stopping
# Epoch 1/100
# 85/85 - 3s - loss: 0.0578 - mse: 0.0578 - val_loss: 0.0256 - val_mse: 0.0256 - 3s/epoch - 40ms/step
# Epoch 2/100
# 85/85 - 1s - loss: 0.0370 - mse: 0.0370 - val_loss: 0.0200 - val_mse: 0.0200 - 765ms/epoch - 9ms/step
# Epoch 3/100
# 85/85 - 1s - loss: 0.0300 - mse: 0.0300 - val_loss: 0.0162 - val_mse: 0.0162 - 761ms/epoch - 9ms/step
# Epoch 4/100
# 85/85 - 1s - loss: 0.0271 - mse: 0.0271 - val_loss: 0.0155 - val_mse: 0.0155 - 759ms/epoch - 9ms/step
# Epoch 5/100
# 85/85 - 1s - loss: 0.0228 - mse: 0.0228 - val_loss: 0.0140 - val_mse: 0.0140 - 750ms/epoch - 9ms/step
# Epoch 6/100
# 85/85 - 1s - loss: 0.0214 - mse: 0.0214 - val_loss: 0.0137 - val_mse: 0.0137 - 766ms/epoch - 9ms/step
# Epoch 7/100
# 85/85 - 1s - loss: 0.0197 - mse: 0.0197 - val_loss: 0.0145 - val_mse: 0.0145 - 760ms/epoch - 9ms/step
# Epoch 8/100
# 85/85 - 1s - loss: 0.0192 - mse: 0.0192 - val_loss: 0.0115 - val_mse: 0.0115 - 772ms/epoch - 9ms/step
# Epoch 9/100
# 85/85 - 1s - loss: 0.0184 - mse: 0.0184 - val_loss: 0.0131 - val_mse: 0.0131 - 777ms/epoch - 9ms/step
# Epoch 10/100
# 85/85 - 1s - loss: 0.0173 - mse: 0.0173 - val_loss: 0.0106 - val_mse: 0.0106 - 789ms/epoch - 9ms/step
# Epoch 11/100
# 85/85 - 1s - loss: 0.0162 - mse: 0.0162 - val_loss: 0.0118 - val_mse: 0.0118 - 787ms/epoch - 9ms/step
# Epoch 12/100
# 85/85 - 1s - loss: 0.0155 - mse: 0.0155 - val_loss: 0.0114 - val_mse: 0.0114 - 791ms/epoch - 9ms/step
# Epoch 13/100
# 85/85 - 1s - loss: 0.0161 - mse: 0.0161 - val_loss: 0.0120 - val_mse: 0.0120 - 803ms/epoch - 9ms/step
# Epoch 13: early stopping
# Epoch 1/100
# 85/85 - 3s - loss: 0.0755 - mse: 0.0755 - val_loss: 0.0176 - val_mse: 0.0176 - 3s/epoch - 40ms/step
# Epoch 2/100
# 85/85 - 1s - loss: 0.0313 - mse: 0.0313 - val_loss: 0.0163 - val_mse: 0.0163 - 737ms/epoch - 9ms/step
# Epoch 3/100
# 85/85 - 1s - loss: 0.0276 - mse: 0.0276 - val_loss: 0.0161 - val_mse: 0.0161 - 748ms/epoch - 9ms/step
# Epoch 4/100
# 85/85 - 1s - loss: 0.0241 - mse: 0.0241 - val_loss: 0.0129 - val_mse: 0.0129 - 772ms/epoch - 9ms/step
# Epoch 5/100
# 85/85 - 1s - loss: 0.0224 - mse: 0.0224 - val_loss: 0.0110 - val_mse: 0.0110 - 775ms/epoch - 9ms/step
# Epoch 6/100
# 85/85 - 1s - loss: 0.0198 - mse: 0.0198 - val_loss: 0.0106 - val_mse: 0.0106 - 789ms/epoch - 9ms/step
# Epoch 7/100
# 85/85 - 1s - loss: 0.0173 - mse: 0.0173 - val_loss: 0.0102 - val_mse: 0.0102 - 788ms/epoch - 9ms/step
# Epoch 8/100
# 85/85 - 1s - loss: 0.0167 - mse: 0.0167 - val_loss: 0.0093 - val_mse: 0.0093 - 781ms/epoch - 9ms/step
# Epoch 9/100
# 85/85 - 1s - loss: 0.0167 - mse: 0.0167 - val_loss: 0.0093 - val_mse: 0.0093 - 787ms/epoch - 9ms/step
# Epoch 10/100
# 85/85 - 1s - loss: 0.0158 - mse: 0.0158 - val_loss: 0.0093 - val_mse: 0.0093 - 782ms/epoch - 9ms/step
# Epoch 11/100
# 85/85 - 1s - loss: 0.0155 - mse: 0.0155 - val_loss: 0.0090 - val_mse: 0.0090 - 788ms/epoch - 9ms/step
# Epoch 12/100
# 85/85 - 1s - loss: 0.0153 - mse: 0.0153 - val_loss: 0.0086 - val_mse: 0.0086 - 791ms/epoch - 9ms/step
# Epoch 13/100
# 85/85 - 1s - loss: 0.0138 - mse: 0.0138 - val_loss: 0.0085 - val_mse: 0.0085 - 759ms/epoch - 9ms/step
# Epoch 14/100
# 85/85 - 1s - loss: 0.0141 - mse: 0.0141 - val_loss: 0.0093 - val_mse: 0.0093 - 756ms/epoch - 9ms/step
# Epoch 15/100
# 85/85 - 1s - loss: 0.0132 - mse: 0.0132 - val_loss: 0.0079 - val_mse: 0.0079 - 733ms/epoch - 9ms/step
# Epoch 16/100
# 85/85 - 1s - loss: 0.0136 - mse: 0.0136 - val_loss: 0.0080 - val_mse: 0.0080 - 743ms/epoch - 9ms/step
# Epoch 17/100
# 85/85 - 1s - loss: 0.0133 - mse: 0.0133 - val_loss: 0.0087 - val_mse: 0.0087 - 745ms/epoch - 9ms/step
# Epoch 18/100
# 85/85 - 1s - loss: 0.0131 - mse: 0.0131 - val_loss: 0.0083 - val_mse: 0.0083 - 776ms/epoch - 9ms/step
# Epoch 18: early stopping
# Epoch 1/100
# 85/85 - 3s - loss: 0.0570 - mse: 0.0570 - val_loss: 0.0283 - val_mse: 0.0283 - 3s/epoch - 40ms/step
# Epoch 2/100
# 85/85 - 1s - loss: 0.0340 - mse: 0.0340 - val_loss: 0.0140 - val_mse: 0.0140 - 752ms/epoch - 9ms/step
# Epoch 3/100
# 85/85 - 1s - loss: 0.0284 - mse: 0.0284 - val_loss: 0.0169 - val_mse: 0.0169 - 725ms/epoch - 9ms/step
# Epoch 4/100
# 85/85 - 1s - loss: 0.0244 - mse: 0.0244 - val_loss: 0.0121 - val_mse: 0.0121 - 719ms/epoch - 8ms/step
# Epoch 5/100
# 85/85 - 1s - loss: 0.0215 - mse: 0.0215 - val_loss: 0.0113 - val_mse: 0.0113 - 710ms/epoch - 8ms/step
# Epoch 6/100
# 85/85 - 1s - loss: 0.0198 - mse: 0.0198 - val_loss: 0.0089 - val_mse: 0.0089 - 715ms/epoch - 8ms/step
# Epoch 7/100
# 85/85 - 1s - loss: 0.0185 - mse: 0.0185 - val_loss: 0.0084 - val_mse: 0.0084 - 690ms/epoch - 8ms/step
# Epoch 8/100
# 85/85 - 1s - loss: 0.0166 - mse: 0.0166 - val_loss: 0.0083 - val_mse: 0.0083 - 698ms/epoch - 8ms/step
# Epoch 9/100
# 85/85 - 1s - loss: 0.0159 - mse: 0.0159 - val_loss: 0.0088 - val_mse: 0.0088 - 699ms/epoch - 8ms/step
# Epoch 10/100
# 85/85 - 1s - loss: 0.0159 - mse: 0.0159 - val_loss: 0.0086 - val_mse: 0.0086 - 718ms/epoch - 8ms/step
# Epoch 11/100
# 85/85 - 1s - loss: 0.0151 - mse: 0.0151 - val_loss: 0.0080 - val_mse: 0.0080 - 740ms/epoch - 9ms/step
# Epoch 12/100
# 85/85 - 1s - loss: 0.0138 - mse: 0.0138 - val_loss: 0.0076 - val_mse: 0.0076 - 761ms/epoch - 9ms/step
# Epoch 13/100
# 85/85 - 1s - loss: 0.0135 - mse: 0.0135 - val_loss: 0.0071 - val_mse: 0.0071 - 788ms/epoch - 9ms/step
# Epoch 14/100
# 85/85 - 1s - loss: 0.0134 - mse: 0.0134 - val_loss: 0.0087 - val_mse: 0.0087 - 762ms/epoch - 9ms/step
# Epoch 15/100
# 85/85 - 1s - loss: 0.0132 - mse: 0.0132 - val_loss: 0.0081 - val_mse: 0.0081 - 760ms/epoch - 9ms/step
# Epoch 16/100
# 85/85 - 1s - loss: 0.0122 - mse: 0.0122 - val_loss: 0.0065 - val_mse: 0.0065 - 766ms/epoch - 9ms/step
# Epoch 17/100
# 85/85 - 1s - loss: 0.0128 - mse: 0.0128 - val_loss: 0.0066 - val_mse: 0.0066 - 754ms/epoch - 9ms/step
# Epoch 18/100
# 85/85 - 1s - loss: 0.0127 - mse: 0.0127 - val_loss: 0.0072 - val_mse: 0.0072 - 741ms/epoch - 9ms/step
# Epoch 19/100
# 85/85 - 1s - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0080 - val_mse: 0.0080 - 733ms/epoch - 9ms/step
# Epoch 19: early stopping

# %%
# Resumen del entrenamiento
n_rows = 2
n_cols = 3

fig, ax = plt.subplots(n_rows, n_cols, figsize=(14,8))
fig.suptitle('Model loss SPI_6')
plt.subplots_adjust(hspace=0.3, wspace=0.3)
for i, (key, value) in enumerate(model_history_dict.items()):
    if i<n_cols:
        ax[0, i].plot(value.history['loss'])
        ax[0, i].plot(value.history['val_loss'])
        ax[0, i].set_title(key, fontsize=10)
        ax[0, i].set_ylabel('loss')
        ax[0, i].set_xlabel('epoch')
        ax[0, i].legend(['train', 'test'], loc='upper right')
    else:
        ax[1, i-n_cols].plot(value.history['loss'])
        ax[1, i-n_cols].plot(value.history['val_loss'])
        ax[1, i-n_cols].set_title(key, fontsize=10)
        ax[1, i-n_cols].set_ylabel('loss')
        ax[1, i-n_cols].set_xlabel('epoch')
        ax[1, i-n_cols].legend(['train', 'test'], loc='upper right')

# %% [markdown]
# # Evaluación del modelo

# %%
test_score_values = []
for key in spi_6_dict.keys():
    print('Evaluación '+ key)
    train_prediction = model.predict(X_train_dict[key], verbose=0)
    test_prediction = model.predict(X_test_dict[key], verbose=0)
    train_score = model.evaluate(X_train_dict[key], y_train_dict[key], verbose=0)
    test_score = model.evaluate(X_test_dict[key], y_test_dict[key], verbose=0)
    test_score_values.append(test_score[0])
    print('Train score: {} MSE'.format(train_score[0]))
    print('Test score: {} MSE'.format(test_score[0]))
    print('')

mean_test_score = sum(test_score_values) / len(test_score_values)
print('Mean Test score: {} MSE'.format(mean_test_score))
# Out:
# Evaluación Demarcación Hidrográfica de las Cuencas Mediterráneas Andaluzas
# Train score: 0.016676301136612892 MSE
# Test score: 0.01802554726600647 MSE
#
# Evaluación Cuenca hidrográfica del Guadalquivir
# Train score: 0.01758764125406742 MSE
# Test score: 0.015629690140485764 MSE
#
# Evaluación Cuenca hidrográfica del Guadiana
# Train score: 0.016311317682266235 MSE
# Test score: 0.015744879841804504 MSE
#
# Evaluación Cuenca hidrográfica del Segura
# Train score: 0.01526929996907711 MSE
# Test score: 0.01527449581772089 MSE
#
# Evaluación Demarcación Hidrográfica Guadalete-Barbate
# Train score: 0.01396748423576355 MSE
# Test score: 0.011966845951974392 MSE
#
# Evaluación Demarcación Hidrográfica Tinto, Odiel y Piedras
# Train score: 0.00987719465047121 MSE
# Test score: 0.007952486164867878 MSE
#
# Mean Test score: 0.014098990863809982 MSE

# %% [markdown]
# # Visualización de la predicción

# %%
# Gráfica con los valores reales frente a los datos de predicción
# Se usa como ejemplo la predicción de la Demarcación Hidrográfica Tinto, Odiel y Piedras
plt.figure(figsize=(12, 8))
train_stamp = np.arange(3+sequence_size, sequence_size + 3+X_train_dict[keys_names[5]].shape[0])
test_stamp = np.arange(3+2 * sequence_size + X_train_dict[keys_names[5]].shape[0], 3+len(spi_6_dict[keys_names[5]]))
plt.plot(spi_6_dict[keys_names[5]], label='Valores reales')
plt.plot(train_stamp, train_prediction, label='train prediction')
plt.plot(test_stamp, test_prediction, label = 'test prediction')
plt.title('Predicción SPI_6 '+ keys_names[5])
plt.legend()
plt.show()
